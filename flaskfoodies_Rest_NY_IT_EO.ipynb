# %%
# scrape 
from bs4 import BeautifulSoup
from bs4 import BeautifulSoup as bs
from splinter import Browser
from splinter.exceptions import ElementDoesNotExist
import requests
import pandas as pd
import time

# %% [markdown]
# <h1># Windows Users</h1>

# %%
#Set the chromedriver path
executable_path = {"executable_path": "/users/evaeb/bin/chromedriver"}
browser = Browser("chrome", **executable_path, headless=False)

# %%
# Scrap Italian restaurants in New York
url = 'https://www.zomato.com/new-york-city/restaurants/italian'
browser.visit(url)
restaurant_name=[]
restaurant_address=[]
votes=[]
ratings=[]
costs=[]

for x in range(1, 30):
    html = browser.html
    soup = bs(html, 'html.parser')
    restaurant_info = soup.find_all(class_='content')
    for restaurant in restaurant_info:
        try: 
            rest_name= restaurant.find('a', class_='result-title').text
            rest_address= restaurant.find(class_='search-result-address').text
            vote= restaurant.find('span').text
            rating= restaurant.find(class_='rating-popup').text
            cost= restaurant.find(class_="res-cost").text
            
            restaurant_name.append(rest_name)
            restaurant_address.append(rest_address)
            votes.append(vote)
            ratings.append(rating)
            costs.append(cost)
        except:
            print("Not Available")
        

#         print(rest_name)
#         print(rest_address)
#         print(vote)
#         print(rating)
        try:
            browser.click_link_by_partial_text('Next Page')
        except:
            print("Scraping Complete")
# Out:
# Not Available
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Not Available
# Scraping Complete
# Not Available
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Not Available
# Scraping Complete
# Not Available
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Not Available
# Scraping Complete
# Not Available
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Not Available
# Scraping Complete
# Not Available
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Not Available
# Scraping Complete
# Not Available
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Not Available
# Scraping Complete
# Not Available
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Not Available
# Scraping Complete
# Not Available
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Not Available
# Scraping Complete
# Not Available
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Not Available
# Scraping Complete
# Not Available
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Not Available
# Scraping Complete
# Not Available
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Not Available
# Scraping Complete
# Not Available
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Not Available
# Scraping Complete
# Not Available
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Not Available
# Scraping Complete
# Not Available
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Not Available
# Scraping Complete
# Not Available
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Not Available
# Scraping Complete
# Not Available
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Not Available
# Scraping Complete
# Not Available
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Not Available
# Scraping Complete
# Not Available
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Not Available
# Scraping Complete
# Not Available
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Not Available
# Scraping Complete
# Not Available
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Not Available
# Scraping Complete
# Not Available
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Not Available
# Scraping Complete
# Not Available
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Not Available
# Scraping Complete
# Not Available
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Not Available
# Scraping Complete
# Not Available
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Not Available
# Scraping Complete
# Not Available
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Not Available
# Scraping Complete
# Not Available
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Not Available
# Scraping Complete
# Not Available
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Not Available
# Scraping Complete
# Not Available
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Not Available
# Scraping Complete
# Not Available
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Not Available
# Scraping Complete

# %%
restaurant_name
# Out:
# ["Carmine's Italian Restaurant\n                                    ",
#  'Becco\n                                    ',
#  "Grimaldi's Pizzeria\n                                    ",
#  "Lombardi's Pizza\n                                    ",
#  'Babbo\n                                    ',
#  "John's Pizza of Times Square\n                                    ",
#  'Otto Enoteca Pizzeria\n                                    ',
#  'The Meatball Shop\n                                    ',
#  'Union Square Cafe\n                                    ',
#  'Locanda Verde\n                                    ',
#  'Lupa Osteria Romana\n                                    ',
#  "Roberta's\n                                    ",
#  'Del Posto\n                                    ',
#  'La Birreria\n                                    ',
#  'L & B Spumoni Gardens\n                                    ',
#  "Carmine's Italian Restaurant\n                                    ",
#  'Becco\n                                    ',
#  "Grimaldi's Pizzeria\n                                    ",
#  "Lombardi's Pizza\n                                    ",
#  'Babbo\n                                    ',
#  "John's Pizza of Times Square\n                                    ",
#  'Otto Enoteca Pizzeria\n                                    ',
#  'The Meatball Shop\n                                    ',
#  'Union Square Cafe\n                                    ',
#  'Locanda Verde\n                                    ',
#  'Lupa Osteria Romana\n                                    ',
#  "Roberta's\n                                    ",
#  'Del Posto\n                                    ',
#  'La Birreria\n                                    ',
#  'L & B Spumoni Gardens\n                                    ',
#  "Carmine's Italian Restaurant\n                                    ",
#  'Becco\n                                    ',
#  "Grimaldi's Pizzeria\n                                    ",
#  "Lombardi's Pizza\n                                    ",
#  'Babbo\n                                    ',
#  "John's Pizza of Times Square\n                                    ",
#  'Otto Enoteca Pizzeria\n                                    ',
#  'The Meatball Shop\n                                    ',
#  'Union Square Cafe\n                                    ',
#  'Locanda Verde\n                                    ',
#  'Lupa Osteria Romana\n                                    ',
#  "Roberta's\n                                    ",
#  'Del Posto\n                                    ',
#  'La Birreria\n                                    ',
#  'L & B Spumoni Gardens\n                                    ',
#  "Carmine's Italian Restaurant\n                                    ",
#  'Becco\n                                    ',
#  "Grimaldi's Pizzeria\n                                    ",
#  "Lombardi's Pizza\n                                    ",
#  'Babbo\n                                    ',
#  "John's Pizza of Times Square\n                                    ",
#  'Otto Enoteca Pizzeria\n                                    ',
#  'The Meatball Shop\n                                    ',
#  'Union Square Cafe\n                                    ',
#  'Locanda Verde\n                                    ',
#  'Lupa Osteria Romana\n                                    ',
#  "Roberta's\n                                    ",
#  'Del Posto\n                                    ',
#  'La Birreria\n                                    ',
#  'L & B Spumoni Gardens\n                                    ',
#  "Carmine's Italian Restaurant\n                                    ",
#  'Becco\n                                    ',
#  "Grimaldi's Pizzeria\n                                    ",
#  "Lombardi's Pizza\n                                    ",
#  'Babbo\n                                    ',
#  "John's Pizza of Times Square\n                                    ",
#  'Otto Enoteca Pizzeria\n                                    ',
#  'The Meatball Shop\n                                    ',
#  'Union Square Cafe\n                                    ',
#  'Locanda Verde\n                                    ',
#  'Lupa Osteria Romana\n                                    ',
#  "Roberta's\n                                    ",
#  'Del Posto\n                                    ',
#  'La Birreria\n                                    ',
#  'L & B Spumoni Gardens\n                                    ',
#  "Carmine's Italian Restaurant\n                                    ",
#  'Becco\n                                    ',
#  "Grimaldi's Pizzeria\n                                    ",
#  "Lombardi's Pizza\n                                    ",
#  'Babbo\n                                    ',
#  "John's Pizza of Times Square\n                                    ",
#  'Otto Enoteca Pizzeria\n                                    ',
#  'The Meatball Shop\n                                    ',
#  'Union Square Cafe\n                                    ',
#  'Locanda Verde\n                                    ',
#  'Lupa Osteria Romana\n                                    ',
#  "Roberta's\n                                    ",
#  'Del Posto\n                                    ',
#  'La Birreria\n                                    ',
#  'L & B Spumoni Gardens\n                                    ',
#  "Carmine's Italian Restaurant\n                                    ",
#  'Becco\n                                    ',
#  "Grimaldi's Pizzeria\n                                    ",
#  "Lombardi's Pizza\n                                    ",
#  'Babbo\n                                    ',
#  "John's Pizza of Times Square\n                                    ",
#  'Otto Enoteca Pizzeria\n                                    ',
#  'The Meatball Shop\n                                    ',
#  'Union Square Cafe\n                                    ',
#  'Locanda Verde\n                                    ',
#  'Lupa Osteria Romana\n                                    ',
#  "Roberta's\n                                    ",
#  'Del Posto\n                                    ',
#  'La Birreria\n                                    ',
#  'L & B Spumoni Gardens\n                                    ',
#  "Carmine's Italian Restaurant\n                                    ",
#  'Becco\n                                    ',
#  "Grimaldi's Pizzeria\n                                    ",
#  "Lombardi's Pizza\n                                    ",
#  'Babbo\n                                    ',
#  "John's Pizza of Times Square\n                                    ",
#  'Otto Enoteca Pizzeria\n                                    ',
#  'The Meatball Shop\n                                    ',
#  'Union Square Cafe\n                                    ',
#  'Locanda Verde\n                                    ',
#  'Lupa Osteria Romana\n                                    ',
#  "Roberta's\n                                    ",
#  'Del Posto\n                                    ',
#  'La Birreria\n                                    ',
#  'L & B Spumoni Gardens\n                                    ',
#  "Carmine's Italian Restaurant\n                                    ",
#  'Becco\n                                    ',
#  "Grimaldi's Pizzeria\n                                    ",
#  "Lombardi's Pizza\n                                    ",
#  'Babbo\n                                    ',
#  "John's Pizza of Times Square\n                                    ",
#  'Otto Enoteca Pizzeria\n                                    ',
#  'The Meatball Shop\n                                    ',
#  'Union Square Cafe\n                                    ',
#  'Locanda Verde\n                                    ',
#  'Lupa Osteria Romana\n                                    ',
#  "Roberta's\n                                    ",
#  'Del Posto\n                                    ',
#  'La Birreria\n                                    ',
#  'L & B Spumoni Gardens\n                                    ',
#  "Carmine's Italian Restaurant\n                                    ",
#  'Becco\n                                    ',
#  "Grimaldi's Pizzeria\n                                    ",
#  "Lombardi's Pizza\n                                    ",
#  'Babbo\n                                    ',
#  "John's Pizza of Times Square\n                                    ",
#  'Otto Enoteca Pizzeria\n                                    ',
#  'The Meatball Shop\n                                    ',
#  'Union Square Cafe\n                                    ',
#  'Locanda Verde\n                                    ',
#  'Lupa Osteria Romana\n                                    ',
#  "Roberta's\n                                    ",
#  'Del Posto\n                                    ',
#  'La Birreria\n                                    ',
#  'L & B Spumoni Gardens\n                                    ',
#  "Carmine's Italian Restaurant\n                                    ",
#  'Becco\n                                    ',
#  "Grimaldi's Pizzeria\n                                    ",
#  "Lombardi's Pizza\n                                    ",
#  'Babbo\n                                    ',
#  "John's Pizza of Times Square\n                                    ",
#  'Otto Enoteca Pizzeria\n                                    ',
#  'The Meatball Shop\n                                    ',
#  'Union Square Cafe\n                                    ',
#  'Locanda Verde\n                                    ',
#  'Lupa Osteria Romana\n                                    ',
#  "Roberta's\n                                    ",
#  'Del Posto\n                                    ',
#  'La Birreria\n                                    ',
#  'L & B Spumoni Gardens\n                                    ',
#  "Carmine's Italian Restaurant\n                                    ",
#  'Becco\n                                    ',
#  "Grimaldi's Pizzeria\n                                    ",
#  "Lombardi's Pizza\n                                    ",
#  'Babbo\n                                    ',
#  "John's Pizza of Times Square\n                                    ",
#  'Otto Enoteca Pizzeria\n                                    ',
#  'The Meatball Shop\n                                    ',
#  'Union Square Cafe\n                                    ',
#  'Locanda Verde\n                                    ',
#  'Lupa Osteria Romana\n                                    ',
#  "Roberta's\n                                    ",
#  'Del Posto\n                                    ',
#  'La Birreria\n                                    ',
#  'L & B Spumoni Gardens\n                                    ',
#  "Carmine's Italian Restaurant\n                                    ",
#  'Becco\n                                    ',
#  "Grimaldi's Pizzeria\n                                    ",
#  "Lombardi's Pizza\n                                    ",
#  'Babbo\n                                    ',
#  "John's Pizza of Times Square\n                                    ",
#  'Otto Enoteca Pizzeria\n                                    ',
#  'The Meatball Shop\n                                    ',
#  'Union Square Cafe\n                                    ',
#  'Locanda Verde\n                                    ',
#  'Lupa Osteria Romana\n                                    ',
#  "Roberta's\n                                    ",
#  'Del Posto\n                                    ',
#  'La Birreria\n                                    ',
#  'L & B Spumoni Gardens\n                                    ',
#  "Carmine's Italian Restaurant\n                                    ",
#  'Becco\n                                    ',
#  "Grimaldi's Pizzeria\n                                    ",
#  "Lombardi's Pizza\n                                    ",
#  'Babbo\n                                    ',
#  "John's Pizza of Times Square\n                                    ",
#  'Otto Enoteca Pizzeria\n                                    ',
#  'The Meatball Shop\n                                    ',
#  'Union Square Cafe\n                                    ',
#  'Locanda Verde\n                                    ',
#  'Lupa Osteria Romana\n                                    ',
#  "Roberta's\n                                    ",
#  'Del Posto\n                                    ',
#  'La Birreria\n                                    ',
#  'L & B Spumoni Gardens\n                                    ',
#  "Carmine's Italian Restaurant\n                                    ",
#  'Becco\n                                    ',
#  "Grimaldi's Pizzeria\n                                    ",
#  "Lombardi's Pizza\n                                    ",
#  'Babbo\n                                    ',
#  "John's Pizza of Times Square\n                                    ",
#  'Otto Enoteca Pizzeria\n                                    ',
#  'The Meatball Shop\n                                    ',
#  'Union Square Cafe\n                                    ',
#  'Locanda Verde\n                                    ',
#  'Lupa Osteria Romana\n                                    ',
#  "Roberta's\n                                    ",
#  'Del Posto\n                                    ',
#  'La Birreria\n                                    ',
#  'L & B Spumoni Gardens\n                                    ',
#  "Carmine's Italian Restaurant\n                                    ",
#  'Becco\n                                    ',
#  "Grimaldi's Pizzeria\n                                    ",
#  "Lombardi's Pizza\n                                    ",
#  'Babbo\n                                    ',
#  "John's Pizza of Times Square\n                                    ",
#  'Otto Enoteca Pizzeria\n                                    ',
#  'The Meatball Shop\n                                    ',
#  'Union Square Cafe\n                                    ',
#  'Locanda Verde\n                                    ',
#  'Lupa Osteria Romana\n                                    ',
#  "Roberta's\n                                    ",
#  'Del Posto\n                                    ',
#  'La Birreria\n                                    ',
#  'L & B Spumoni Gardens\n                                    ',
#  "Carmine's Italian Restaurant\n                                    ",
#  'Becco\n                                    ',
#  "Grimaldi's Pizzeria\n                                    ",
#  "Lombardi's Pizza\n                                    ",
#  'Babbo\n                                    ',
#  "John's Pizza of Times Square\n                                    ",
#  'Otto Enoteca Pizzeria\n                                    ',
#  'The Meatball Shop\n                                    ',
#  'Union Square Cafe\n                                    ',
#  'Locanda Verde\n                                    ',
#  'Lupa Osteria Romana\n                                    ',
#  "Roberta's\n                                    ",
#  'Del Posto\n                                    ',
#  'La Birreria\n                                    ',
#  'L & B Spumoni Gardens\n                                    ',
#  "Carmine's Italian Restaurant\n                                    ",
#  'Becco\n                                    ',
#  "Grimaldi's Pizzeria\n                                    ",
#  "Lombardi's Pizza\n                                    ",
#  'Babbo\n                                    ',
#  "John's Pizza of Times Square\n                                    ",
#  'Otto Enoteca Pizzeria\n                                    ',
#  'The Meatball Shop\n                                    ',
#  'Union Square Cafe\n                                    ',
#  'Locanda Verde\n                                    ',
#  'Lupa Osteria Romana\n                                    ',
#  "Roberta's\n                                    ",
#  'Del Posto\n                                    ',
#  'La Birreria\n                                    ',
#  'L & B Spumoni Gardens\n                                    ',
#  "Carmine's Italian Restaurant\n                                    ",
#  'Becco\n                                    ',
#  "Grimaldi's Pizzeria\n                                    ",
#  "Lombardi's Pizza\n                                    ",
#  'Babbo\n                                    ',
#  "John's Pizza of Times Square\n                                    ",
#  'Otto Enoteca Pizzeria\n                                    ',
#  'The Meatball Shop\n                                    ',
#  'Union Square Cafe\n                                    ',
#  'Locanda Verde\n                                    ',
#  'Lupa Osteria Romana\n                                    ',
#  "Roberta's\n                                    ",
#  'Del Posto\n                                    ',
#  'La Birreria\n                                    ',
#  'L & B Spumoni Gardens\n                                    ',
#  "Carmine's Italian Restaurant\n                                    ",
#  'Becco\n                                    ',
#  "Grimaldi's Pizzeria\n                                    ",
#  "Lombardi's Pizza\n                                    ",
#  'Babbo\n                                    ',
#  "John's Pizza of Times Square\n                                    ",
#  'Otto Enoteca Pizzeria\n                                    ',
#  'The Meatball Shop\n                                    ',
#  'Union Square Cafe\n                                    ',
#  'Locanda Verde\n                                    ',
#  'Lupa Osteria Romana\n                                    ',
#  "Roberta's\n                                    ",
#  'Del Posto\n                                    ',
#  'La Birreria\n                                    ',
#  'L & B Spumoni Gardens\n                                    ',
#  "Carmine's Italian Restaurant\n                                    ",
#  'Becco\n                                    ',
#  "Grimaldi's Pizzeria\n                                    ",
#  "Lombardi's Pizza\n                                    ",
#  'Babbo\n                                    ',
#  "John's Pizza of Times Square\n                                    ",
#  'Otto Enoteca Pizzeria\n                                    ',
#  'The Meatball Shop\n                                    ',
#  'Union Square Cafe\n                                    ',
#  'Locanda Verde\n                                    ',
#  'Lupa Osteria Romana\n                                    ',
#  "Roberta's\n                                    ",
#  'Del Posto\n                                    ',
#  'La Birreria\n                                    ',
#  'L & B Spumoni Gardens\n                                    ',
#  "Carmine's Italian Restaurant\n                                    ",
#  'Becco\n                                    ',
#  "Grimaldi's Pizzeria\n                                    ",
#  "Lombardi's Pizza\n                                    ",
#  'Babbo\n                                    ',
#  "John's Pizza of Times Square\n                                    ",
#  'Otto Enoteca Pizzeria\n                                    ',
#  'The Meatball Shop\n                                    ',
#  'Union Square Cafe\n                                    ',
#  'Locanda Verde\n                                    ',
#  'Lupa Osteria Romana\n                                    ',
#  "Roberta's\n                                    ",
#  'Del Posto\n                                    ',
#  'La Birreria\n                                    ',
#  'L & B Spumoni Gardens\n                                    ',
#  "Carmine's Italian Restaurant\n                                    ",
#  'Becco\n                                    ',
#  "Grimaldi's Pizzeria\n                                    ",
#  "Lombardi's Pizza\n                                    ",
#  'Babbo\n                                    ',
#  "John's Pizza of Times Square\n                                    ",
#  'Otto Enoteca Pizzeria\n                                    ',
#  'The Meatball Shop\n                                    ',
#  'Union Square Cafe\n                                    ',
#  'Locanda Verde\n                                    ',
#  'Lupa Osteria Romana\n                                    ',
#  "Roberta's\n                                    ",
#  'Del Posto\n                                    ',
#  'La Birreria\n                                    ',
#  'L & B Spumoni Gardens\n                                    ',
#  "Carmine's Italian Restaurant\n                                    ",
#  'Becco\n                                    ',
#  "Grimaldi's Pizzeria\n                                    ",
#  "Lombardi's Pizza\n                                    ",
#  'Babbo\n                                    ',
#  "John's Pizza of Times Square\n                                    ",
#  'Otto Enoteca Pizzeria\n                                    ',
#  'The Meatball Shop\n                                    ',
#  'Union Square Cafe\n                                    ',
#  'Locanda Verde\n                                    ',
#  'Lupa Osteria Romana\n                                    ',
#  "Roberta's\n                                    ",
#  'Del Posto\n                                    ',
#  'La Birreria\n                                    ',
#  'L & B Spumoni Gardens\n                                    ',
#  "Carmine's Italian Restaurant\n                                    ",
#  'Becco\n                                    ',
#  "Grimaldi's Pizzeria\n                                    ",
#  "Lombardi's Pizza\n                                    ",
#  'Babbo\n                                    ',
#  "John's Pizza of Times Square\n                                    ",
#  'Otto Enoteca Pizzeria\n                                    ',
#  'The Meatball Shop\n                                    ',
#  'Union Square Cafe\n                                    ',
#  'Locanda Verde\n                                    ',
#  'Lupa Osteria Romana\n                                    ',
#  "Roberta's\n                                    ",
#  'Del Posto\n                                    ',
#  'La Birreria\n                                    ',
#  'L & B Spumoni Gardens\n                                    ',
#  "Carmine's Italian Restaurant\n                                    ",
#  'Becco\n                                    ',
#  "Grimaldi's Pizzeria\n                                    ",
#  "Lombardi's Pizza\n                                    ",
#  'Babbo\n                                    ',
#  "John's Pizza of Times Square\n                                    ",
#  'Otto Enoteca Pizzeria\n                                    ',
#  'The Meatball Shop\n                                    ',
#  'Union Square Cafe\n                                    ',
#  'Locanda Verde\n                                    ',
#  'Lupa Osteria Romana\n                                    ',
#  "Roberta's\n                                    ",
#  'Del Posto\n                                    ',
#  'La Birreria\n                                    ',
#  'L & B Spumoni Gardens\n                                    ',
#  "Carmine's Italian Restaurant\n                                    ",
#  'Becco\n                                    ',
#  "Grimaldi's Pizzeria\n                                    ",
#  "Lombardi's Pizza\n                                    ",
#  'Babbo\n                                    ',
#  "John's Pizza of Times Square\n                                    ",
#  'Otto Enoteca Pizzeria\n                                    ',
#  'The Meatball Shop\n                                    ',
#  'Union Square Cafe\n                                    ',
#  'Locanda Verde\n                                    ',
#  'Lupa Osteria Romana\n                                    ',
#  "Roberta's\n                                    ",
#  'Del Posto\n                                    ',
#  'La Birreria\n                                    ',
#  'L & B Spumoni Gardens\n                                    ',
#  "Carmine's Italian Restaurant\n                                    ",
#  'Becco\n                                    ',
#  "Grimaldi's Pizzeria\n                                    ",
#  "Lombardi's Pizza\n                                    ",
#  'Babbo\n                                    ',
#  "John's Pizza of Times Square\n                                    ",
#  'Otto Enoteca Pizzeria\n                                    ',
#  'The Meatball Shop\n                                    ',
#  'Union Square Cafe\n                                    ',
#  'Locanda Verde\n                                    ',
#  'Lupa Osteria Romana\n                                    ',
#  "Roberta's\n                                    ",
#  'Del Posto\n                                    ',
#  'La Birreria\n                                    ',
#  'L & B Spumoni Gardens\n                                    ',
#  "Carmine's Italian Restaurant\n                                    ",
#  'Becco\n                                    ',
#  "Grimaldi's Pizzeria\n                                    ",
#  "Lombardi's Pizza\n                                    ",
#  'Babbo\n                                    ',
#  "John's Pizza of Times Square\n                                    ",
#  'Otto Enoteca Pizzeria\n                                    ',
#  'The Meatball Shop\n                                    ',
#  'Union Square Cafe\n                                    ',
#  'Locanda Verde\n                                    ',
#  'Lupa Osteria Romana\n                                    ',
#  "Roberta's\n                                    ",
#  'Del Posto\n                                    ',
#  'La Birreria\n                                    ',
#  'L & B Spumoni Gardens\n                                    ']

# %%
restaurant_address
# Out:
# [' 200 West 44th Street, btwn Broadway & 8th Avenue 10036',
#  ' 355 West 46th Street, Theater District 10036',
#  ' 1 Front Street, Brooklyn 11201',
#  ' 32 Spring Street, New York 10012',
#  ' 110 Waverly Pl, Greenwich Village 10011',
#  ' 260 W 44th Street, New York 10036',
#  ' One Fifth Avenue at 8th Street, Greenwich Village 10003',
#  ' 84 Stanton Street 10002',
#  ' 16th Street, New York 10003',
#  ' 377 Greenwich Street, New York 10013',
#  ' 170 Thompson Street, New York 10012',
#  ' 261 Moore Street, Brooklyn 11206',
#  ' 85 10th Avenue, Chelsea 10011',
#  ' 200 Fifth Avenue 10010',
#  ' 2725 86th Street 11223',
#  ' 200 West 44th Street, btwn Broadway & 8th Avenue 10036',
#  ' 355 West 46th Street, Theater District 10036',
#  ' 1 Front Street, Brooklyn 11201',
#  ' 32 Spring Street, New York 10012',
#  ' 110 Waverly Pl, Greenwich Village 10011',
#  ' 260 W 44th Street, New York 10036',
#  ' One Fifth Avenue at 8th Street, Greenwich Village 10003',
#  ' 84 Stanton Street 10002',
#  ' 16th Street, New York 10003',
#  ' 377 Greenwich Street, New York 10013',
#  ' 170 Thompson Street, New York 10012',
#  ' 261 Moore Street, Brooklyn 11206',
#  ' 85 10th Avenue, Chelsea 10011',
#  ' 200 Fifth Avenue 10010',
#  ' 2725 86th Street 11223',
#  ' 200 West 44th Street, btwn Broadway & 8th Avenue 10036',
#  ' 355 West 46th Street, Theater District 10036',
#  ' 1 Front Street, Brooklyn 11201',
#  ' 32 Spring Street, New York 10012',
#  ' 110 Waverly Pl, Greenwich Village 10011',
#  ' 260 W 44th Street, New York 10036',
#  ' One Fifth Avenue at 8th Street, Greenwich Village 10003',
#  ' 84 Stanton Street 10002',
#  ' 16th Street, New York 10003',
#  ' 377 Greenwich Street, New York 10013',
#  ' 170 Thompson Street, New York 10012',
#  ' 261 Moore Street, Brooklyn 11206',
#  ' 85 10th Avenue, Chelsea 10011',
#  ' 200 Fifth Avenue 10010',
#  ' 2725 86th Street 11223',
#  ' 200 West 44th Street, btwn Broadway & 8th Avenue 10036',
#  ' 355 West 46th Street, Theater District 10036',
#  ' 1 Front Street, Brooklyn 11201',
#  ' 32 Spring Street, New York 10012',
#  ' 110 Waverly Pl, Greenwich Village 10011',
#  ' 260 W 44th Street, New York 10036',
#  ' One Fifth Avenue at 8th Street, Greenwich Village 10003',
#  ' 84 Stanton Street 10002',
#  ' 16th Street, New York 10003',
#  ' 377 Greenwich Street, New York 10013',
#  ' 170 Thompson Street, New York 10012',
#  ' 261 Moore Street, Brooklyn 11206',
#  ' 85 10th Avenue, Chelsea 10011',
#  ' 200 Fifth Avenue 10010',
#  ' 2725 86th Street 11223',
#  ' 200 West 44th Street, btwn Broadway & 8th Avenue 10036',
#  ' 355 West 46th Street, Theater District 10036',
#  ' 1 Front Street, Brooklyn 11201',
#  ' 32 Spring Street, New York 10012',
#  ' 110 Waverly Pl, Greenwich Village 10011',
#  ' 260 W 44th Street, New York 10036',
#  ' One Fifth Avenue at 8th Street, Greenwich Village 10003',
#  ' 84 Stanton Street 10002',
#  ' 16th Street, New York 10003',
#  ' 377 Greenwich Street, New York 10013',
#  ' 170 Thompson Street, New York 10012',
#  ' 261 Moore Street, Brooklyn 11206',
#  ' 85 10th Avenue, Chelsea 10011',
#  ' 200 Fifth Avenue 10010',
#  ' 2725 86th Street 11223',
#  ' 200 West 44th Street, btwn Broadway & 8th Avenue 10036',
#  ' 355 West 46th Street, Theater District 10036',
#  ' 1 Front Street, Brooklyn 11201',
#  ' 32 Spring Street, New York 10012',
#  ' 110 Waverly Pl, Greenwich Village 10011',
#  ' 260 W 44th Street, New York 10036',
#  ' One Fifth Avenue at 8th Street, Greenwich Village 10003',
#  ' 84 Stanton Street 10002',
#  ' 16th Street, New York 10003',
#  ' 377 Greenwich Street, New York 10013',
#  ' 170 Thompson Street, New York 10012',
#  ' 261 Moore Street, Brooklyn 11206',
#  ' 85 10th Avenue, Chelsea 10011',
#  ' 200 Fifth Avenue 10010',
#  ' 2725 86th Street 11223',
#  ' 200 West 44th Street, btwn Broadway & 8th Avenue 10036',
#  ' 355 West 46th Street, Theater District 10036',
#  ' 1 Front Street, Brooklyn 11201',
#  ' 32 Spring Street, New York 10012',
#  ' 110 Waverly Pl, Greenwich Village 10011',
#  ' 260 W 44th Street, New York 10036',
#  ' One Fifth Avenue at 8th Street, Greenwich Village 10003',
#  ' 84 Stanton Street 10002',
#  ' 16th Street, New York 10003',
#  ' 377 Greenwich Street, New York 10013',
#  ' 170 Thompson Street, New York 10012',
#  ' 261 Moore Street, Brooklyn 11206',
#  ' 85 10th Avenue, Chelsea 10011',
#  ' 200 Fifth Avenue 10010',
#  ' 2725 86th Street 11223',
#  ' 200 West 44th Street, btwn Broadway & 8th Avenue 10036',
#  ' 355 West 46th Street, Theater District 10036',
#  ' 1 Front Street, Brooklyn 11201',
#  ' 32 Spring Street, New York 10012',
#  ' 110 Waverly Pl, Greenwich Village 10011',
#  ' 260 W 44th Street, New York 10036',
#  ' One Fifth Avenue at 8th Street, Greenwich Village 10003',
#  ' 84 Stanton Street 10002',
#  ' 16th Street, New York 10003',
#  ' 377 Greenwich Street, New York 10013',
#  ' 170 Thompson Street, New York 10012',
#  ' 261 Moore Street, Brooklyn 11206',
#  ' 85 10th Avenue, Chelsea 10011',
#  ' 200 Fifth Avenue 10010',
#  ' 2725 86th Street 11223',
#  ' 200 West 44th Street, btwn Broadway & 8th Avenue 10036',
#  ' 355 West 46th Street, Theater District 10036',
#  ' 1 Front Street, Brooklyn 11201',
#  ' 32 Spring Street, New York 10012',
#  ' 110 Waverly Pl, Greenwich Village 10011',
#  ' 260 W 44th Street, New York 10036',
#  ' One Fifth Avenue at 8th Street, Greenwich Village 10003',
#  ' 84 Stanton Street 10002',
#  ' 16th Street, New York 10003',
#  ' 377 Greenwich Street, New York 10013',
#  ' 170 Thompson Street, New York 10012',
#  ' 261 Moore Street, Brooklyn 11206',
#  ' 85 10th Avenue, Chelsea 10011',
#  ' 200 Fifth Avenue 10010',
#  ' 2725 86th Street 11223',
#  ' 200 West 44th Street, btwn Broadway & 8th Avenue 10036',
#  ' 355 West 46th Street, Theater District 10036',
#  ' 1 Front Street, Brooklyn 11201',
#  ' 32 Spring Street, New York 10012',
#  ' 110 Waverly Pl, Greenwich Village 10011',
#  ' 260 W 44th Street, New York 10036',
#  ' One Fifth Avenue at 8th Street, Greenwich Village 10003',
#  ' 84 Stanton Street 10002',
#  ' 16th Street, New York 10003',
#  ' 377 Greenwich Street, New York 10013',
#  ' 170 Thompson Street, New York 10012',
#  ' 261 Moore Street, Brooklyn 11206',
#  ' 85 10th Avenue, Chelsea 10011',
#  ' 200 Fifth Avenue 10010',
#  ' 2725 86th Street 11223',
#  ' 200 West 44th Street, btwn Broadway & 8th Avenue 10036',
#  ' 355 West 46th Street, Theater District 10036',
#  ' 1 Front Street, Brooklyn 11201',
#  ' 32 Spring Street, New York 10012',
#  ' 110 Waverly Pl, Greenwich Village 10011',
#  ' 260 W 44th Street, New York 10036',
#  ' One Fifth Avenue at 8th Street, Greenwich Village 10003',
#  ' 84 Stanton Street 10002',
#  ' 16th Street, New York 10003',
#  ' 377 Greenwich Street, New York 10013',
#  ' 170 Thompson Street, New York 10012',
#  ' 261 Moore Street, Brooklyn 11206',
#  ' 85 10th Avenue, Chelsea 10011',
#  ' 200 Fifth Avenue 10010',
#  ' 2725 86th Street 11223',
#  ' 200 West 44th Street, btwn Broadway & 8th Avenue 10036',
#  ' 355 West 46th Street, Theater District 10036',
#  ' 1 Front Street, Brooklyn 11201',
#  ' 32 Spring Street, New York 10012',
#  ' 110 Waverly Pl, Greenwich Village 10011',
#  ' 260 W 44th Street, New York 10036',
#  ' One Fifth Avenue at 8th Street, Greenwich Village 10003',
#  ' 84 Stanton Street 10002',
#  ' 16th Street, New York 10003',
#  ' 377 Greenwich Street, New York 10013',
#  ' 170 Thompson Street, New York 10012',
#  ' 261 Moore Street, Brooklyn 11206',
#  ' 85 10th Avenue, Chelsea 10011',
#  ' 200 Fifth Avenue 10010',
#  ' 2725 86th Street 11223',
#  ' 200 West 44th Street, btwn Broadway & 8th Avenue 10036',
#  ' 355 West 46th Street, Theater District 10036',
#  ' 1 Front Street, Brooklyn 11201',
#  ' 32 Spring Street, New York 10012',
#  ' 110 Waverly Pl, Greenwich Village 10011',
#  ' 260 W 44th Street, New York 10036',
#  ' One Fifth Avenue at 8th Street, Greenwich Village 10003',
#  ' 84 Stanton Street 10002',
#  ' 16th Street, New York 10003',
#  ' 377 Greenwich Street, New York 10013',
#  ' 170 Thompson Street, New York 10012',
#  ' 261 Moore Street, Brooklyn 11206',
#  ' 85 10th Avenue, Chelsea 10011',
#  ' 200 Fifth Avenue 10010',
#  ' 2725 86th Street 11223',
#  ' 200 West 44th Street, btwn Broadway & 8th Avenue 10036',
#  ' 355 West 46th Street, Theater District 10036',
#  ' 1 Front Street, Brooklyn 11201',
#  ' 32 Spring Street, New York 10012',
#  ' 110 Waverly Pl, Greenwich Village 10011',
#  ' 260 W 44th Street, New York 10036',
#  ' One Fifth Avenue at 8th Street, Greenwich Village 10003',
#  ' 84 Stanton Street 10002',
#  ' 16th Street, New York 10003',
#  ' 377 Greenwich Street, New York 10013',
#  ' 170 Thompson Street, New York 10012',
#  ' 261 Moore Street, Brooklyn 11206',
#  ' 85 10th Avenue, Chelsea 10011',
#  ' 200 Fifth Avenue 10010',
#  ' 2725 86th Street 11223',
#  ' 200 West 44th Street, btwn Broadway & 8th Avenue 10036',
#  ' 355 West 46th Street, Theater District 10036',
#  ' 1 Front Street, Brooklyn 11201',
#  ' 32 Spring Street, New York 10012',
#  ' 110 Waverly Pl, Greenwich Village 10011',
#  ' 260 W 44th Street, New York 10036',
#  ' One Fifth Avenue at 8th Street, Greenwich Village 10003',
#  ' 84 Stanton Street 10002',
#  ' 16th Street, New York 10003',
#  ' 377 Greenwich Street, New York 10013',
#  ' 170 Thompson Street, New York 10012',
#  ' 261 Moore Street, Brooklyn 11206',
#  ' 85 10th Avenue, Chelsea 10011',
#  ' 200 Fifth Avenue 10010',
#  ' 2725 86th Street 11223',
#  ' 200 West 44th Street, btwn Broadway & 8th Avenue 10036',
#  ' 355 West 46th Street, Theater District 10036',
#  ' 1 Front Street, Brooklyn 11201',
#  ' 32 Spring Street, New York 10012',
#  ' 110 Waverly Pl, Greenwich Village 10011',
#  ' 260 W 44th Street, New York 10036',
#  ' One Fifth Avenue at 8th Street, Greenwich Village 10003',
#  ' 84 Stanton Street 10002',
#  ' 16th Street, New York 10003',
#  ' 377 Greenwich Street, New York 10013',
#  ' 170 Thompson Street, New York 10012',
#  ' 261 Moore Street, Brooklyn 11206',
#  ' 85 10th Avenue, Chelsea 10011',
#  ' 200 Fifth Avenue 10010',
#  ' 2725 86th Street 11223',
#  ' 200 West 44th Street, btwn Broadway & 8th Avenue 10036',
#  ' 355 West 46th Street, Theater District 10036',
#  ' 1 Front Street, Brooklyn 11201',
#  ' 32 Spring Street, New York 10012',
#  ' 110 Waverly Pl, Greenwich Village 10011',
#  ' 260 W 44th Street, New York 10036',
#  ' One Fifth Avenue at 8th Street, Greenwich Village 10003',
#  ' 84 Stanton Street 10002',
#  ' 16th Street, New York 10003',
#  ' 377 Greenwich Street, New York 10013',
#  ' 170 Thompson Street, New York 10012',
#  ' 261 Moore Street, Brooklyn 11206',
#  ' 85 10th Avenue, Chelsea 10011',
#  ' 200 Fifth Avenue 10010',
#  ' 2725 86th Street 11223',
#  ' 200 West 44th Street, btwn Broadway & 8th Avenue 10036',
#  ' 355 West 46th Street, Theater District 10036',
#  ' 1 Front Street, Brooklyn 11201',
#  ' 32 Spring Street, New York 10012',
#  ' 110 Waverly Pl, Greenwich Village 10011',
#  ' 260 W 44th Street, New York 10036',
#  ' One Fifth Avenue at 8th Street, Greenwich Village 10003',
#  ' 84 Stanton Street 10002',
#  ' 16th Street, New York 10003',
#  ' 377 Greenwich Street, New York 10013',
#  ' 170 Thompson Street, New York 10012',
#  ' 261 Moore Street, Brooklyn 11206',
#  ' 85 10th Avenue, Chelsea 10011',
#  ' 200 Fifth Avenue 10010',
#  ' 2725 86th Street 11223',
#  ' 200 West 44th Street, btwn Broadway & 8th Avenue 10036',
#  ' 355 West 46th Street, Theater District 10036',
#  ' 1 Front Street, Brooklyn 11201',
#  ' 32 Spring Street, New York 10012',
#  ' 110 Waverly Pl, Greenwich Village 10011',
#  ' 260 W 44th Street, New York 10036',
#  ' One Fifth Avenue at 8th Street, Greenwich Village 10003',
#  ' 84 Stanton Street 10002',
#  ' 16th Street, New York 10003',
#  ' 377 Greenwich Street, New York 10013',
#  ' 170 Thompson Street, New York 10012',
#  ' 261 Moore Street, Brooklyn 11206',
#  ' 85 10th Avenue, Chelsea 10011',
#  ' 200 Fifth Avenue 10010',
#  ' 2725 86th Street 11223',
#  ' 200 West 44th Street, btwn Broadway & 8th Avenue 10036',
#  ' 355 West 46th Street, Theater District 10036',
#  ' 1 Front Street, Brooklyn 11201',
#  ' 32 Spring Street, New York 10012',
#  ' 110 Waverly Pl, Greenwich Village 10011',
#  ' 260 W 44th Street, New York 10036',
#  ' One Fifth Avenue at 8th Street, Greenwich Village 10003',
#  ' 84 Stanton Street 10002',
#  ' 16th Street, New York 10003',
#  ' 377 Greenwich Street, New York 10013',
#  ' 170 Thompson Street, New York 10012',
#  ' 261 Moore Street, Brooklyn 11206',
#  ' 85 10th Avenue, Chelsea 10011',
#  ' 200 Fifth Avenue 10010',
#  ' 2725 86th Street 11223',
#  ' 200 West 44th Street, btwn Broadway & 8th Avenue 10036',
#  ' 355 West 46th Street, Theater District 10036',
#  ' 1 Front Street, Brooklyn 11201',
#  ' 32 Spring Street, New York 10012',
#  ' 110 Waverly Pl, Greenwich Village 10011',
#  ' 260 W 44th Street, New York 10036',
#  ' One Fifth Avenue at 8th Street, Greenwich Village 10003',
#  ' 84 Stanton Street 10002',
#  ' 16th Street, New York 10003',
#  ' 377 Greenwich Street, New York 10013',
#  ' 170 Thompson Street, New York 10012',
#  ' 261 Moore Street, Brooklyn 11206',
#  ' 85 10th Avenue, Chelsea 10011',
#  ' 200 Fifth Avenue 10010',
#  ' 2725 86th Street 11223',
#  ' 200 West 44th Street, btwn Broadway & 8th Avenue 10036',
#  ' 355 West 46th Street, Theater District 10036',
#  ' 1 Front Street, Brooklyn 11201',
#  ' 32 Spring Street, New York 10012',
#  ' 110 Waverly Pl, Greenwich Village 10011',
#  ' 260 W 44th Street, New York 10036',
#  ' One Fifth Avenue at 8th Street, Greenwich Village 10003',
#  ' 84 Stanton Street 10002',
#  ' 16th Street, New York 10003',
#  ' 377 Greenwich Street, New York 10013',
#  ' 170 Thompson Street, New York 10012',
#  ' 261 Moore Street, Brooklyn 11206',
#  ' 85 10th Avenue, Chelsea 10011',
#  ' 200 Fifth Avenue 10010',
#  ' 2725 86th Street 11223',
#  ' 200 West 44th Street, btwn Broadway & 8th Avenue 10036',
#  ' 355 West 46th Street, Theater District 10036',
#  ' 1 Front Street, Brooklyn 11201',
#  ' 32 Spring Street, New York 10012',
#  ' 110 Waverly Pl, Greenwich Village 10011',
#  ' 260 W 44th Street, New York 10036',
#  ' One Fifth Avenue at 8th Street, Greenwich Village 10003',
#  ' 84 Stanton Street 10002',
#  ' 16th Street, New York 10003',
#  ' 377 Greenwich Street, New York 10013',
#  ' 170 Thompson Street, New York 10012',
#  ' 261 Moore Street, Brooklyn 11206',
#  ' 85 10th Avenue, Chelsea 10011',
#  ' 200 Fifth Avenue 10010',
#  ' 2725 86th Street 11223',
#  ' 200 West 44th Street, btwn Broadway & 8th Avenue 10036',
#  ' 355 West 46th Street, Theater District 10036',
#  ' 1 Front Street, Brooklyn 11201',
#  ' 32 Spring Street, New York 10012',
#  ' 110 Waverly Pl, Greenwich Village 10011',
#  ' 260 W 44th Street, New York 10036',
#  ' One Fifth Avenue at 8th Street, Greenwich Village 10003',
#  ' 84 Stanton Street 10002',
#  ' 16th Street, New York 10003',
#  ' 377 Greenwich Street, New York 10013',
#  ' 170 Thompson Street, New York 10012',
#  ' 261 Moore Street, Brooklyn 11206',
#  ' 85 10th Avenue, Chelsea 10011',
#  ' 200 Fifth Avenue 10010',
#  ' 2725 86th Street 11223',
#  ' 200 West 44th Street, btwn Broadway & 8th Avenue 10036',
#  ' 355 West 46th Street, Theater District 10036',
#  ' 1 Front Street, Brooklyn 11201',
#  ' 32 Spring Street, New York 10012',
#  ' 110 Waverly Pl, Greenwich Village 10011',
#  ' 260 W 44th Street, New York 10036',
#  ' One Fifth Avenue at 8th Street, Greenwich Village 10003',
#  ' 84 Stanton Street 10002',
#  ' 16th Street, New York 10003',
#  ' 377 Greenwich Street, New York 10013',
#  ' 170 Thompson Street, New York 10012',
#  ' 261 Moore Street, Brooklyn 11206',
#  ' 85 10th Avenue, Chelsea 10011',
#  ' 200 Fifth Avenue 10010',
#  ' 2725 86th Street 11223',
#  ' 200 West 44th Street, btwn Broadway & 8th Avenue 10036',
#  ' 355 West 46th Street, Theater District 10036',
#  ' 1 Front Street, Brooklyn 11201',
#  ' 32 Spring Street, New York 10012',
#  ' 110 Waverly Pl, Greenwich Village 10011',
#  ' 260 W 44th Street, New York 10036',
#  ' One Fifth Avenue at 8th Street, Greenwich Village 10003',
#  ' 84 Stanton Street 10002',
#  ' 16th Street, New York 10003',
#  ' 377 Greenwich Street, New York 10013',
#  ' 170 Thompson Street, New York 10012',
#  ' 261 Moore Street, Brooklyn 11206',
#  ' 85 10th Avenue, Chelsea 10011',
#  ' 200 Fifth Avenue 10010',
#  ' 2725 86th Street 11223',
#  ' 200 West 44th Street, btwn Broadway & 8th Avenue 10036',
#  ' 355 West 46th Street, Theater District 10036',
#  ' 1 Front Street, Brooklyn 11201',
#  ' 32 Spring Street, New York 10012',
#  ' 110 Waverly Pl, Greenwich Village 10011',
#  ' 260 W 44th Street, New York 10036',
#  ' One Fifth Avenue at 8th Street, Greenwich Village 10003',
#  ' 84 Stanton Street 10002',
#  ' 16th Street, New York 10003',
#  ' 377 Greenwich Street, New York 10013',
#  ' 170 Thompson Street, New York 10012',
#  ' 261 Moore Street, Brooklyn 11206',
#  ' 85 10th Avenue, Chelsea 10011',
#  ' 200 Fifth Avenue 10010',
#  ' 2725 86th Street 11223',
#  ' 200 West 44th Street, btwn Broadway & 8th Avenue 10036',
#  ' 355 West 46th Street, Theater District 10036',
#  ' 1 Front Street, Brooklyn 11201',
#  ' 32 Spring Street, New York 10012',
#  ' 110 Waverly Pl, Greenwich Village 10011',
#  ' 260 W 44th Street, New York 10036',
#  ' One Fifth Avenue at 8th Street, Greenwich Village 10003',
#  ' 84 Stanton Street 10002',
#  ' 16th Street, New York 10003',
#  ' 377 Greenwich Street, New York 10013',
#  ' 170 Thompson Street, New York 10012',
#  ' 261 Moore Street, Brooklyn 11206',
#  ' 85 10th Avenue, Chelsea 10011',
#  ' 200 Fifth Avenue 10010',
#  ' 2725 86th Street 11223',
#  ' 200 West 44th Street, btwn Broadway & 8th Avenue 10036',
#  ' 355 West 46th Street, Theater District 10036',
#  ' 1 Front Street, Brooklyn 11201',
#  ' 32 Spring Street, New York 10012',
#  ' 110 Waverly Pl, Greenwich Village 10011',
#  ' 260 W 44th Street, New York 10036',
#  ' One Fifth Avenue at 8th Street, Greenwich Village 10003',
#  ' 84 Stanton Street 10002',
#  ' 16th Street, New York 10003',
#  ' 377 Greenwich Street, New York 10013',
#  ' 170 Thompson Street, New York 10012',
#  ' 261 Moore Street, Brooklyn 11206',
#  ' 85 10th Avenue, Chelsea 10011',
#  ' 200 Fifth Avenue 10010',
#  ' 2725 86th Street 11223']

# %%
votes
# Out:
# ['1043 votes',
#  ',',
#  '935 votes',
#  '1444 votes',
#  '835 votes',
#  '714 votes',
#  '569 votes',
#  '393 votes',
#  ',',
#  '361 votes',
#  '410 votes',
#  ',',
#  '285 votes',
#  '171 votes',
#  '289 votes',
#  '1043 votes',
#  ',',
#  '935 votes',
#  '1444 votes',
#  '835 votes',
#  '714 votes',
#  '569 votes',
#  '393 votes',
#  ',',
#  '361 votes',
#  '410 votes',
#  ',',
#  '285 votes',
#  '171 votes',
#  '289 votes',
#  '1043 votes',
#  ',',
#  '935 votes',
#  '1444 votes',
#  '835 votes',
#  '714 votes',
#  '569 votes',
#  '393 votes',
#  ',',
#  '361 votes',
#  '410 votes',
#  ',',
#  '285 votes',
#  '171 votes',
#  '289 votes',
#  '1043 votes',
#  ',',
#  '935 votes',
#  '1444 votes',
#  '835 votes',
#  '714 votes',
#  '569 votes',
#  '393 votes',
#  ',',
#  '361 votes',
#  '410 votes',
#  ',',
#  '285 votes',
#  '171 votes',
#  '289 votes',
#  '1043 votes',
#  ',',
#  '935 votes',
#  '1444 votes',
#  '835 votes',
#  '714 votes',
#  '569 votes',
#  '393 votes',
#  ',',
#  '361 votes',
#  '410 votes',
#  ',',
#  '285 votes',
#  '171 votes',
#  '289 votes',
#  '1043 votes',
#  ',',
#  '935 votes',
#  '1444 votes',
#  '835 votes',
#  '714 votes',
#  '569 votes',
#  '393 votes',
#  ',',
#  '361 votes',
#  '410 votes',
#  ',',
#  '285 votes',
#  '171 votes',
#  '289 votes',
#  '1043 votes',
#  ',',
#  '935 votes',
#  '1444 votes',
#  '835 votes',
#  '714 votes',
#  '569 votes',
#  '393 votes',
#  ',',
#  '361 votes',
#  '410 votes',
#  ',',
#  '285 votes',
#  '171 votes',
#  '289 votes',
#  '1043 votes',
#  ',',
#  '935 votes',
#  '1444 votes',
#  '835 votes',
#  '714 votes',
#  '569 votes',
#  '393 votes',
#  ',',
#  '361 votes',
#  '410 votes',
#  ',',
#  '285 votes',
#  '171 votes',
#  '289 votes',
#  '1043 votes',
#  ',',
#  '935 votes',
#  '1444 votes',
#  '835 votes',
#  '714 votes',
#  '569 votes',
#  '393 votes',
#  ',',
#  '361 votes',
#  '410 votes',
#  ',',
#  '285 votes',
#  '171 votes',
#  '289 votes',
#  '1043 votes',
#  ',',
#  '935 votes',
#  '1444 votes',
#  '835 votes',
#  '714 votes',
#  '569 votes',
#  '393 votes',
#  ',',
#  '361 votes',
#  '410 votes',
#  ',',
#  '285 votes',
#  '171 votes',
#  '289 votes',
#  '1043 votes',
#  ',',
#  '935 votes',
#  '1444 votes',
#  '835 votes',
#  '714 votes',
#  '569 votes',
#  '393 votes',
#  ',',
#  '361 votes',
#  '410 votes',
#  ',',
#  '285 votes',
#  '171 votes',
#  '289 votes',
#  '1043 votes',
#  ',',
#  '935 votes',
#  '1444 votes',
#  '835 votes',
#  '714 votes',
#  '569 votes',
#  '393 votes',
#  ',',
#  '361 votes',
#  '410 votes',
#  ',',
#  '285 votes',
#  '171 votes',
#  '289 votes',
#  '1043 votes',
#  ',',
#  '935 votes',
#  '1444 votes',
#  '835 votes',
#  '714 votes',
#  '569 votes',
#  '393 votes',
#  ',',
#  '361 votes',
#  '410 votes',
#  ',',
#  '285 votes',
#  '171 votes',
#  '289 votes',
#  '1043 votes',
#  ',',
#  '935 votes',
#  '1444 votes',
#  '835 votes',
#  '714 votes',
#  '569 votes',
#  '393 votes',
#  ',',
#  '361 votes',
#  '410 votes',
#  ',',
#  '285 votes',
#  '171 votes',
#  '289 votes',
#  '1043 votes',
#  ',',
#  '935 votes',
#  '1444 votes',
#  '835 votes',
#  '714 votes',
#  '569 votes',
#  '393 votes',
#  ',',
#  '361 votes',
#  '410 votes',
#  ',',
#  '285 votes',
#  '171 votes',
#  '289 votes',
#  '1043 votes',
#  ',',
#  '935 votes',
#  '1444 votes',
#  '835 votes',
#  '714 votes',
#  '569 votes',
#  '393 votes',
#  ',',
#  '361 votes',
#  '410 votes',
#  ',',
#  '285 votes',
#  '171 votes',
#  '289 votes',
#  '1043 votes',
#  ',',
#  '935 votes',
#  '1444 votes',
#  '835 votes',
#  '714 votes',
#  '569 votes',
#  '393 votes',
#  ',',
#  '361 votes',
#  '410 votes',
#  ',',
#  '285 votes',
#  '171 votes',
#  '289 votes',
#  '1043 votes',
#  ',',
#  '935 votes',
#  '1444 votes',
#  '835 votes',
#  '714 votes',
#  '569 votes',
#  '393 votes',
#  ',',
#  '361 votes',
#  '410 votes',
#  ',',
#  '285 votes',
#  '171 votes',
#  '289 votes',
#  '1043 votes',
#  ',',
#  '935 votes',
#  '1444 votes',
#  '835 votes',
#  '714 votes',
#  '569 votes',
#  '393 votes',
#  ',',
#  '361 votes',
#  '410 votes',
#  ',',
#  '285 votes',
#  '171 votes',
#  '289 votes',
#  '1043 votes',
#  ',',
#  '935 votes',
#  '1444 votes',
#  '835 votes',
#  '714 votes',
#  '569 votes',
#  '393 votes',
#  ',',
#  '361 votes',
#  '410 votes',
#  ',',
#  '285 votes',
#  '171 votes',
#  '289 votes',
#  '1043 votes',
#  ',',
#  '935 votes',
#  '1444 votes',
#  '835 votes',
#  '714 votes',
#  '569 votes',
#  '393 votes',
#  ',',
#  '361 votes',
#  '410 votes',
#  ',',
#  '285 votes',
#  '171 votes',
#  '289 votes',
#  '1043 votes',
#  ',',
#  '935 votes',
#  '1444 votes',
#  '835 votes',
#  '714 votes',
#  '569 votes',
#  '393 votes',
#  ',',
#  '361 votes',
#  '410 votes',
#  ',',
#  '285 votes',
#  '171 votes',
#  '289 votes',
#  '1043 votes',
#  ',',
#  '935 votes',
#  '1444 votes',
#  '835 votes',
#  '714 votes',
#  '569 votes',
#  '393 votes',
#  ',',
#  '361 votes',
#  '410 votes',
#  ',',
#  '285 votes',
#  '171 votes',
#  '289 votes',
#  '1043 votes',
#  ',',
#  '935 votes',
#  '1444 votes',
#  '835 votes',
#  '714 votes',
#  '569 votes',
#  '393 votes',
#  ',',
#  '361 votes',
#  '410 votes',
#  ',',
#  '285 votes',
#  '171 votes',
#  '289 votes',
#  '1043 votes',
#  ',',
#  '935 votes',
#  '1444 votes',
#  '835 votes',
#  '714 votes',
#  '569 votes',
#  '393 votes',
#  ',',
#  '361 votes',
#  '410 votes',
#  ',',
#  '285 votes',
#  '171 votes',
#  '289 votes',
#  '1043 votes',
#  ',',
#  '935 votes',
#  '1444 votes',
#  '835 votes',
#  '714 votes',
#  '569 votes',
#  '393 votes',
#  ',',
#  '361 votes',
#  '410 votes',
#  ',',
#  '285 votes',
#  '171 votes',
#  '289 votes',
#  '1043 votes',
#  ',',
#  '935 votes',
#  '1444 votes',
#  '835 votes',
#  '714 votes',
#  '569 votes',
#  '393 votes',
#  ',',
#  '361 votes',
#  '410 votes',
#  ',',
#  '285 votes',
#  '171 votes',
#  '289 votes',
#  '1043 votes',
#  ',',
#  '935 votes',
#  '1444 votes',
#  '835 votes',
#  '714 votes',
#  '569 votes',
#  '393 votes',
#  ',',
#  '361 votes',
#  '410 votes',
#  ',',
#  '285 votes',
#  '171 votes',
#  '289 votes',
#  '1043 votes',
#  ',',
#  '935 votes',
#  '1444 votes',
#  '835 votes',
#  '714 votes',
#  '569 votes',
#  '393 votes',
#  ',',
#  '361 votes',
#  '410 votes',
#  ',',
#  '285 votes',
#  '171 votes',
#  '289 votes']

# %%
ratings
# Out:
# ['\n                                        4.8\n                                    ',
#  '\n                                        4.7\n                                    ',
#  '\n                                        4.7\n                                    ',
#  '\n                                        4.9\n                                    ',
#  '\n                                        4.6\n                                    ',
#  '\n                                        4.7\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.6\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.6\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.8\n                                    ',
#  '\n                                        4.7\n                                    ',
#  '\n                                        4.7\n                                    ',
#  '\n                                        4.9\n                                    ',
#  '\n                                        4.6\n                                    ',
#  '\n                                        4.7\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.6\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.6\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.8\n                                    ',
#  '\n                                        4.7\n                                    ',
#  '\n                                        4.7\n                                    ',
#  '\n                                        4.9\n                                    ',
#  '\n                                        4.6\n                                    ',
#  '\n                                        4.7\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.6\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.6\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.8\n                                    ',
#  '\n                                        4.7\n                                    ',
#  '\n                                        4.7\n                                    ',
#  '\n                                        4.9\n                                    ',
#  '\n                                        4.6\n                                    ',
#  '\n                                        4.7\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.6\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.6\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.8\n                                    ',
#  '\n                                        4.7\n                                    ',
#  '\n                                        4.7\n                                    ',
#  '\n                                        4.9\n                                    ',
#  '\n                                        4.6\n                                    ',
#  '\n                                        4.7\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.6\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.6\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.8\n                                    ',
#  '\n                                        4.7\n                                    ',
#  '\n                                        4.7\n                                    ',
#  '\n                                        4.9\n                                    ',
#  '\n                                        4.6\n                                    ',
#  '\n                                        4.7\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.6\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.6\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.8\n                                    ',
#  '\n                                        4.7\n                                    ',
#  '\n                                        4.7\n                                    ',
#  '\n                                        4.9\n                                    ',
#  '\n                                        4.6\n                                    ',
#  '\n                                        4.7\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.6\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.6\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.8\n                                    ',
#  '\n                                        4.7\n                                    ',
#  '\n                                        4.7\n                                    ',
#  '\n                                        4.9\n                                    ',
#  '\n                                        4.6\n                                    ',
#  '\n                                        4.7\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.6\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.6\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.8\n                                    ',
#  '\n                                        4.7\n                                    ',
#  '\n                                        4.7\n                                    ',
#  '\n                                        4.9\n                                    ',
#  '\n                                        4.6\n                                    ',
#  '\n                                        4.7\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.6\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.6\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.8\n                                    ',
#  '\n                                        4.7\n                                    ',
#  '\n                                        4.7\n                                    ',
#  '\n                                        4.9\n                                    ',
#  '\n                                        4.6\n                                    ',
#  '\n                                        4.7\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.6\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.6\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.8\n                                    ',
#  '\n                                        4.7\n                                    ',
#  '\n                                        4.7\n                                    ',
#  '\n                                        4.9\n                                    ',
#  '\n                                        4.6\n                                    ',
#  '\n                                        4.7\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.6\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.6\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.8\n                                    ',
#  '\n                                        4.7\n                                    ',
#  '\n                                        4.7\n                                    ',
#  '\n                                        4.9\n                                    ',
#  '\n                                        4.6\n                                    ',
#  '\n                                        4.7\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.6\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.6\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.8\n                                    ',
#  '\n                                        4.7\n                                    ',
#  '\n                                        4.7\n                                    ',
#  '\n                                        4.9\n                                    ',
#  '\n                                        4.6\n                                    ',
#  '\n                                        4.7\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.6\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.6\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.8\n                                    ',
#  '\n                                        4.7\n                                    ',
#  '\n                                        4.7\n                                    ',
#  '\n                                        4.9\n                                    ',
#  '\n                                        4.6\n                                    ',
#  '\n                                        4.7\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.6\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.6\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.8\n                                    ',
#  '\n                                        4.7\n                                    ',
#  '\n                                        4.7\n                                    ',
#  '\n                                        4.9\n                                    ',
#  '\n                                        4.6\n                                    ',
#  '\n                                        4.7\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.6\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.6\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.8\n                                    ',
#  '\n                                        4.7\n                                    ',
#  '\n                                        4.7\n                                    ',
#  '\n                                        4.9\n                                    ',
#  '\n                                        4.6\n                                    ',
#  '\n                                        4.7\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.6\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.6\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.8\n                                    ',
#  '\n                                        4.7\n                                    ',
#  '\n                                        4.7\n                                    ',
#  '\n                                        4.9\n                                    ',
#  '\n                                        4.6\n                                    ',
#  '\n                                        4.7\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.6\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.6\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.8\n                                    ',
#  '\n                                        4.7\n                                    ',
#  '\n                                        4.7\n                                    ',
#  '\n                                        4.9\n                                    ',
#  '\n                                        4.6\n                                    ',
#  '\n                                        4.7\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.6\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.6\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.8\n                                    ',
#  '\n                                        4.7\n                                    ',
#  '\n                                        4.7\n                                    ',
#  '\n                                        4.9\n                                    ',
#  '\n                                        4.6\n                                    ',
#  '\n                                        4.7\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.6\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.6\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.8\n                                    ',
#  '\n                                        4.7\n                                    ',
#  '\n                                        4.7\n                                    ',
#  '\n                                        4.9\n                                    ',
#  '\n                                        4.6\n                                    ',
#  '\n                                        4.7\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.6\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.6\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.8\n                                    ',
#  '\n                                        4.7\n                                    ',
#  '\n                                        4.7\n                                    ',
#  '\n                                        4.9\n                                    ',
#  '\n                                        4.6\n                                    ',
#  '\n                                        4.7\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.6\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.6\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.8\n                                    ',
#  '\n                                        4.7\n                                    ',
#  '\n                                        4.7\n                                    ',
#  '\n                                        4.9\n                                    ',
#  '\n                                        4.6\n                                    ',
#  '\n                                        4.7\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.6\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.6\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.8\n                                    ',
#  '\n                                        4.7\n                                    ',
#  '\n                                        4.7\n                                    ',
#  '\n                                        4.9\n                                    ',
#  '\n                                        4.6\n                                    ',
#  '\n                                        4.7\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.6\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.6\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.8\n                                    ',
#  '\n                                        4.7\n                                    ',
#  '\n                                        4.7\n                                    ',
#  '\n                                        4.9\n                                    ',
#  '\n                                        4.6\n                                    ',
#  '\n                                        4.7\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.6\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.6\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.8\n                                    ',
#  '\n                                        4.7\n                                    ',
#  '\n                                        4.7\n                                    ',
#  '\n                                        4.9\n                                    ',
#  '\n                                        4.6\n                                    ',
#  '\n                                        4.7\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.6\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.6\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.8\n                                    ',
#  '\n                                        4.7\n                                    ',
#  '\n                                        4.7\n                                    ',
#  '\n                                        4.9\n                                    ',
#  '\n                                        4.6\n                                    ',
#  '\n                                        4.7\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.6\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.6\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.8\n                                    ',
#  '\n                                        4.7\n                                    ',
#  '\n                                        4.7\n                                    ',
#  '\n                                        4.9\n                                    ',
#  '\n                                        4.6\n                                    ',
#  '\n                                        4.7\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.6\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.6\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.8\n                                    ',
#  '\n                                        4.7\n                                    ',
#  '\n                                        4.7\n                                    ',
#  '\n                                        4.9\n                                    ',
#  '\n                                        4.6\n                                    ',
#  '\n                                        4.7\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.6\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.6\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.8\n                                    ',
#  '\n                                        4.7\n                                    ',
#  '\n                                        4.7\n                                    ',
#  '\n                                        4.9\n                                    ',
#  '\n                                        4.6\n                                    ',
#  '\n                                        4.7\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.6\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.6\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.5\n                                    ']

# %%
df_restaurant_NewYork_IT=pd.DataFrame({'Name': restaurant_name,
                                 'Address':restaurant_address,
                                 'Votes': votes,
                                 'Rating': ratings,'cost':costs})
df_restaurant_NewYork_IT
# Out:
#                                                   Name  \
# 0    Carmine's Italian Restaurant\n                ...
# 1          Becco\n
# 2    Grimaldi's Pizzeria\n                         ...
# 3    Lombardi's Pizza\n                            ...
# 4          Babbo\n
# ..                                                 ...
# 430  Lupa Osteria Romana\n                         ...
# 431    Roberta's\n
# 432    Del Posto\n
# 433  La Birreria\n
# 434  L & B Spumoni Gardens\n                       ...
#
#                                                Address       Votes  \
# 0     200 West 44th Street, btwn Broadway & 8th Ave...  1043 votes
# 1         355 West 46th Street, Theater District 10036           ,
# 2                       1 Front Street, Brooklyn 11201   935 votes
# 3                     32 Spring Street, New York 10012  1444 votes
# 4              110 Waverly Pl, Greenwich Village 10011   835 votes
# ..                                                 ...         ...
# 430                170 Thompson Street, New York 10012   410 votes
# 431                   261 Moore Street, Brooklyn 11206           ,
# 432                      85 10th Avenue, Chelsea 10011   285 votes
# 433                             200 Fifth Avenue 10010   171 votes
# 434                             2725 86th Street 11223   289 votes
#
#                                                 Rating               cost
# 0    \n                                        4.8\...  Cost for two:$100
# 1    \n                                        4.7\...  Cost for two:$110
# 2    \n                                        4.7\...   Cost for two:$50
# 3    \n                                        4.9\...   Cost for two:$50
# 4    \n                                        4.6\...  Cost for two:$150
# ..                                                 ...                ...
# 430  \n                                        4.5\...  Cost for two:$100
# 431  \n                                        4.6\...   Cost for two:$50
# 432  \n                                        4.4\...  Cost for two:$250
# 433  \n                                        4.4\...   Cost for two:$80
# 434  \n                                        4.5\...   Cost for two:$75
#
# [435 rows x 5 columns]

# %%
#### Save raw data to csv
df_restaurant_NewYork_IT.to_csv('df_restaurant_NewYork_IT_raw_EO.csv',index=False)
