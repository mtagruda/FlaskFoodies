# %%
# scrape 
from bs4 import BeautifulSoup
from bs4 import BeautifulSoup as bs
from splinter import Browser
from splinter.exceptions import ElementDoesNotExist
import requests
import pandas as pd
import time

# %% [markdown]
# <h1># Windows Users</h1>

# %%
#Set the chromedriver path
executable_path = {"executable_path": "/users/evaeb/bin/chromedriver"}
browser = Browser("chrome", **executable_path, headless=False)

# %%
# Scrap Italian restaurants in New York
#url = 'https://www.zomato.com/houston/restaurants/italian'
n = 1
restaurant_name=[]
restaurant_address=[]
votes=[]
ratings=[]
costs=[]

for x in range(1, 30):
    url = f'https://www.zomato.com/houston/restaurants/italian?page={n}'
    browser.visit(url)

    html = browser.html
    soup = bs(html, 'html.parser')
    restaurant_info = soup.find_all(class_='content')
    
    for restaurant in restaurant_info:
        try:
            rest_name= restaurant.find('a', class_='result-title').text     
            rest_address= restaurant.find(class_='search-result-address').text
            vote= restaurant.find('span').text
            rating= restaurant.find(class_='rating-popup').text
            cost= restaurant.find(class_="res-cost").text
            
                  
            restaurant_name.append(rest_name)
            restaurant_address.append(rest_address)
            votes.append(vote)
            ratings.append(rating)
            costs.append(cost)
            
        except:
            print("Not Available")
              
        
#         print(rest_name)
#         print(rest_address)
#         print(vote)
#         print(rating)
        n += 1
# Out:
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available

# %%
restaurant_name
# Out:
# ['Star Pizza\n                                    ',
#  "Maggiano's Little Italy\n                                    ",
#  'Santa Barbara Italian Cafe\n                                    ',
#  "Italiano's\n                                    ",
#  "Grimaldi's Pizzeria\n                                    ",
#  'Prego Italian Cuisine\n                                    ',
#  'BRIO Tuscan Grille - Woodlands - The Woodlands\n                                    ',
#  "D'Amico's Italian Market Cafe\n                                    ",
#  'Da Vinci Ristorante Italiano\n                                    ',
#  "Dan's Pizza Co.\n                                    ",
#  'La Griglia\n                                    ',
#  "Carrabba's\n                                    ",
#  "Barry's Pizza and Italian Diner\n                                    ",
#  'Via Emilia\n                                    ',
#  'MidiCi\n                                    ',
#  'Brothers Pizzeria\n                                    ',
#  'The Italian Joint\n                                    ',
#  'Enoteca Rossa\n                                    ',
#  'Papa Amadeus\n                                    ',
#  'Amici Ristorante Italiano\n                                    ',
#  "Mario's Italian\n                                    ",
#  "Carmine's Italian Restaurant\n                                    ",
#  'Wine Cellar & Mezza Bar\n                                    ',
#  'Mona Fresh Italian\n                                    ',
#  'Tosca Americana\n                                    ',
#  'La Fresca Pizza\n                                    ',
#  'Cicis Pizza\n                                    ',
#  "Domino's Pizza\n                                    ",
#  'Peter Piper Pizza\n                                    ',
#  'Shiloh Club\n                                    ',
#  "People's Choice Pizza\n                                    ",
#  'Houston Pizza Venture\n                                    ',
#  "Marco's Pizza\n                                    ",
#  'Pizza Fire\n                                    ',
#  "Big Ben's Pizzeria\n                                    ",
#  "Pizzaiolo's Gourmet Pizza\n                                    ",
#  'Il Primo Pizza and Wings II\n                                    ',
#  'Pizza Hut\n                                    ',
#  'Giannina’s Pizza\n                                    ',
#  'Star Pizza\n                                    ',
#  "Maggiano's Little Italy\n                                    ",
#  'Santa Barbara Italian Cafe\n                                    ',
#  "Italiano's\n                                    ",
#  "Grimaldi's Pizzeria\n                                    ",
#  'Prego Italian Cuisine\n                                    ',
#  'BRIO Tuscan Grille - Woodlands - The Woodlands\n                                    ',
#  "D'Amico's Italian Market Cafe\n                                    ",
#  'Da Vinci Ristorante Italiano\n                                    ',
#  "Dan's Pizza Co.\n                                    ",
#  'La Griglia\n                                    ',
#  "Carrabba's\n                                    ",
#  "Barry's Pizza and Italian Diner\n                                    ",
#  'Via Emilia\n                                    ',
#  'Star Pizza\n                                    ',
#  "Maggiano's Little Italy\n                                    ",
#  'Santa Barbara Italian Cafe\n                                    ',
#  "Italiano's\n                                    ",
#  "Grimaldi's Pizzeria\n                                    ",
#  'Prego Italian Cuisine\n                                    ',
#  'BRIO Tuscan Grille - Woodlands - The Woodlands\n                                    ',
#  "D'Amico's Italian Market Cafe\n                                    ",
#  'Da Vinci Ristorante Italiano\n                                    ',
#  "Dan's Pizza Co.\n                                    ",
#  'La Griglia\n                                    ',
#  "Carrabba's\n                                    ",
#  "Barry's Pizza and Italian Diner\n                                    ",
#  'Via Emilia\n                                    ',
#  'Star Pizza\n                                    ',
#  "Maggiano's Little Italy\n                                    ",
#  'Santa Barbara Italian Cafe\n                                    ',
#  "Italiano's\n                                    ",
#  "Grimaldi's Pizzeria\n                                    ",
#  'Prego Italian Cuisine\n                                    ',
#  'BRIO Tuscan Grille - Woodlands - The Woodlands\n                                    ',
#  "D'Amico's Italian Market Cafe\n                                    ",
#  'Da Vinci Ristorante Italiano\n                                    ',
#  "Dan's Pizza Co.\n                                    ",
#  'La Griglia\n                                    ',
#  "Carrabba's\n                                    ",
#  "Barry's Pizza and Italian Diner\n                                    ",
#  'Via Emilia\n                                    ',
#  'Star Pizza\n                                    ',
#  "Maggiano's Little Italy\n                                    ",
#  'Santa Barbara Italian Cafe\n                                    ',
#  "Italiano's\n                                    ",
#  "Grimaldi's Pizzeria\n                                    ",
#  'Prego Italian Cuisine\n                                    ',
#  'BRIO Tuscan Grille - Woodlands - The Woodlands\n                                    ',
#  "D'Amico's Italian Market Cafe\n                                    ",
#  'Da Vinci Ristorante Italiano\n                                    ',
#  "Dan's Pizza Co.\n                                    ",
#  'La Griglia\n                                    ',
#  "Carrabba's\n                                    ",
#  "Barry's Pizza and Italian Diner\n                                    ",
#  'Via Emilia\n                                    ',
#  'Star Pizza\n                                    ',
#  "Maggiano's Little Italy\n                                    ",
#  'Santa Barbara Italian Cafe\n                                    ',
#  "Italiano's\n                                    ",
#  "Grimaldi's Pizzeria\n                                    ",
#  'Prego Italian Cuisine\n                                    ',
#  'BRIO Tuscan Grille - Woodlands - The Woodlands\n                                    ',
#  "D'Amico's Italian Market Cafe\n                                    ",
#  'Da Vinci Ristorante Italiano\n                                    ',
#  "Dan's Pizza Co.\n                                    ",
#  'La Griglia\n                                    ',
#  "Carrabba's\n                                    ",
#  "Barry's Pizza and Italian Diner\n                                    ",
#  'Via Emilia\n                                    ',
#  'Star Pizza\n                                    ',
#  "Maggiano's Little Italy\n                                    ",
#  'Santa Barbara Italian Cafe\n                                    ',
#  "Italiano's\n                                    ",
#  "Grimaldi's Pizzeria\n                                    ",
#  'Prego Italian Cuisine\n                                    ',
#  'BRIO Tuscan Grille - Woodlands - The Woodlands\n                                    ',
#  "D'Amico's Italian Market Cafe\n                                    ",
#  'Da Vinci Ristorante Italiano\n                                    ',
#  "Dan's Pizza Co.\n                                    ",
#  'La Griglia\n                                    ',
#  "Carrabba's\n                                    ",
#  "Barry's Pizza and Italian Diner\n                                    ",
#  'Via Emilia\n                                    ',
#  'Star Pizza\n                                    ',
#  "Maggiano's Little Italy\n                                    ",
#  'Santa Barbara Italian Cafe\n                                    ',
#  "Italiano's\n                                    ",
#  "Grimaldi's Pizzeria\n                                    ",
#  'Prego Italian Cuisine\n                                    ',
#  'BRIO Tuscan Grille - Woodlands - The Woodlands\n                                    ',
#  "D'Amico's Italian Market Cafe\n                                    ",
#  'Da Vinci Ristorante Italiano\n                                    ',
#  "Dan's Pizza Co.\n                                    ",
#  'La Griglia\n                                    ',
#  "Carrabba's\n                                    ",
#  "Barry's Pizza and Italian Diner\n                                    ",
#  'Via Emilia\n                                    ',
#  'Star Pizza\n                                    ',
#  "Maggiano's Little Italy\n                                    ",
#  'Santa Barbara Italian Cafe\n                                    ',
#  "Italiano's\n                                    ",
#  "Grimaldi's Pizzeria\n                                    ",
#  'Prego Italian Cuisine\n                                    ',
#  'BRIO Tuscan Grille - Woodlands - The Woodlands\n                                    ',
#  "D'Amico's Italian Market Cafe\n                                    ",
#  'Da Vinci Ristorante Italiano\n                                    ',
#  "Dan's Pizza Co.\n                                    ",
#  'La Griglia\n                                    ',
#  "Carrabba's\n                                    ",
#  "Barry's Pizza and Italian Diner\n                                    ",
#  'Via Emilia\n                                    ',
#  'Star Pizza\n                                    ',
#  "Maggiano's Little Italy\n                                    ",
#  'Santa Barbara Italian Cafe\n                                    ',
#  "Italiano's\n                                    ",
#  "Grimaldi's Pizzeria\n                                    ",
#  'Prego Italian Cuisine\n                                    ',
#  'BRIO Tuscan Grille - Woodlands - The Woodlands\n                                    ',
#  "D'Amico's Italian Market Cafe\n                                    ",
#  'Da Vinci Ristorante Italiano\n                                    ',
#  "Dan's Pizza Co.\n                                    ",
#  'La Griglia\n                                    ',
#  "Carrabba's\n                                    ",
#  "Barry's Pizza and Italian Diner\n                                    ",
#  'Via Emilia\n                                    ',
#  'Star Pizza\n                                    ',
#  "Maggiano's Little Italy\n                                    ",
#  'Santa Barbara Italian Cafe\n                                    ',
#  "Italiano's\n                                    ",
#  "Grimaldi's Pizzeria\n                                    ",
#  'Prego Italian Cuisine\n                                    ',
#  'BRIO Tuscan Grille - Woodlands - The Woodlands\n                                    ',
#  "D'Amico's Italian Market Cafe\n                                    ",
#  'Da Vinci Ristorante Italiano\n                                    ',
#  "Dan's Pizza Co.\n                                    ",
#  'La Griglia\n                                    ',
#  "Carrabba's\n                                    ",
#  "Barry's Pizza and Italian Diner\n                                    ",
#  'Via Emilia\n                                    ',
#  'Star Pizza\n                                    ',
#  "Maggiano's Little Italy\n                                    ",
#  'Santa Barbara Italian Cafe\n                                    ',
#  "Italiano's\n                                    ",
#  "Grimaldi's Pizzeria\n                                    ",
#  'Prego Italian Cuisine\n                                    ',
#  'BRIO Tuscan Grille - Woodlands - The Woodlands\n                                    ',
#  "D'Amico's Italian Market Cafe\n                                    ",
#  'Da Vinci Ristorante Italiano\n                                    ',
#  "Dan's Pizza Co.\n                                    ",
#  'La Griglia\n                                    ',
#  "Carrabba's\n                                    ",
#  "Barry's Pizza and Italian Diner\n                                    ",
#  'Via Emilia\n                                    ',
#  'Star Pizza\n                                    ',
#  "Maggiano's Little Italy\n                                    ",
#  'Santa Barbara Italian Cafe\n                                    ',
#  "Italiano's\n                                    ",
#  "Grimaldi's Pizzeria\n                                    ",
#  'Prego Italian Cuisine\n                                    ',
#  'BRIO Tuscan Grille - Woodlands - The Woodlands\n                                    ',
#  "D'Amico's Italian Market Cafe\n                                    ",
#  'Da Vinci Ristorante Italiano\n                                    ',
#  "Dan's Pizza Co.\n                                    ",
#  'La Griglia\n                                    ',
#  "Carrabba's\n                                    ",
#  "Barry's Pizza and Italian Diner\n                                    ",
#  'Via Emilia\n                                    ',
#  'Star Pizza\n                                    ',
#  "Maggiano's Little Italy\n                                    ",
#  'Santa Barbara Italian Cafe\n                                    ',
#  "Italiano's\n                                    ",
#  "Grimaldi's Pizzeria\n                                    ",
#  'Prego Italian Cuisine\n                                    ',
#  'BRIO Tuscan Grille - Woodlands - The Woodlands\n                                    ',
#  "D'Amico's Italian Market Cafe\n                                    ",
#  'Da Vinci Ristorante Italiano\n                                    ',
#  "Dan's Pizza Co.\n                                    ",
#  'La Griglia\n                                    ',
#  "Carrabba's\n                                    ",
#  "Barry's Pizza and Italian Diner\n                                    ",
#  'Via Emilia\n                                    ',
#  'Star Pizza\n                                    ',
#  "Maggiano's Little Italy\n                                    ",
#  'Santa Barbara Italian Cafe\n                                    ',
#  "Italiano's\n                                    ",
#  "Grimaldi's Pizzeria\n                                    ",
#  'Prego Italian Cuisine\n                                    ',
#  'BRIO Tuscan Grille - Woodlands - The Woodlands\n                                    ',
#  "D'Amico's Italian Market Cafe\n                                    ",
#  'Da Vinci Ristorante Italiano\n                                    ',
#  "Dan's Pizza Co.\n                                    ",
#  'La Griglia\n                                    ',
#  "Carrabba's\n                                    ",
#  "Barry's Pizza and Italian Diner\n                                    ",
#  'Via Emilia\n                                    ',
#  'Star Pizza\n                                    ',
#  "Maggiano's Little Italy\n                                    ",
#  'Santa Barbara Italian Cafe\n                                    ',
#  "Italiano's\n                                    ",
#  "Grimaldi's Pizzeria\n                                    ",
#  'Prego Italian Cuisine\n                                    ',
#  'BRIO Tuscan Grille - Woodlands - The Woodlands\n                                    ',
#  "D'Amico's Italian Market Cafe\n                                    ",
#  'Da Vinci Ristorante Italiano\n                                    ',
#  "Dan's Pizza Co.\n                                    ",
#  'La Griglia\n                                    ',
#  "Carrabba's\n                                    ",
#  "Barry's Pizza and Italian Diner\n                                    ",
#  'Via Emilia\n                                    ',
#  'Star Pizza\n                                    ',
#  "Maggiano's Little Italy\n                                    ",
#  'Santa Barbara Italian Cafe\n                                    ',
#  "Italiano's\n                                    ",
#  "Grimaldi's Pizzeria\n                                    ",
#  'Prego Italian Cuisine\n                                    ',
#  'BRIO Tuscan Grille - Woodlands - The Woodlands\n                                    ',
#  "D'Amico's Italian Market Cafe\n                                    ",
#  'Da Vinci Ristorante Italiano\n                                    ',
#  "Dan's Pizza Co.\n                                    ",
#  'La Griglia\n                                    ',
#  "Carrabba's\n                                    ",
#  "Barry's Pizza and Italian Diner\n                                    ",
#  'Via Emilia\n                                    ',
#  'Star Pizza\n                                    ',
#  "Maggiano's Little Italy\n                                    ",
#  'Santa Barbara Italian Cafe\n                                    ',
#  "Italiano's\n                                    ",
#  "Grimaldi's Pizzeria\n                                    ",
#  'Prego Italian Cuisine\n                                    ',
#  'BRIO Tuscan Grille - Woodlands - The Woodlands\n                                    ',
#  "D'Amico's Italian Market Cafe\n                                    ",
#  'Da Vinci Ristorante Italiano\n                                    ',
#  "Dan's Pizza Co.\n                                    ",
#  'La Griglia\n                                    ',
#  "Carrabba's\n                                    ",
#  "Barry's Pizza and Italian Diner\n                                    ",
#  'Via Emilia\n                                    ',
#  'Star Pizza\n                                    ',
#  "Maggiano's Little Italy\n                                    ",
#  'Santa Barbara Italian Cafe\n                                    ',
#  "Italiano's\n                                    ",
#  "Grimaldi's Pizzeria\n                                    ",
#  'Prego Italian Cuisine\n                                    ',
#  'BRIO Tuscan Grille - Woodlands - The Woodlands\n                                    ',
#  "D'Amico's Italian Market Cafe\n                                    ",
#  'Da Vinci Ristorante Italiano\n                                    ',
#  "Dan's Pizza Co.\n                                    ",
#  'La Griglia\n                                    ',
#  "Carrabba's\n                                    ",
#  "Barry's Pizza and Italian Diner\n                                    ",
#  'Via Emilia\n                                    ',
#  'Star Pizza\n                                    ',
#  "Maggiano's Little Italy\n                                    ",
#  'Santa Barbara Italian Cafe\n                                    ',
#  "Italiano's\n                                    ",
#  "Grimaldi's Pizzeria\n                                    ",
#  'Prego Italian Cuisine\n                                    ',
#  'BRIO Tuscan Grille - Woodlands - The Woodlands\n                                    ',
#  "D'Amico's Italian Market Cafe\n                                    ",
#  'Da Vinci Ristorante Italiano\n                                    ',
#  "Dan's Pizza Co.\n                                    ",
#  'La Griglia\n                                    ',
#  "Carrabba's\n                                    ",
#  "Barry's Pizza and Italian Diner\n                                    ",
#  'Via Emilia\n                                    ',
#  'Star Pizza\n                                    ',
#  "Maggiano's Little Italy\n                                    ",
#  'Santa Barbara Italian Cafe\n                                    ',
#  "Italiano's\n                                    ",
#  "Grimaldi's Pizzeria\n                                    ",
#  'Prego Italian Cuisine\n                                    ',
#  'BRIO Tuscan Grille - Woodlands - The Woodlands\n                                    ',
#  "D'Amico's Italian Market Cafe\n                                    ",
#  'Da Vinci Ristorante Italiano\n                                    ',
#  "Dan's Pizza Co.\n                                    ",
#  'La Griglia\n                                    ',
#  "Carrabba's\n                                    ",
#  "Barry's Pizza and Italian Diner\n                                    ",
#  'Via Emilia\n                                    ',
#  'Star Pizza\n                                    ',
#  "Maggiano's Little Italy\n                                    ",
#  'Santa Barbara Italian Cafe\n                                    ',
#  "Italiano's\n                                    ",
#  "Grimaldi's Pizzeria\n                                    ",
#  'Prego Italian Cuisine\n                                    ',
#  'BRIO Tuscan Grille - Woodlands - The Woodlands\n                                    ',
#  "D'Amico's Italian Market Cafe\n                                    ",
#  'Da Vinci Ristorante Italiano\n                                    ',
#  "Dan's Pizza Co.\n                                    ",
#  'La Griglia\n                                    ',
#  "Carrabba's\n                                    ",
#  "Barry's Pizza and Italian Diner\n                                    ",
#  'Via Emilia\n                                    ',
#  'Star Pizza\n                                    ',
#  "Maggiano's Little Italy\n                                    ",
#  'Santa Barbara Italian Cafe\n                                    ',
#  "Italiano's\n                                    ",
#  "Grimaldi's Pizzeria\n                                    ",
#  'Prego Italian Cuisine\n                                    ',
#  'BRIO Tuscan Grille - Woodlands - The Woodlands\n                                    ',
#  "D'Amico's Italian Market Cafe\n                                    ",
#  'Da Vinci Ristorante Italiano\n                                    ',
#  "Dan's Pizza Co.\n                                    ",
#  'La Griglia\n                                    ',
#  "Carrabba's\n                                    ",
#  "Barry's Pizza and Italian Diner\n                                    ",
#  'Via Emilia\n                                    ',
#  'Star Pizza\n                                    ',
#  "Maggiano's Little Italy\n                                    ",
#  'Santa Barbara Italian Cafe\n                                    ',
#  "Italiano's\n                                    ",
#  "Grimaldi's Pizzeria\n                                    ",
#  'Prego Italian Cuisine\n                                    ',
#  'BRIO Tuscan Grille - Woodlands - The Woodlands\n                                    ',
#  "D'Amico's Italian Market Cafe\n                                    ",
#  'Da Vinci Ristorante Italiano\n                                    ',
#  "Dan's Pizza Co.\n                                    ",
#  'La Griglia\n                                    ',
#  "Carrabba's\n                                    ",
#  "Barry's Pizza and Italian Diner\n                                    ",
#  'Via Emilia\n                                    ',
#  'Star Pizza\n                                    ',
#  "Maggiano's Little Italy\n                                    ",
#  'Santa Barbara Italian Cafe\n                                    ',
#  "Italiano's\n                                    ",
#  "Grimaldi's Pizzeria\n                                    ",
#  'Prego Italian Cuisine\n                                    ',
#  'BRIO Tuscan Grille - Woodlands - The Woodlands\n                                    ',
#  "D'Amico's Italian Market Cafe\n                                    ",
#  'Da Vinci Ristorante Italiano\n                                    ',
#  "Dan's Pizza Co.\n                                    ",
#  'La Griglia\n                                    ',
#  "Carrabba's\n                                    ",
#  "Barry's Pizza and Italian Diner\n                                    ",
#  'Via Emilia\n                                    ',
#  'Star Pizza\n                                    ',
#  "Maggiano's Little Italy\n                                    ",
#  'Santa Barbara Italian Cafe\n                                    ',
#  "Italiano's\n                                    ",
#  "Grimaldi's Pizzeria\n                                    ",
#  'Prego Italian Cuisine\n                                    ',
#  'BRIO Tuscan Grille - Woodlands - The Woodlands\n                                    ',
#  "D'Amico's Italian Market Cafe\n                                    ",
#  'Da Vinci Ristorante Italiano\n                                    ',
#  "Dan's Pizza Co.\n                                    ",
#  'La Griglia\n                                    ',
#  "Carrabba's\n                                    ",
#  "Barry's Pizza and Italian Diner\n                                    ",
#  'Via Emilia\n                                    ',
#  'Star Pizza\n                                    ',
#  "Maggiano's Little Italy\n                                    ",
#  'Santa Barbara Italian Cafe\n                                    ',
#  "Italiano's\n                                    ",
#  "Grimaldi's Pizzeria\n                                    ",
#  'Prego Italian Cuisine\n                                    ',
#  'BRIO Tuscan Grille - Woodlands - The Woodlands\n                                    ',
#  "D'Amico's Italian Market Cafe\n                                    ",
#  'Da Vinci Ristorante Italiano\n                                    ',
#  "Dan's Pizza Co.\n                                    ",
#  'La Griglia\n                                    ',
#  "Carrabba's\n                                    ",
#  "Barry's Pizza and Italian Diner\n                                    ",
#  'Via Emilia\n                                    ']

# %%
restaurant_address
# Out:
# [' 2111 Norfolk Street, Houston 77098',
#  ' 2019 Post Oak Boulevard 77056',
#  ' 5012 Broadway Street, Pearland 77581',
#  ' 217 Farm to Market 1960 Bypass Road E, Humble 77338',
#  ' 20 Waterway Avenue, Suite 100, The Woodlands 77380',
#  ' 2520 Amherst Street, Houston 77005',
#  ' 1201 Lake Woodlands Drive 77380',
#  ' 5510 Morningside Drive 77005',
#  ' 6455 South Fry Road, Suite 100, Katy 77494',
#  ' 15148 HWY 3. 77598',
#  ' 2002 West Gray Street 77019',
#  ' 3115 Kirby Drive, Houston 77098',
#  ' 6003 Richmond Avenue 77057',
#  ' 10700 Kuykendahl Road 77381',
#  ' 21784 Katy Freeway, Suite 100 77024',
#  ' 1029 Hwy 6 N, Suite 100, Houston 77079',
#  ' 26420 Preston Street 77373',
#  ' 4566 Bissonnet Street 77401',
#  ' 25602 Interstate 45 N, Suite 101 77386',
#  ' 709 West Parkwood Avenue 77546',
#  ' 628 Seawall Boulevard 77550',
#  ' 15407 Texas 36, Needville 77461',
#  ' 540 Texas Avenue, Houston 77002',
#  ' 19355 Katy Fwy #500',
#  ' 18321 W Lake Houston Parkway, suite 540 77346',
#  ' 5300 N Braeswood Boulevard 77096',
#  ' 28145A Tomball Parkway',
#  ' 9451 Cullen Boulevard Ste A',
#  ' 3471 E Sam Houston Pkwy S, Pasadena 77505',
#  ' 1321 Studewood Street, Houston 77008',
#  ' 7072 FM 1960 Rd E, Humble 77346',
#  ' 2800 Marina Bay Dr, League City 77573',
#  ' 12810 West. Broadway Street',
#  ' 9814 Fry Rd, Suite 120, Cypress 77433',
#  ' 5431 Barker Cypress Rd, Houston 77084',
#  ' 18304 FM 1488 RD Magnolia 77354',
#  ' 6037 North Fry Road 77449',
#  ' 32826 FM 2978',
#  ' 9740 Barker Cypress Rd, Ste 115, Cypress',
#  ' 2111 Norfolk Street, Houston 77098',
#  ' 2019 Post Oak Boulevard 77056',
#  ' 5012 Broadway Street, Pearland 77581',
#  ' 217 Farm to Market 1960 Bypass Road E, Humble 77338',
#  ' 20 Waterway Avenue, Suite 100, The Woodlands 77380',
#  ' 2520 Amherst Street, Houston 77005',
#  ' 1201 Lake Woodlands Drive 77380',
#  ' 5510 Morningside Drive 77005',
#  ' 6455 South Fry Road, Suite 100, Katy 77494',
#  ' 15148 HWY 3. 77598',
#  ' 2002 West Gray Street 77019',
#  ' 3115 Kirby Drive, Houston 77098',
#  ' 6003 Richmond Avenue 77057',
#  ' 10700 Kuykendahl Road 77381',
#  ' 2111 Norfolk Street, Houston 77098',
#  ' 2019 Post Oak Boulevard 77056',
#  ' 5012 Broadway Street, Pearland 77581',
#  ' 217 Farm to Market 1960 Bypass Road E, Humble 77338',
#  ' 20 Waterway Avenue, Suite 100, The Woodlands 77380',
#  ' 2520 Amherst Street, Houston 77005',
#  ' 1201 Lake Woodlands Drive 77380',
#  ' 5510 Morningside Drive 77005',
#  ' 6455 South Fry Road, Suite 100, Katy 77494',
#  ' 15148 HWY 3. 77598',
#  ' 2002 West Gray Street 77019',
#  ' 3115 Kirby Drive, Houston 77098',
#  ' 6003 Richmond Avenue 77057',
#  ' 10700 Kuykendahl Road 77381',
#  ' 2111 Norfolk Street, Houston 77098',
#  ' 2019 Post Oak Boulevard 77056',
#  ' 5012 Broadway Street, Pearland 77581',
#  ' 217 Farm to Market 1960 Bypass Road E, Humble 77338',
#  ' 20 Waterway Avenue, Suite 100, The Woodlands 77380',
#  ' 2520 Amherst Street, Houston 77005',
#  ' 1201 Lake Woodlands Drive 77380',
#  ' 5510 Morningside Drive 77005',
#  ' 6455 South Fry Road, Suite 100, Katy 77494',
#  ' 15148 HWY 3. 77598',
#  ' 2002 West Gray Street 77019',
#  ' 3115 Kirby Drive, Houston 77098',
#  ' 6003 Richmond Avenue 77057',
#  ' 10700 Kuykendahl Road 77381',
#  ' 2111 Norfolk Street, Houston 77098',
#  ' 2019 Post Oak Boulevard 77056',
#  ' 5012 Broadway Street, Pearland 77581',
#  ' 217 Farm to Market 1960 Bypass Road E, Humble 77338',
#  ' 20 Waterway Avenue, Suite 100, The Woodlands 77380',
#  ' 2520 Amherst Street, Houston 77005',
#  ' 1201 Lake Woodlands Drive 77380',
#  ' 5510 Morningside Drive 77005',
#  ' 6455 South Fry Road, Suite 100, Katy 77494',
#  ' 15148 HWY 3. 77598',
#  ' 2002 West Gray Street 77019',
#  ' 3115 Kirby Drive, Houston 77098',
#  ' 6003 Richmond Avenue 77057',
#  ' 10700 Kuykendahl Road 77381',
#  ' 2111 Norfolk Street, Houston 77098',
#  ' 2019 Post Oak Boulevard 77056',
#  ' 5012 Broadway Street, Pearland 77581',
#  ' 217 Farm to Market 1960 Bypass Road E, Humble 77338',
#  ' 20 Waterway Avenue, Suite 100, The Woodlands 77380',
#  ' 2520 Amherst Street, Houston 77005',
#  ' 1201 Lake Woodlands Drive 77380',
#  ' 5510 Morningside Drive 77005',
#  ' 6455 South Fry Road, Suite 100, Katy 77494',
#  ' 15148 HWY 3. 77598',
#  ' 2002 West Gray Street 77019',
#  ' 3115 Kirby Drive, Houston 77098',
#  ' 6003 Richmond Avenue 77057',
#  ' 10700 Kuykendahl Road 77381',
#  ' 2111 Norfolk Street, Houston 77098',
#  ' 2019 Post Oak Boulevard 77056',
#  ' 5012 Broadway Street, Pearland 77581',
#  ' 217 Farm to Market 1960 Bypass Road E, Humble 77338',
#  ' 20 Waterway Avenue, Suite 100, The Woodlands 77380',
#  ' 2520 Amherst Street, Houston 77005',
#  ' 1201 Lake Woodlands Drive 77380',
#  ' 5510 Morningside Drive 77005',
#  ' 6455 South Fry Road, Suite 100, Katy 77494',
#  ' 15148 HWY 3. 77598',
#  ' 2002 West Gray Street 77019',
#  ' 3115 Kirby Drive, Houston 77098',
#  ' 6003 Richmond Avenue 77057',
#  ' 10700 Kuykendahl Road 77381',
#  ' 2111 Norfolk Street, Houston 77098',
#  ' 2019 Post Oak Boulevard 77056',
#  ' 5012 Broadway Street, Pearland 77581',
#  ' 217 Farm to Market 1960 Bypass Road E, Humble 77338',
#  ' 20 Waterway Avenue, Suite 100, The Woodlands 77380',
#  ' 2520 Amherst Street, Houston 77005',
#  ' 1201 Lake Woodlands Drive 77380',
#  ' 5510 Morningside Drive 77005',
#  ' 6455 South Fry Road, Suite 100, Katy 77494',
#  ' 15148 HWY 3. 77598',
#  ' 2002 West Gray Street 77019',
#  ' 3115 Kirby Drive, Houston 77098',
#  ' 6003 Richmond Avenue 77057',
#  ' 10700 Kuykendahl Road 77381',
#  ' 2111 Norfolk Street, Houston 77098',
#  ' 2019 Post Oak Boulevard 77056',
#  ' 5012 Broadway Street, Pearland 77581',
#  ' 217 Farm to Market 1960 Bypass Road E, Humble 77338',
#  ' 20 Waterway Avenue, Suite 100, The Woodlands 77380',
#  ' 2520 Amherst Street, Houston 77005',
#  ' 1201 Lake Woodlands Drive 77380',
#  ' 5510 Morningside Drive 77005',
#  ' 6455 South Fry Road, Suite 100, Katy 77494',
#  ' 15148 HWY 3. 77598',
#  ' 2002 West Gray Street 77019',
#  ' 3115 Kirby Drive, Houston 77098',
#  ' 6003 Richmond Avenue 77057',
#  ' 10700 Kuykendahl Road 77381',
#  ' 2111 Norfolk Street, Houston 77098',
#  ' 2019 Post Oak Boulevard 77056',
#  ' 5012 Broadway Street, Pearland 77581',
#  ' 217 Farm to Market 1960 Bypass Road E, Humble 77338',
#  ' 20 Waterway Avenue, Suite 100, The Woodlands 77380',
#  ' 2520 Amherst Street, Houston 77005',
#  ' 1201 Lake Woodlands Drive 77380',
#  ' 5510 Morningside Drive 77005',
#  ' 6455 South Fry Road, Suite 100, Katy 77494',
#  ' 15148 HWY 3. 77598',
#  ' 2002 West Gray Street 77019',
#  ' 3115 Kirby Drive, Houston 77098',
#  ' 6003 Richmond Avenue 77057',
#  ' 10700 Kuykendahl Road 77381',
#  ' 2111 Norfolk Street, Houston 77098',
#  ' 2019 Post Oak Boulevard 77056',
#  ' 5012 Broadway Street, Pearland 77581',
#  ' 217 Farm to Market 1960 Bypass Road E, Humble 77338',
#  ' 20 Waterway Avenue, Suite 100, The Woodlands 77380',
#  ' 2520 Amherst Street, Houston 77005',
#  ' 1201 Lake Woodlands Drive 77380',
#  ' 5510 Morningside Drive 77005',
#  ' 6455 South Fry Road, Suite 100, Katy 77494',
#  ' 15148 HWY 3. 77598',
#  ' 2002 West Gray Street 77019',
#  ' 3115 Kirby Drive, Houston 77098',
#  ' 6003 Richmond Avenue 77057',
#  ' 10700 Kuykendahl Road 77381',
#  ' 2111 Norfolk Street, Houston 77098',
#  ' 2019 Post Oak Boulevard 77056',
#  ' 5012 Broadway Street, Pearland 77581',
#  ' 217 Farm to Market 1960 Bypass Road E, Humble 77338',
#  ' 20 Waterway Avenue, Suite 100, The Woodlands 77380',
#  ' 2520 Amherst Street, Houston 77005',
#  ' 1201 Lake Woodlands Drive 77380',
#  ' 5510 Morningside Drive 77005',
#  ' 6455 South Fry Road, Suite 100, Katy 77494',
#  ' 15148 HWY 3. 77598',
#  ' 2002 West Gray Street 77019',
#  ' 3115 Kirby Drive, Houston 77098',
#  ' 6003 Richmond Avenue 77057',
#  ' 10700 Kuykendahl Road 77381',
#  ' 2111 Norfolk Street, Houston 77098',
#  ' 2019 Post Oak Boulevard 77056',
#  ' 5012 Broadway Street, Pearland 77581',
#  ' 217 Farm to Market 1960 Bypass Road E, Humble 77338',
#  ' 20 Waterway Avenue, Suite 100, The Woodlands 77380',
#  ' 2520 Amherst Street, Houston 77005',
#  ' 1201 Lake Woodlands Drive 77380',
#  ' 5510 Morningside Drive 77005',
#  ' 6455 South Fry Road, Suite 100, Katy 77494',
#  ' 15148 HWY 3. 77598',
#  ' 2002 West Gray Street 77019',
#  ' 3115 Kirby Drive, Houston 77098',
#  ' 6003 Richmond Avenue 77057',
#  ' 10700 Kuykendahl Road 77381',
#  ' 2111 Norfolk Street, Houston 77098',
#  ' 2019 Post Oak Boulevard 77056',
#  ' 5012 Broadway Street, Pearland 77581',
#  ' 217 Farm to Market 1960 Bypass Road E, Humble 77338',
#  ' 20 Waterway Avenue, Suite 100, The Woodlands 77380',
#  ' 2520 Amherst Street, Houston 77005',
#  ' 1201 Lake Woodlands Drive 77380',
#  ' 5510 Morningside Drive 77005',
#  ' 6455 South Fry Road, Suite 100, Katy 77494',
#  ' 15148 HWY 3. 77598',
#  ' 2002 West Gray Street 77019',
#  ' 3115 Kirby Drive, Houston 77098',
#  ' 6003 Richmond Avenue 77057',
#  ' 10700 Kuykendahl Road 77381',
#  ' 2111 Norfolk Street, Houston 77098',
#  ' 2019 Post Oak Boulevard 77056',
#  ' 5012 Broadway Street, Pearland 77581',
#  ' 217 Farm to Market 1960 Bypass Road E, Humble 77338',
#  ' 20 Waterway Avenue, Suite 100, The Woodlands 77380',
#  ' 2520 Amherst Street, Houston 77005',
#  ' 1201 Lake Woodlands Drive 77380',
#  ' 5510 Morningside Drive 77005',
#  ' 6455 South Fry Road, Suite 100, Katy 77494',
#  ' 15148 HWY 3. 77598',
#  ' 2002 West Gray Street 77019',
#  ' 3115 Kirby Drive, Houston 77098',
#  ' 6003 Richmond Avenue 77057',
#  ' 10700 Kuykendahl Road 77381',
#  ' 2111 Norfolk Street, Houston 77098',
#  ' 2019 Post Oak Boulevard 77056',
#  ' 5012 Broadway Street, Pearland 77581',
#  ' 217 Farm to Market 1960 Bypass Road E, Humble 77338',
#  ' 20 Waterway Avenue, Suite 100, The Woodlands 77380',
#  ' 2520 Amherst Street, Houston 77005',
#  ' 1201 Lake Woodlands Drive 77380',
#  ' 5510 Morningside Drive 77005',
#  ' 6455 South Fry Road, Suite 100, Katy 77494',
#  ' 15148 HWY 3. 77598',
#  ' 2002 West Gray Street 77019',
#  ' 3115 Kirby Drive, Houston 77098',
#  ' 6003 Richmond Avenue 77057',
#  ' 10700 Kuykendahl Road 77381',
#  ' 2111 Norfolk Street, Houston 77098',
#  ' 2019 Post Oak Boulevard 77056',
#  ' 5012 Broadway Street, Pearland 77581',
#  ' 217 Farm to Market 1960 Bypass Road E, Humble 77338',
#  ' 20 Waterway Avenue, Suite 100, The Woodlands 77380',
#  ' 2520 Amherst Street, Houston 77005',
#  ' 1201 Lake Woodlands Drive 77380',
#  ' 5510 Morningside Drive 77005',
#  ' 6455 South Fry Road, Suite 100, Katy 77494',
#  ' 15148 HWY 3. 77598',
#  ' 2002 West Gray Street 77019',
#  ' 3115 Kirby Drive, Houston 77098',
#  ' 6003 Richmond Avenue 77057',
#  ' 10700 Kuykendahl Road 77381',
#  ' 2111 Norfolk Street, Houston 77098',
#  ' 2019 Post Oak Boulevard 77056',
#  ' 5012 Broadway Street, Pearland 77581',
#  ' 217 Farm to Market 1960 Bypass Road E, Humble 77338',
#  ' 20 Waterway Avenue, Suite 100, The Woodlands 77380',
#  ' 2520 Amherst Street, Houston 77005',
#  ' 1201 Lake Woodlands Drive 77380',
#  ' 5510 Morningside Drive 77005',
#  ' 6455 South Fry Road, Suite 100, Katy 77494',
#  ' 15148 HWY 3. 77598',
#  ' 2002 West Gray Street 77019',
#  ' 3115 Kirby Drive, Houston 77098',
#  ' 6003 Richmond Avenue 77057',
#  ' 10700 Kuykendahl Road 77381',
#  ' 2111 Norfolk Street, Houston 77098',
#  ' 2019 Post Oak Boulevard 77056',
#  ' 5012 Broadway Street, Pearland 77581',
#  ' 217 Farm to Market 1960 Bypass Road E, Humble 77338',
#  ' 20 Waterway Avenue, Suite 100, The Woodlands 77380',
#  ' 2520 Amherst Street, Houston 77005',
#  ' 1201 Lake Woodlands Drive 77380',
#  ' 5510 Morningside Drive 77005',
#  ' 6455 South Fry Road, Suite 100, Katy 77494',
#  ' 15148 HWY 3. 77598',
#  ' 2002 West Gray Street 77019',
#  ' 3115 Kirby Drive, Houston 77098',
#  ' 6003 Richmond Avenue 77057',
#  ' 10700 Kuykendahl Road 77381',
#  ' 2111 Norfolk Street, Houston 77098',
#  ' 2019 Post Oak Boulevard 77056',
#  ' 5012 Broadway Street, Pearland 77581',
#  ' 217 Farm to Market 1960 Bypass Road E, Humble 77338',
#  ' 20 Waterway Avenue, Suite 100, The Woodlands 77380',
#  ' 2520 Amherst Street, Houston 77005',
#  ' 1201 Lake Woodlands Drive 77380',
#  ' 5510 Morningside Drive 77005',
#  ' 6455 South Fry Road, Suite 100, Katy 77494',
#  ' 15148 HWY 3. 77598',
#  ' 2002 West Gray Street 77019',
#  ' 3115 Kirby Drive, Houston 77098',
#  ' 6003 Richmond Avenue 77057',
#  ' 10700 Kuykendahl Road 77381',
#  ' 2111 Norfolk Street, Houston 77098',
#  ' 2019 Post Oak Boulevard 77056',
#  ' 5012 Broadway Street, Pearland 77581',
#  ' 217 Farm to Market 1960 Bypass Road E, Humble 77338',
#  ' 20 Waterway Avenue, Suite 100, The Woodlands 77380',
#  ' 2520 Amherst Street, Houston 77005',
#  ' 1201 Lake Woodlands Drive 77380',
#  ' 5510 Morningside Drive 77005',
#  ' 6455 South Fry Road, Suite 100, Katy 77494',
#  ' 15148 HWY 3. 77598',
#  ' 2002 West Gray Street 77019',
#  ' 3115 Kirby Drive, Houston 77098',
#  ' 6003 Richmond Avenue 77057',
#  ' 10700 Kuykendahl Road 77381',
#  ' 2111 Norfolk Street, Houston 77098',
#  ' 2019 Post Oak Boulevard 77056',
#  ' 5012 Broadway Street, Pearland 77581',
#  ' 217 Farm to Market 1960 Bypass Road E, Humble 77338',
#  ' 20 Waterway Avenue, Suite 100, The Woodlands 77380',
#  ' 2520 Amherst Street, Houston 77005',
#  ' 1201 Lake Woodlands Drive 77380',
#  ' 5510 Morningside Drive 77005',
#  ' 6455 South Fry Road, Suite 100, Katy 77494',
#  ' 15148 HWY 3. 77598',
#  ' 2002 West Gray Street 77019',
#  ' 3115 Kirby Drive, Houston 77098',
#  ' 6003 Richmond Avenue 77057',
#  ' 10700 Kuykendahl Road 77381',
#  ' 2111 Norfolk Street, Houston 77098',
#  ' 2019 Post Oak Boulevard 77056',
#  ' 5012 Broadway Street, Pearland 77581',
#  ' 217 Farm to Market 1960 Bypass Road E, Humble 77338',
#  ' 20 Waterway Avenue, Suite 100, The Woodlands 77380',
#  ' 2520 Amherst Street, Houston 77005',
#  ' 1201 Lake Woodlands Drive 77380',
#  ' 5510 Morningside Drive 77005',
#  ' 6455 South Fry Road, Suite 100, Katy 77494',
#  ' 15148 HWY 3. 77598',
#  ' 2002 West Gray Street 77019',
#  ' 3115 Kirby Drive, Houston 77098',
#  ' 6003 Richmond Avenue 77057',
#  ' 10700 Kuykendahl Road 77381',
#  ' 2111 Norfolk Street, Houston 77098',
#  ' 2019 Post Oak Boulevard 77056',
#  ' 5012 Broadway Street, Pearland 77581',
#  ' 217 Farm to Market 1960 Bypass Road E, Humble 77338',
#  ' 20 Waterway Avenue, Suite 100, The Woodlands 77380',
#  ' 2520 Amherst Street, Houston 77005',
#  ' 1201 Lake Woodlands Drive 77380',
#  ' 5510 Morningside Drive 77005',
#  ' 6455 South Fry Road, Suite 100, Katy 77494',
#  ' 15148 HWY 3. 77598',
#  ' 2002 West Gray Street 77019',
#  ' 3115 Kirby Drive, Houston 77098',
#  ' 6003 Richmond Avenue 77057',
#  ' 10700 Kuykendahl Road 77381',
#  ' 2111 Norfolk Street, Houston 77098',
#  ' 2019 Post Oak Boulevard 77056',
#  ' 5012 Broadway Street, Pearland 77581',
#  ' 217 Farm to Market 1960 Bypass Road E, Humble 77338',
#  ' 20 Waterway Avenue, Suite 100, The Woodlands 77380',
#  ' 2520 Amherst Street, Houston 77005',
#  ' 1201 Lake Woodlands Drive 77380',
#  ' 5510 Morningside Drive 77005',
#  ' 6455 South Fry Road, Suite 100, Katy 77494',
#  ' 15148 HWY 3. 77598',
#  ' 2002 West Gray Street 77019',
#  ' 3115 Kirby Drive, Houston 77098',
#  ' 6003 Richmond Avenue 77057',
#  ' 10700 Kuykendahl Road 77381',
#  ' 2111 Norfolk Street, Houston 77098',
#  ' 2019 Post Oak Boulevard 77056',
#  ' 5012 Broadway Street, Pearland 77581',
#  ' 217 Farm to Market 1960 Bypass Road E, Humble 77338',
#  ' 20 Waterway Avenue, Suite 100, The Woodlands 77380',
#  ' 2520 Amherst Street, Houston 77005',
#  ' 1201 Lake Woodlands Drive 77380',
#  ' 5510 Morningside Drive 77005',
#  ' 6455 South Fry Road, Suite 100, Katy 77494',
#  ' 15148 HWY 3. 77598',
#  ' 2002 West Gray Street 77019',
#  ' 3115 Kirby Drive, Houston 77098',
#  ' 6003 Richmond Avenue 77057',
#  ' 10700 Kuykendahl Road 77381',
#  ' 2111 Norfolk Street, Houston 77098',
#  ' 2019 Post Oak Boulevard 77056',
#  ' 5012 Broadway Street, Pearland 77581',
#  ' 217 Farm to Market 1960 Bypass Road E, Humble 77338',
#  ' 20 Waterway Avenue, Suite 100, The Woodlands 77380',
#  ' 2520 Amherst Street, Houston 77005',
#  ' 1201 Lake Woodlands Drive 77380',
#  ' 5510 Morningside Drive 77005',
#  ' 6455 South Fry Road, Suite 100, Katy 77494',
#  ' 15148 HWY 3. 77598',
#  ' 2002 West Gray Street 77019',
#  ' 3115 Kirby Drive, Houston 77098',
#  ' 6003 Richmond Avenue 77057',
#  ' 10700 Kuykendahl Road 77381']

# %%
votes
# Out:
# ['677 votes',
#  '527 votes',
#  '149 votes',
#  '238 votes',
#  '177 votes',
#  '169 votes',
#  '198 votes',
#  '168 votes',
#  '133 votes',
#  ',',
#  '136 votes',
#  '155 votes',
#  '115 votes',
#  '134 votes',
#  ',',
#  '110 votes',
#  'Cuisines: ',
#  'Cuisines: ',
#  'Cuisines: ',
#  'Cuisines: ',
#  '85 votes',
#  'Cuisines: ',
#  'Cuisines: ',
#  'Cuisines: ',
#  'Cuisines: ',
#  'Cuisines: ',
#  ',',
#  ',',
#  'Cuisines: ',
#  'Cuisines: ',
#  'Cuisines: ',
#  'Cuisines: ',
#  'Cuisines: ',
#  'Cuisines: ',
#  'Cuisines: ',
#  'Cuisines: ',
#  'Cuisines: ',
#  ',',
#  'Cuisines: ',
#  '677 votes',
#  '527 votes',
#  '149 votes',
#  '238 votes',
#  '177 votes',
#  '169 votes',
#  '198 votes',
#  '168 votes',
#  '133 votes',
#  ',',
#  '136 votes',
#  '155 votes',
#  '115 votes',
#  '134 votes',
#  '677 votes',
#  '527 votes',
#  '149 votes',
#  '238 votes',
#  '177 votes',
#  '169 votes',
#  '198 votes',
#  '168 votes',
#  '133 votes',
#  ',',
#  '136 votes',
#  '155 votes',
#  '115 votes',
#  '134 votes',
#  '677 votes',
#  '527 votes',
#  '149 votes',
#  '238 votes',
#  '177 votes',
#  '169 votes',
#  '198 votes',
#  '168 votes',
#  '133 votes',
#  ',',
#  '136 votes',
#  '155 votes',
#  '115 votes',
#  '134 votes',
#  '677 votes',
#  '527 votes',
#  '149 votes',
#  '238 votes',
#  '177 votes',
#  '169 votes',
#  '198 votes',
#  '168 votes',
#  '133 votes',
#  ',',
#  '136 votes',
#  '155 votes',
#  '115 votes',
#  '134 votes',
#  '677 votes',
#  '527 votes',
#  '149 votes',
#  '238 votes',
#  '177 votes',
#  '169 votes',
#  '198 votes',
#  '168 votes',
#  '133 votes',
#  ',',
#  '136 votes',
#  '155 votes',
#  '115 votes',
#  '134 votes',
#  '677 votes',
#  '527 votes',
#  '149 votes',
#  '238 votes',
#  '177 votes',
#  '169 votes',
#  '198 votes',
#  '168 votes',
#  '133 votes',
#  ',',
#  '136 votes',
#  '155 votes',
#  '115 votes',
#  '134 votes',
#  '677 votes',
#  '527 votes',
#  '149 votes',
#  '238 votes',
#  '177 votes',
#  '169 votes',
#  '198 votes',
#  '168 votes',
#  '133 votes',
#  ',',
#  '136 votes',
#  '155 votes',
#  '115 votes',
#  '134 votes',
#  '677 votes',
#  '527 votes',
#  '149 votes',
#  '238 votes',
#  '177 votes',
#  '169 votes',
#  '198 votes',
#  '168 votes',
#  '133 votes',
#  ',',
#  '136 votes',
#  '155 votes',
#  '115 votes',
#  '134 votes',
#  '677 votes',
#  '527 votes',
#  '149 votes',
#  '238 votes',
#  '177 votes',
#  '169 votes',
#  '198 votes',
#  '168 votes',
#  '133 votes',
#  ',',
#  '136 votes',
#  '155 votes',
#  '115 votes',
#  '134 votes',
#  '677 votes',
#  '527 votes',
#  '149 votes',
#  '238 votes',
#  '177 votes',
#  '169 votes',
#  '198 votes',
#  '168 votes',
#  '133 votes',
#  ',',
#  '136 votes',
#  '155 votes',
#  '115 votes',
#  '134 votes',
#  '677 votes',
#  '527 votes',
#  '149 votes',
#  '238 votes',
#  '177 votes',
#  '169 votes',
#  '198 votes',
#  '168 votes',
#  '133 votes',
#  ',',
#  '136 votes',
#  '155 votes',
#  '115 votes',
#  '134 votes',
#  '677 votes',
#  '527 votes',
#  '149 votes',
#  '238 votes',
#  '177 votes',
#  '169 votes',
#  '198 votes',
#  '168 votes',
#  '133 votes',
#  ',',
#  '136 votes',
#  '155 votes',
#  '115 votes',
#  '134 votes',
#  '677 votes',
#  '527 votes',
#  '149 votes',
#  '238 votes',
#  '177 votes',
#  '169 votes',
#  '198 votes',
#  '168 votes',
#  '133 votes',
#  ',',
#  '136 votes',
#  '155 votes',
#  '115 votes',
#  '134 votes',
#  '677 votes',
#  '527 votes',
#  '149 votes',
#  '238 votes',
#  '177 votes',
#  '169 votes',
#  '198 votes',
#  '168 votes',
#  '133 votes',
#  ',',
#  '136 votes',
#  '155 votes',
#  '115 votes',
#  '134 votes',
#  '677 votes',
#  '527 votes',
#  '149 votes',
#  '238 votes',
#  '177 votes',
#  '169 votes',
#  '198 votes',
#  '168 votes',
#  '133 votes',
#  ',',
#  '136 votes',
#  '155 votes',
#  '115 votes',
#  '134 votes',
#  '677 votes',
#  '527 votes',
#  '149 votes',
#  '238 votes',
#  '177 votes',
#  '169 votes',
#  '198 votes',
#  '168 votes',
#  '133 votes',
#  ',',
#  '136 votes',
#  '155 votes',
#  '115 votes',
#  '134 votes',
#  '677 votes',
#  '527 votes',
#  '149 votes',
#  '238 votes',
#  '177 votes',
#  '169 votes',
#  '198 votes',
#  '168 votes',
#  '133 votes',
#  ',',
#  '136 votes',
#  '155 votes',
#  '115 votes',
#  '134 votes',
#  '677 votes',
#  '527 votes',
#  '149 votes',
#  '238 votes',
#  '177 votes',
#  '169 votes',
#  '198 votes',
#  '168 votes',
#  '133 votes',
#  ',',
#  '136 votes',
#  '155 votes',
#  '115 votes',
#  '134 votes',
#  '677 votes',
#  '527 votes',
#  '149 votes',
#  '238 votes',
#  '177 votes',
#  '169 votes',
#  '198 votes',
#  '168 votes',
#  '133 votes',
#  ',',
#  '136 votes',
#  '155 votes',
#  '115 votes',
#  '134 votes',
#  '677 votes',
#  '527 votes',
#  '149 votes',
#  '238 votes',
#  '177 votes',
#  '169 votes',
#  '198 votes',
#  '168 votes',
#  '133 votes',
#  ',',
#  '136 votes',
#  '155 votes',
#  '115 votes',
#  '134 votes',
#  '677 votes',
#  '527 votes',
#  '149 votes',
#  '238 votes',
#  '177 votes',
#  '169 votes',
#  '198 votes',
#  '168 votes',
#  '133 votes',
#  ',',
#  '136 votes',
#  '155 votes',
#  '115 votes',
#  '134 votes',
#  '677 votes',
#  '527 votes',
#  '149 votes',
#  '238 votes',
#  '177 votes',
#  '169 votes',
#  '198 votes',
#  '168 votes',
#  '133 votes',
#  ',',
#  '136 votes',
#  '155 votes',
#  '115 votes',
#  '134 votes',
#  '677 votes',
#  '527 votes',
#  '149 votes',
#  '238 votes',
#  '177 votes',
#  '169 votes',
#  '198 votes',
#  '168 votes',
#  '133 votes',
#  ',',
#  '136 votes',
#  '155 votes',
#  '115 votes',
#  '134 votes',
#  '677 votes',
#  '527 votes',
#  '149 votes',
#  '238 votes',
#  '177 votes',
#  '169 votes',
#  '198 votes',
#  '168 votes',
#  '133 votes',
#  ',',
#  '136 votes',
#  '155 votes',
#  '115 votes',
#  '134 votes',
#  '677 votes',
#  '527 votes',
#  '149 votes',
#  '238 votes',
#  '177 votes',
#  '169 votes',
#  '198 votes',
#  '168 votes',
#  '133 votes',
#  ',',
#  '136 votes',
#  '155 votes',
#  '115 votes',
#  '134 votes',
#  '677 votes',
#  '527 votes',
#  '149 votes',
#  '238 votes',
#  '177 votes',
#  '169 votes',
#  '198 votes',
#  '168 votes',
#  '133 votes',
#  ',',
#  '136 votes',
#  '155 votes',
#  '115 votes',
#  '134 votes']

# %%
ratings
# Out:
# ['\n                                        4.9\n                                    ',
#  '\n                                        4.8\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.3\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.3\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        -\n                                    ',
#  '\n                                        4.3\n                                    ',
#  '\n                                        -\n                                    ',
#  '\n                                        -\n                                    ',
#  '\n                                        -\n                                    ',
#  '\n                                        -\n                                    ',
#  '\n                                        4.1\n                                    ',
#  '\n                                        -\n                                    ',
#  '\n                                        -\n                                    ',
#  '\n                                        -\n                                    ',
#  '\n                                        -\n                                    ',
#  '\n                                        -\n                                    ',
#  '\n                                        -\n                                    ',
#  '\n                                        -\n                                    ',
#  '\n                                        -\n                                    ',
#  '\n                                        -\n                                    ',
#  '\n                                        -\n                                    ',
#  '\n                                        -\n                                    ',
#  '\n                                        -\n                                    ',
#  '\n                                        -\n                                    ',
#  '\n                                        -\n                                    ',
#  '\n                                        -\n                                    ',
#  '\n                                        -\n                                    ',
#  '\n                                        -\n                                    ',
#  '\n                                        -\n                                    ',
#  '\n                                        4.9\n                                    ',
#  '\n                                        4.8\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.3\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.3\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.9\n                                    ',
#  '\n                                        4.8\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.3\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.3\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.9\n                                    ',
#  '\n                                        4.8\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.3\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.3\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.9\n                                    ',
#  '\n                                        4.8\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.3\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.3\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.9\n                                    ',
#  '\n                                        4.8\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.3\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.3\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.9\n                                    ',
#  '\n                                        4.8\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.3\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.3\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.9\n                                    ',
#  '\n                                        4.8\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.3\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.3\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.9\n                                    ',
#  '\n                                        4.8\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.3\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.3\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.9\n                                    ',
#  '\n                                        4.8\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.3\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.3\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.9\n                                    ',
#  '\n                                        4.8\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.3\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.3\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.9\n                                    ',
#  '\n                                        4.8\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.3\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.3\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.9\n                                    ',
#  '\n                                        4.8\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.3\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.3\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.9\n                                    ',
#  '\n                                        4.8\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.3\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.3\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.9\n                                    ',
#  '\n                                        4.8\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.3\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.3\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.9\n                                    ',
#  '\n                                        4.8\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.3\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.3\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.9\n                                    ',
#  '\n                                        4.8\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.3\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.3\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.9\n                                    ',
#  '\n                                        4.8\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.3\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.3\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.9\n                                    ',
#  '\n                                        4.8\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.3\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.3\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.9\n                                    ',
#  '\n                                        4.8\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.3\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.3\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.9\n                                    ',
#  '\n                                        4.8\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.3\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.3\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.9\n                                    ',
#  '\n                                        4.8\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.3\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.3\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.9\n                                    ',
#  '\n                                        4.8\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.3\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.3\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.9\n                                    ',
#  '\n                                        4.8\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.3\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.3\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.9\n                                    ',
#  '\n                                        4.8\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.3\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.3\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.9\n                                    ',
#  '\n                                        4.8\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.3\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.3\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.9\n                                    ',
#  '\n                                        4.8\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.5\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.3\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.3\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.4\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.2\n                                    ']

# %%
df_restaurant_HOU_IT=pd.DataFrame({'Name': restaurant_name,
                                 'Address':restaurant_address,
                                 'Votes': votes,
                                 'Rating': ratings,'cost':costs})
df_restaurant_HOU_IT
# Out:
#                                                   Name  \
# 0     Star Pizza\n
# 1    Maggiano's Little Italy\n                     ...
# 2    Santa Barbara Italian Cafe\n                  ...
# 3     Italiano's\n
# 4    Grimaldi's Pizzeria\n                         ...
# ..                                                 ...
# 398  Dan's Pizza Co.\n                             ...
# 399   La Griglia\n
# 400   Carrabba's\n
# 401  Barry's Pizza and Italian Diner\n             ...
# 402   Via Emilia\n
#
#                                                Address      Votes  \
# 0                   2111 Norfolk Street, Houston 77098  677 votes
# 1                        2019 Post Oak Boulevard 77056  527 votes
# 2                 5012 Broadway Street, Pearland 77581  149 votes
# 3     217 Farm to Market 1960 Bypass Road E, Humble...  238 votes
# 4     20 Waterway Avenue, Suite 100, The Woodlands ...  177 votes
# ..                                                 ...        ...
# 398                                 15148 HWY 3. 77598          ,
# 399                        2002 West Gray Street 77019  136 votes
# 400                    3115 Kirby Drive, Houston 77098  155 votes
# 401                         6003 Richmond Avenue 77057  115 votes
# 402                        10700 Kuykendahl Road 77381  134 votes
#
#                                                 Rating               cost
# 0    \n                                        4.9\...   Cost for two:$50
# 1    \n                                        4.8\...   Cost for two:$55
# 2    \n                                        4.5\...  Cost for two:$150
# 3    \n                                        4.5\...   Cost for two:$75
# 4    \n                                        4.2\...   Cost for two:$75
# ..                                                 ...                ...
# 398  \n                                        4.3\...   Cost for two:$25
# 399  \n                                        4.2\...   Cost for two:$75
# 400  \n                                        4.4\...  Cost for two:$100
# 401  \n                                        4.2\...   Cost for two:$25
# 402  \n                                        4.2\...  Cost for two:$150
#
# [403 rows x 5 columns]

# %%
df_restaurant_HOU_IT.drop_duplicates()
# Out:
#                                                  Name  \
# 0    Star Pizza\n
# 1   Maggiano's Little Italy\n                     ...
# 2   Santa Barbara Italian Cafe\n                  ...
# 3    Italiano's\n
# 4   Grimaldi's Pizzeria\n                         ...
# 5   Prego Italian Cuisine\n                       ...
# 6   BRIO Tuscan Grille - Woodlands - The Woodlands...
# 7   D'Amico's Italian Market Cafe\n               ...
# 8   Da Vinci Ristorante Italiano\n                ...
# 9   Dan's Pizza Co.\n                             ...
# 10   La Griglia\n
# 11   Carrabba's\n
# 12  Barry's Pizza and Italian Diner\n             ...
# 13   Via Emilia\n
# 14       MidiCi\n
# 15  Brothers Pizzeria\n                           ...
# 16  The Italian Joint\n                           ...
# 17  Enoteca Rossa\n                               ...
# 18  Papa Amadeus\n                                ...
# 19  Amici Ristorante Italiano\n                   ...
# 20  Mario's Italian\n                             ...
# 21  Carmine's Italian Restaurant\n                ...
# 22  Wine Cellar & Mezza Bar\n                     ...
# 23  Mona Fresh Italian\n                          ...
# 24  Tosca Americana\n                             ...
# 25  La Fresca Pizza\n                             ...
# 26  Cicis Pizza\n
# 27  Domino's Pizza\n                              ...
# 28  Peter Piper Pizza\n                           ...
# 29  Shiloh Club\n
# 30  People's Choice Pizza\n                       ...
# 31  Houston Pizza Venture\n                       ...
# 32  Marco's Pizza\n                               ...
# 33   Pizza Fire\n
# 34  Big Ben's Pizzeria\n                          ...
# 35  Pizzaiolo's Gourmet Pizza\n                   ...
# 36  Il Primo Pizza and Wings II\n                 ...
# 37    Pizza Hut\n
# 38  Giannina’s Pizza\n                            ...
#
#                                               Address       Votes  \
# 0                  2111 Norfolk Street, Houston 77098   677 votes
# 1                       2019 Post Oak Boulevard 77056   527 votes
# 2                5012 Broadway Street, Pearland 77581   149 votes
# 3    217 Farm to Market 1960 Bypass Road E, Humble...   238 votes
# 4    20 Waterway Avenue, Suite 100, The Woodlands ...   177 votes
# 5                  2520 Amherst Street, Houston 77005   169 votes
# 6                     1201 Lake Woodlands Drive 77380   198 votes
# 7                        5510 Morningside Drive 77005   168 votes
# 8          6455 South Fry Road, Suite 100, Katy 77494   133 votes
# 9                                  15148 HWY 3. 77598           ,
# 10                        2002 West Gray Street 77019   136 votes
# 11                    3115 Kirby Drive, Houston 77098   155 votes
# 12                         6003 Richmond Avenue 77057   115 votes
# 13                        10700 Kuykendahl Road 77381   134 votes
# 14                21784 Katy Freeway, Suite 100 77024           ,
# 15             1029 Hwy 6 N, Suite 100, Houston 77079   110 votes
# 16                         26420 Preston Street 77373  Cuisines:
# 17                        4566 Bissonnet Street 77401  Cuisines:
# 18             25602 Interstate 45 N, Suite 101 77386  Cuisines:
# 19                     709 West Parkwood Avenue 77546  Cuisines:
# 20                        628 Seawall Boulevard 77550    85 votes
# 21                    15407 Texas 36, Needville 77461  Cuisines:
# 22                    540 Texas Avenue, Houston 77002  Cuisines:
# 23                                19355 Katy Fwy #500  Cuisines:
# 24      18321 W Lake Houston Parkway, suite 540 77346  Cuisines:
# 25                   5300 N Braeswood Boulevard 77096  Cuisines:
# 26                             28145A Tomball Parkway           ,
# 27                        9451 Cullen Boulevard Ste A           ,
# 28          3471 E Sam Houston Pkwy S, Pasadena 77505  Cuisines:
# 29               1321 Studewood Street, Houston 77008  Cuisines:
# 30                    7072 FM 1960 Rd E, Humble 77346  Cuisines:
# 31              2800 Marina Bay Dr, League City 77573  Cuisines:
# 32                        12810 West. Broadway Street  Cuisines:
# 33              9814 Fry Rd, Suite 120, Cypress 77433  Cuisines:
# 34              5431 Barker Cypress Rd, Houston 77084  Cuisines:
# 35                    18304 FM 1488 RD Magnolia 77354  Cuisines:
# 36                          6037 North Fry Road 77449  Cuisines:
# 37                                      32826 FM 2978           ,
# 38           9740 Barker Cypress Rd, Ste 115, Cypress  Cuisines:
#
#                                                Rating               cost
# 0   \n                                        4.9\...   Cost for two:$50
# 1   \n                                        4.8\...   Cost for two:$55
# 2   \n                                        4.5\...  Cost for two:$150
# 3   \n                                        4.5\...   Cost for two:$75
# 4   \n                                        4.2\...   Cost for two:$75
# 5   \n                                        4.4\...   Cost for two:$70
# 6   \n                                        4.3\...   Cost for two:$35
# 7   \n                                        4.4\...   Cost for two:$45
# 8   \n                                        4.4\...  Cost for two:$150
# 9   \n                                        4.3\...   Cost for two:$25
# 10  \n                                        4.2\...   Cost for two:$75
# 11  \n                                        4.4\...  Cost for two:$100
# 12  \n                                        4.2\...   Cost for two:$25
# 13  \n                                        4.2\...  Cost for two:$150
# 14  \n                                        -\n ...   Cost for two:$30
# 15  \n                                        4.3\...   Cost for two:$25
# 16  \n                                        -\n ...   Cost for two:$50
# 17  \n                                        -\n ...   Cost for two:$45
# 18  \n                                        -\n ...   Cost for two:$25
# 19  \n                                        -\n ...   Cost for two:$75
# 20  \n                                        4.1\...   Cost for two:$75
# 21  \n                                        -\n ...   Cost for two:$25
# 22  \n                                        -\n ...   Cost for two:$65
# 23  \n                                        -\n ...   Cost for two:$15
# 24  \n                                        -\n ...   Cost for two:$25
# 25  \n                                        -\n ...   Cost for two:$15
# 26  \n                                        -\n ...   Cost for two:$20
# 27  \n                                        -\n ...   Cost for two:$20
# 28  \n                                        -\n ...   Cost for two:$25
# 29  \n                                        -\n ...   Cost for two:$25
# 30  \n                                        -\n ...   Cost for two:$25
# 31  \n                                        -\n ...   Cost for two:$25
# 32  \n                                        -\n ...   Cost for two:$20
# 33  \n                                        -\n ...   Cost for two:$25
# 34  \n                                        -\n ...   Cost for two:$75
# 35  \n                                        -\n ...   Cost for two:$25
# 36  \n                                        -\n ...   Cost for two:$25
# 37  \n                                        -\n ...   Cost for two:$20
# 38  \n                                        -\n ...   Cost for two:$20

# %%
#### Save raw data to csv
df_restaurant_HOU_IT.to_csv('df_restaurant_HOU_IT_raw_EO.csv',index=False)
