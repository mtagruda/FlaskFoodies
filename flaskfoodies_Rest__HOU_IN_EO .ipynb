# %%
# scrape 
from bs4 import BeautifulSoup
from bs4 import BeautifulSoup as bs
from splinter import Browser
from splinter.exceptions import ElementDoesNotExist
import requests
import pandas as pd
import time

# %% [markdown]
# <h1># Windows Users</h1>

# %%
#Set the chromedriver path
executable_path = {"executable_path": "/users/evaeb/bin/chromedriver"}
browser = Browser("chrome", **executable_path, headless=False)

# %%
# Scrap Indian restaurants in New York
#url = 'https://www.zomato.com/houston/restaurants/indian'
n = 1
restaurant_name=[]
restaurant_address=[]
votes=[]
ratings=[]
costs=[]

for x in range(1, 30):
    url = f'https://www.zomato.com/houston/restaurants/indian?page={n}'
    browser.visit(url)

    html = browser.html
    soup = bs(html, 'html.parser')
    restaurant_info = soup.find_all(class_='content')
    
    for restaurant in restaurant_info:
        try:
            rest_name= restaurant.find('a', class_='result-title').text     
            rest_address= restaurant.find(class_='search-result-address').text
            vote= restaurant.find('span').text
            rating= restaurant.find(class_='rating-popup').text
            cost= restaurant.find(class_="res-cost").text
            
                  
            restaurant_name.append(rest_name)
            restaurant_address.append(rest_address)
            votes.append(vote)
            ratings.append(rating)
            costs.append(cost)
            
        except:
            print("Not Available")
              
        
#         print(rest_name)
#         print(rest_address)
#         print(vote)
#         print(rating)
        n += 1
# Out:
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available
# Not Available

# %%
restaurant_name
# Out:
# ['Indika\n                                    ',
#  'Pondicheri\n                                    ',
#  'Cuisine of India\n                                    ',
#  'Sitar Cuisine of India\n                                    ',
#  "India's Restaurant\n                                    ",
#  'London Sizzler\n                                    ',
#  'Dhakshin Indian Cuisine\n                                    ',
#  'Mogul Indian Restaurant\n                                    ',
#  'Bombay Grill\n                                    ',
#  "Aga's Restaurant & Catering\n                                    ",
#  'Indika\n                                    ',
#  'Pondicheri\n                                    ',
#  'Cuisine of India\n                                    ',
#  'Sitar Cuisine of India\n                                    ',
#  "India's Restaurant\n                                    ",
#  'London Sizzler\n                                    ',
#  'Dhakshin Indian Cuisine\n                                    ',
#  'Mogul Indian Restaurant\n                                    ',
#  'Bombay Grill\n                                    ',
#  "Aga's Restaurant & Catering\n                                    ",
#  'Indika\n                                    ',
#  'Pondicheri\n                                    ',
#  'Cuisine of India\n                                    ',
#  'Sitar Cuisine of India\n                                    ',
#  "India's Restaurant\n                                    ",
#  'London Sizzler\n                                    ',
#  'Dhakshin Indian Cuisine\n                                    ',
#  'Mogul Indian Restaurant\n                                    ',
#  'Bombay Grill\n                                    ',
#  "Aga's Restaurant & Catering\n                                    ",
#  'Indika\n                                    ',
#  'Pondicheri\n                                    ',
#  'Cuisine of India\n                                    ',
#  'Sitar Cuisine of India\n                                    ',
#  "India's Restaurant\n                                    ",
#  'London Sizzler\n                                    ',
#  'Dhakshin Indian Cuisine\n                                    ',
#  'Mogul Indian Restaurant\n                                    ',
#  'Bombay Grill\n                                    ',
#  "Aga's Restaurant & Catering\n                                    ",
#  'Indika\n                                    ',
#  'Pondicheri\n                                    ',
#  'Cuisine of India\n                                    ',
#  'Sitar Cuisine of India\n                                    ',
#  "India's Restaurant\n                                    ",
#  'London Sizzler\n                                    ',
#  'Dhakshin Indian Cuisine\n                                    ',
#  'Mogul Indian Restaurant\n                                    ',
#  'Bombay Grill\n                                    ',
#  "Aga's Restaurant & Catering\n                                    ",
#  'Indika\n                                    ',
#  'Pondicheri\n                                    ',
#  'Cuisine of India\n                                    ',
#  'Sitar Cuisine of India\n                                    ',
#  "India's Restaurant\n                                    ",
#  'London Sizzler\n                                    ',
#  'Dhakshin Indian Cuisine\n                                    ',
#  'Mogul Indian Restaurant\n                                    ',
#  'Bombay Grill\n                                    ',
#  "Aga's Restaurant & Catering\n                                    ",
#  'Indika\n                                    ',
#  'Pondicheri\n                                    ',
#  'Cuisine of India\n                                    ',
#  'Sitar Cuisine of India\n                                    ',
#  "India's Restaurant\n                                    ",
#  'London Sizzler\n                                    ',
#  'Dhakshin Indian Cuisine\n                                    ',
#  'Mogul Indian Restaurant\n                                    ',
#  'Bombay Grill\n                                    ',
#  "Aga's Restaurant & Catering\n                                    ",
#  'Indika\n                                    ',
#  'Pondicheri\n                                    ',
#  'Cuisine of India\n                                    ',
#  'Sitar Cuisine of India\n                                    ',
#  "India's Restaurant\n                                    ",
#  'London Sizzler\n                                    ',
#  'Dhakshin Indian Cuisine\n                                    ',
#  'Mogul Indian Restaurant\n                                    ',
#  'Bombay Grill\n                                    ',
#  "Aga's Restaurant & Catering\n                                    ",
#  'Indika\n                                    ',
#  'Pondicheri\n                                    ',
#  'Cuisine of India\n                                    ',
#  'Sitar Cuisine of India\n                                    ',
#  "India's Restaurant\n                                    ",
#  'London Sizzler\n                                    ',
#  'Dhakshin Indian Cuisine\n                                    ',
#  'Mogul Indian Restaurant\n                                    ',
#  'Bombay Grill\n                                    ',
#  "Aga's Restaurant & Catering\n                                    ",
#  'Indika\n                                    ',
#  'Pondicheri\n                                    ',
#  'Cuisine of India\n                                    ',
#  'Sitar Cuisine of India\n                                    ',
#  "India's Restaurant\n                                    ",
#  'London Sizzler\n                                    ',
#  'Dhakshin Indian Cuisine\n                                    ',
#  'Mogul Indian Restaurant\n                                    ',
#  'Bombay Grill\n                                    ',
#  "Aga's Restaurant & Catering\n                                    ",
#  'Indika\n                                    ',
#  'Pondicheri\n                                    ',
#  'Cuisine of India\n                                    ',
#  'Sitar Cuisine of India\n                                    ',
#  "India's Restaurant\n                                    ",
#  'London Sizzler\n                                    ',
#  'Dhakshin Indian Cuisine\n                                    ',
#  'Mogul Indian Restaurant\n                                    ',
#  'Bombay Grill\n                                    ',
#  "Aga's Restaurant & Catering\n                                    ",
#  'Indika\n                                    ',
#  'Pondicheri\n                                    ',
#  'Cuisine of India\n                                    ',
#  'Sitar Cuisine of India\n                                    ',
#  "India's Restaurant\n                                    ",
#  'London Sizzler\n                                    ',
#  'Dhakshin Indian Cuisine\n                                    ',
#  'Mogul Indian Restaurant\n                                    ',
#  'Bombay Grill\n                                    ',
#  "Aga's Restaurant & Catering\n                                    ",
#  'Indika\n                                    ',
#  'Pondicheri\n                                    ',
#  'Cuisine of India\n                                    ',
#  'Sitar Cuisine of India\n                                    ',
#  "India's Restaurant\n                                    ",
#  'London Sizzler\n                                    ',
#  'Dhakshin Indian Cuisine\n                                    ',
#  'Mogul Indian Restaurant\n                                    ',
#  'Bombay Grill\n                                    ',
#  "Aga's Restaurant & Catering\n                                    ",
#  'Indika\n                                    ',
#  'Pondicheri\n                                    ',
#  'Cuisine of India\n                                    ',
#  'Sitar Cuisine of India\n                                    ',
#  "India's Restaurant\n                                    ",
#  'London Sizzler\n                                    ',
#  'Dhakshin Indian Cuisine\n                                    ',
#  'Mogul Indian Restaurant\n                                    ',
#  'Bombay Grill\n                                    ',
#  "Aga's Restaurant & Catering\n                                    ",
#  'Indika\n                                    ',
#  'Pondicheri\n                                    ',
#  'Cuisine of India\n                                    ',
#  'Sitar Cuisine of India\n                                    ',
#  "India's Restaurant\n                                    ",
#  'London Sizzler\n                                    ',
#  'Dhakshin Indian Cuisine\n                                    ',
#  'Mogul Indian Restaurant\n                                    ',
#  'Bombay Grill\n                                    ',
#  "Aga's Restaurant & Catering\n                                    ",
#  'Indika\n                                    ',
#  'Pondicheri\n                                    ',
#  'Cuisine of India\n                                    ',
#  'Sitar Cuisine of India\n                                    ',
#  "India's Restaurant\n                                    ",
#  'London Sizzler\n                                    ',
#  'Dhakshin Indian Cuisine\n                                    ',
#  'Mogul Indian Restaurant\n                                    ',
#  'Bombay Grill\n                                    ',
#  "Aga's Restaurant & Catering\n                                    ",
#  'Indika\n                                    ',
#  'Pondicheri\n                                    ',
#  'Cuisine of India\n                                    ',
#  'Sitar Cuisine of India\n                                    ',
#  "India's Restaurant\n                                    ",
#  'London Sizzler\n                                    ',
#  'Dhakshin Indian Cuisine\n                                    ',
#  'Mogul Indian Restaurant\n                                    ',
#  'Bombay Grill\n                                    ',
#  "Aga's Restaurant & Catering\n                                    ",
#  'Indika\n                                    ',
#  'Pondicheri\n                                    ',
#  'Cuisine of India\n                                    ',
#  'Sitar Cuisine of India\n                                    ',
#  "India's Restaurant\n                                    ",
#  'London Sizzler\n                                    ',
#  'Dhakshin Indian Cuisine\n                                    ',
#  'Mogul Indian Restaurant\n                                    ',
#  'Bombay Grill\n                                    ',
#  "Aga's Restaurant & Catering\n                                    ",
#  'Indika\n                                    ',
#  'Pondicheri\n                                    ',
#  'Cuisine of India\n                                    ',
#  'Sitar Cuisine of India\n                                    ',
#  "India's Restaurant\n                                    ",
#  'London Sizzler\n                                    ',
#  'Dhakshin Indian Cuisine\n                                    ',
#  'Mogul Indian Restaurant\n                                    ',
#  'Bombay Grill\n                                    ',
#  "Aga's Restaurant & Catering\n                                    ",
#  'Indika\n                                    ',
#  'Pondicheri\n                                    ',
#  'Cuisine of India\n                                    ',
#  'Sitar Cuisine of India\n                                    ',
#  "India's Restaurant\n                                    ",
#  'London Sizzler\n                                    ',
#  'Dhakshin Indian Cuisine\n                                    ',
#  'Mogul Indian Restaurant\n                                    ',
#  'Bombay Grill\n                                    ',
#  "Aga's Restaurant & Catering\n                                    ",
#  'Indika\n                                    ',
#  'Pondicheri\n                                    ',
#  'Cuisine of India\n                                    ',
#  'Sitar Cuisine of India\n                                    ',
#  "India's Restaurant\n                                    ",
#  'London Sizzler\n                                    ',
#  'Dhakshin Indian Cuisine\n                                    ',
#  'Mogul Indian Restaurant\n                                    ',
#  'Bombay Grill\n                                    ',
#  "Aga's Restaurant & Catering\n                                    ",
#  'Indika\n                                    ',
#  'Pondicheri\n                                    ',
#  'Cuisine of India\n                                    ',
#  'Sitar Cuisine of India\n                                    ',
#  "India's Restaurant\n                                    ",
#  'London Sizzler\n                                    ',
#  'Dhakshin Indian Cuisine\n                                    ',
#  'Mogul Indian Restaurant\n                                    ',
#  'Bombay Grill\n                                    ',
#  "Aga's Restaurant & Catering\n                                    ",
#  'Indika\n                                    ',
#  'Pondicheri\n                                    ',
#  'Cuisine of India\n                                    ',
#  'Sitar Cuisine of India\n                                    ',
#  "India's Restaurant\n                                    ",
#  'London Sizzler\n                                    ',
#  'Dhakshin Indian Cuisine\n                                    ',
#  'Mogul Indian Restaurant\n                                    ',
#  'Bombay Grill\n                                    ',
#  "Aga's Restaurant & Catering\n                                    ",
#  'Indika\n                                    ',
#  'Pondicheri\n                                    ',
#  'Cuisine of India\n                                    ',
#  'Sitar Cuisine of India\n                                    ',
#  "India's Restaurant\n                                    ",
#  'London Sizzler\n                                    ',
#  'Dhakshin Indian Cuisine\n                                    ',
#  'Mogul Indian Restaurant\n                                    ',
#  'Bombay Grill\n                                    ',
#  "Aga's Restaurant & Catering\n                                    ",
#  'Indika\n                                    ',
#  'Pondicheri\n                                    ',
#  'Cuisine of India\n                                    ',
#  'Sitar Cuisine of India\n                                    ',
#  "India's Restaurant\n                                    ",
#  'London Sizzler\n                                    ',
#  'Dhakshin Indian Cuisine\n                                    ',
#  'Mogul Indian Restaurant\n                                    ',
#  'Bombay Grill\n                                    ',
#  "Aga's Restaurant & Catering\n                                    ",
#  'Indika\n                                    ',
#  'Pondicheri\n                                    ',
#  'Cuisine of India\n                                    ',
#  'Sitar Cuisine of India\n                                    ',
#  "India's Restaurant\n                                    ",
#  'London Sizzler\n                                    ',
#  'Dhakshin Indian Cuisine\n                                    ',
#  'Mogul Indian Restaurant\n                                    ',
#  'Bombay Grill\n                                    ',
#  "Aga's Restaurant & Catering\n                                    ",
#  'Indika\n                                    ',
#  'Pondicheri\n                                    ',
#  'Cuisine of India\n                                    ',
#  'Sitar Cuisine of India\n                                    ',
#  "India's Restaurant\n                                    ",
#  'London Sizzler\n                                    ',
#  'Dhakshin Indian Cuisine\n                                    ',
#  'Mogul Indian Restaurant\n                                    ',
#  'Bombay Grill\n                                    ',
#  "Aga's Restaurant & Catering\n                                    ",
#  'Indika\n                                    ',
#  'Pondicheri\n                                    ',
#  'Cuisine of India\n                                    ',
#  'Sitar Cuisine of India\n                                    ',
#  "India's Restaurant\n                                    ",
#  'London Sizzler\n                                    ',
#  'Dhakshin Indian Cuisine\n                                    ',
#  'Mogul Indian Restaurant\n                                    ',
#  'Bombay Grill\n                                    ',
#  "Aga's Restaurant & Catering\n                                    ",
#  'Indika\n                                    ',
#  'Pondicheri\n                                    ',
#  'Cuisine of India\n                                    ',
#  'Sitar Cuisine of India\n                                    ',
#  "India's Restaurant\n                                    ",
#  'London Sizzler\n                                    ',
#  'Dhakshin Indian Cuisine\n                                    ',
#  'Mogul Indian Restaurant\n                                    ',
#  'Bombay Grill\n                                    ',
#  "Aga's Restaurant & Catering\n                                    "]

# %%
restaurant_address
# Out:
# [' 516 Westheimer Road, Houston 77006',
#  ' 2800 Kirby Drive, Suite B 132, Houston 77098',
#  ' 1212 NASA Pkwy, Houston 77058',
#  ' 25701 I-45 N, Suite 12, Houston 77380',
#  ' 5704 Richmond Avenue, Houston 77057',
#  ' 6690 Southwest Freeway 77074',
#  ' 19752 Highway 249, Houston 77070',
#  ' 1055 Bay Area Boulevard, Clear Lake 77058',
#  ' 1852 FM 359 Road 77406',
#  ' 11842 Wilcrest Drive 77031',
#  ' 516 Westheimer Road, Houston 77006',
#  ' 2800 Kirby Drive, Suite B 132, Houston 77098',
#  ' 1212 NASA Pkwy, Houston 77058',
#  ' 25701 I-45 N, Suite 12, Houston 77380',
#  ' 5704 Richmond Avenue, Houston 77057',
#  ' 6690 Southwest Freeway 77074',
#  ' 19752 Highway 249, Houston 77070',
#  ' 1055 Bay Area Boulevard, Clear Lake 77058',
#  ' 1852 FM 359 Road 77406',
#  ' 11842 Wilcrest Drive 77031',
#  ' 516 Westheimer Road, Houston 77006',
#  ' 2800 Kirby Drive, Suite B 132, Houston 77098',
#  ' 1212 NASA Pkwy, Houston 77058',
#  ' 25701 I-45 N, Suite 12, Houston 77380',
#  ' 5704 Richmond Avenue, Houston 77057',
#  ' 6690 Southwest Freeway 77074',
#  ' 19752 Highway 249, Houston 77070',
#  ' 1055 Bay Area Boulevard, Clear Lake 77058',
#  ' 1852 FM 359 Road 77406',
#  ' 11842 Wilcrest Drive 77031',
#  ' 516 Westheimer Road, Houston 77006',
#  ' 2800 Kirby Drive, Suite B 132, Houston 77098',
#  ' 1212 NASA Pkwy, Houston 77058',
#  ' 25701 I-45 N, Suite 12, Houston 77380',
#  ' 5704 Richmond Avenue, Houston 77057',
#  ' 6690 Southwest Freeway 77074',
#  ' 19752 Highway 249, Houston 77070',
#  ' 1055 Bay Area Boulevard, Clear Lake 77058',
#  ' 1852 FM 359 Road 77406',
#  ' 11842 Wilcrest Drive 77031',
#  ' 516 Westheimer Road, Houston 77006',
#  ' 2800 Kirby Drive, Suite B 132, Houston 77098',
#  ' 1212 NASA Pkwy, Houston 77058',
#  ' 25701 I-45 N, Suite 12, Houston 77380',
#  ' 5704 Richmond Avenue, Houston 77057',
#  ' 6690 Southwest Freeway 77074',
#  ' 19752 Highway 249, Houston 77070',
#  ' 1055 Bay Area Boulevard, Clear Lake 77058',
#  ' 1852 FM 359 Road 77406',
#  ' 11842 Wilcrest Drive 77031',
#  ' 516 Westheimer Road, Houston 77006',
#  ' 2800 Kirby Drive, Suite B 132, Houston 77098',
#  ' 1212 NASA Pkwy, Houston 77058',
#  ' 25701 I-45 N, Suite 12, Houston 77380',
#  ' 5704 Richmond Avenue, Houston 77057',
#  ' 6690 Southwest Freeway 77074',
#  ' 19752 Highway 249, Houston 77070',
#  ' 1055 Bay Area Boulevard, Clear Lake 77058',
#  ' 1852 FM 359 Road 77406',
#  ' 11842 Wilcrest Drive 77031',
#  ' 516 Westheimer Road, Houston 77006',
#  ' 2800 Kirby Drive, Suite B 132, Houston 77098',
#  ' 1212 NASA Pkwy, Houston 77058',
#  ' 25701 I-45 N, Suite 12, Houston 77380',
#  ' 5704 Richmond Avenue, Houston 77057',
#  ' 6690 Southwest Freeway 77074',
#  ' 19752 Highway 249, Houston 77070',
#  ' 1055 Bay Area Boulevard, Clear Lake 77058',
#  ' 1852 FM 359 Road 77406',
#  ' 11842 Wilcrest Drive 77031',
#  ' 516 Westheimer Road, Houston 77006',
#  ' 2800 Kirby Drive, Suite B 132, Houston 77098',
#  ' 1212 NASA Pkwy, Houston 77058',
#  ' 25701 I-45 N, Suite 12, Houston 77380',
#  ' 5704 Richmond Avenue, Houston 77057',
#  ' 6690 Southwest Freeway 77074',
#  ' 19752 Highway 249, Houston 77070',
#  ' 1055 Bay Area Boulevard, Clear Lake 77058',
#  ' 1852 FM 359 Road 77406',
#  ' 11842 Wilcrest Drive 77031',
#  ' 516 Westheimer Road, Houston 77006',
#  ' 2800 Kirby Drive, Suite B 132, Houston 77098',
#  ' 1212 NASA Pkwy, Houston 77058',
#  ' 25701 I-45 N, Suite 12, Houston 77380',
#  ' 5704 Richmond Avenue, Houston 77057',
#  ' 6690 Southwest Freeway 77074',
#  ' 19752 Highway 249, Houston 77070',
#  ' 1055 Bay Area Boulevard, Clear Lake 77058',
#  ' 1852 FM 359 Road 77406',
#  ' 11842 Wilcrest Drive 77031',
#  ' 516 Westheimer Road, Houston 77006',
#  ' 2800 Kirby Drive, Suite B 132, Houston 77098',
#  ' 1212 NASA Pkwy, Houston 77058',
#  ' 25701 I-45 N, Suite 12, Houston 77380',
#  ' 5704 Richmond Avenue, Houston 77057',
#  ' 6690 Southwest Freeway 77074',
#  ' 19752 Highway 249, Houston 77070',
#  ' 1055 Bay Area Boulevard, Clear Lake 77058',
#  ' 1852 FM 359 Road 77406',
#  ' 11842 Wilcrest Drive 77031',
#  ' 516 Westheimer Road, Houston 77006',
#  ' 2800 Kirby Drive, Suite B 132, Houston 77098',
#  ' 1212 NASA Pkwy, Houston 77058',
#  ' 25701 I-45 N, Suite 12, Houston 77380',
#  ' 5704 Richmond Avenue, Houston 77057',
#  ' 6690 Southwest Freeway 77074',
#  ' 19752 Highway 249, Houston 77070',
#  ' 1055 Bay Area Boulevard, Clear Lake 77058',
#  ' 1852 FM 359 Road 77406',
#  ' 11842 Wilcrest Drive 77031',
#  ' 516 Westheimer Road, Houston 77006',
#  ' 2800 Kirby Drive, Suite B 132, Houston 77098',
#  ' 1212 NASA Pkwy, Houston 77058',
#  ' 25701 I-45 N, Suite 12, Houston 77380',
#  ' 5704 Richmond Avenue, Houston 77057',
#  ' 6690 Southwest Freeway 77074',
#  ' 19752 Highway 249, Houston 77070',
#  ' 1055 Bay Area Boulevard, Clear Lake 77058',
#  ' 1852 FM 359 Road 77406',
#  ' 11842 Wilcrest Drive 77031',
#  ' 516 Westheimer Road, Houston 77006',
#  ' 2800 Kirby Drive, Suite B 132, Houston 77098',
#  ' 1212 NASA Pkwy, Houston 77058',
#  ' 25701 I-45 N, Suite 12, Houston 77380',
#  ' 5704 Richmond Avenue, Houston 77057',
#  ' 6690 Southwest Freeway 77074',
#  ' 19752 Highway 249, Houston 77070',
#  ' 1055 Bay Area Boulevard, Clear Lake 77058',
#  ' 1852 FM 359 Road 77406',
#  ' 11842 Wilcrest Drive 77031',
#  ' 516 Westheimer Road, Houston 77006',
#  ' 2800 Kirby Drive, Suite B 132, Houston 77098',
#  ' 1212 NASA Pkwy, Houston 77058',
#  ' 25701 I-45 N, Suite 12, Houston 77380',
#  ' 5704 Richmond Avenue, Houston 77057',
#  ' 6690 Southwest Freeway 77074',
#  ' 19752 Highway 249, Houston 77070',
#  ' 1055 Bay Area Boulevard, Clear Lake 77058',
#  ' 1852 FM 359 Road 77406',
#  ' 11842 Wilcrest Drive 77031',
#  ' 516 Westheimer Road, Houston 77006',
#  ' 2800 Kirby Drive, Suite B 132, Houston 77098',
#  ' 1212 NASA Pkwy, Houston 77058',
#  ' 25701 I-45 N, Suite 12, Houston 77380',
#  ' 5704 Richmond Avenue, Houston 77057',
#  ' 6690 Southwest Freeway 77074',
#  ' 19752 Highway 249, Houston 77070',
#  ' 1055 Bay Area Boulevard, Clear Lake 77058',
#  ' 1852 FM 359 Road 77406',
#  ' 11842 Wilcrest Drive 77031',
#  ' 516 Westheimer Road, Houston 77006',
#  ' 2800 Kirby Drive, Suite B 132, Houston 77098',
#  ' 1212 NASA Pkwy, Houston 77058',
#  ' 25701 I-45 N, Suite 12, Houston 77380',
#  ' 5704 Richmond Avenue, Houston 77057',
#  ' 6690 Southwest Freeway 77074',
#  ' 19752 Highway 249, Houston 77070',
#  ' 1055 Bay Area Boulevard, Clear Lake 77058',
#  ' 1852 FM 359 Road 77406',
#  ' 11842 Wilcrest Drive 77031',
#  ' 516 Westheimer Road, Houston 77006',
#  ' 2800 Kirby Drive, Suite B 132, Houston 77098',
#  ' 1212 NASA Pkwy, Houston 77058',
#  ' 25701 I-45 N, Suite 12, Houston 77380',
#  ' 5704 Richmond Avenue, Houston 77057',
#  ' 6690 Southwest Freeway 77074',
#  ' 19752 Highway 249, Houston 77070',
#  ' 1055 Bay Area Boulevard, Clear Lake 77058',
#  ' 1852 FM 359 Road 77406',
#  ' 11842 Wilcrest Drive 77031',
#  ' 516 Westheimer Road, Houston 77006',
#  ' 2800 Kirby Drive, Suite B 132, Houston 77098',
#  ' 1212 NASA Pkwy, Houston 77058',
#  ' 25701 I-45 N, Suite 12, Houston 77380',
#  ' 5704 Richmond Avenue, Houston 77057',
#  ' 6690 Southwest Freeway 77074',
#  ' 19752 Highway 249, Houston 77070',
#  ' 1055 Bay Area Boulevard, Clear Lake 77058',
#  ' 1852 FM 359 Road 77406',
#  ' 11842 Wilcrest Drive 77031',
#  ' 516 Westheimer Road, Houston 77006',
#  ' 2800 Kirby Drive, Suite B 132, Houston 77098',
#  ' 1212 NASA Pkwy, Houston 77058',
#  ' 25701 I-45 N, Suite 12, Houston 77380',
#  ' 5704 Richmond Avenue, Houston 77057',
#  ' 6690 Southwest Freeway 77074',
#  ' 19752 Highway 249, Houston 77070',
#  ' 1055 Bay Area Boulevard, Clear Lake 77058',
#  ' 1852 FM 359 Road 77406',
#  ' 11842 Wilcrest Drive 77031',
#  ' 516 Westheimer Road, Houston 77006',
#  ' 2800 Kirby Drive, Suite B 132, Houston 77098',
#  ' 1212 NASA Pkwy, Houston 77058',
#  ' 25701 I-45 N, Suite 12, Houston 77380',
#  ' 5704 Richmond Avenue, Houston 77057',
#  ' 6690 Southwest Freeway 77074',
#  ' 19752 Highway 249, Houston 77070',
#  ' 1055 Bay Area Boulevard, Clear Lake 77058',
#  ' 1852 FM 359 Road 77406',
#  ' 11842 Wilcrest Drive 77031',
#  ' 516 Westheimer Road, Houston 77006',
#  ' 2800 Kirby Drive, Suite B 132, Houston 77098',
#  ' 1212 NASA Pkwy, Houston 77058',
#  ' 25701 I-45 N, Suite 12, Houston 77380',
#  ' 5704 Richmond Avenue, Houston 77057',
#  ' 6690 Southwest Freeway 77074',
#  ' 19752 Highway 249, Houston 77070',
#  ' 1055 Bay Area Boulevard, Clear Lake 77058',
#  ' 1852 FM 359 Road 77406',
#  ' 11842 Wilcrest Drive 77031',
#  ' 516 Westheimer Road, Houston 77006',
#  ' 2800 Kirby Drive, Suite B 132, Houston 77098',
#  ' 1212 NASA Pkwy, Houston 77058',
#  ' 25701 I-45 N, Suite 12, Houston 77380',
#  ' 5704 Richmond Avenue, Houston 77057',
#  ' 6690 Southwest Freeway 77074',
#  ' 19752 Highway 249, Houston 77070',
#  ' 1055 Bay Area Boulevard, Clear Lake 77058',
#  ' 1852 FM 359 Road 77406',
#  ' 11842 Wilcrest Drive 77031',
#  ' 516 Westheimer Road, Houston 77006',
#  ' 2800 Kirby Drive, Suite B 132, Houston 77098',
#  ' 1212 NASA Pkwy, Houston 77058',
#  ' 25701 I-45 N, Suite 12, Houston 77380',
#  ' 5704 Richmond Avenue, Houston 77057',
#  ' 6690 Southwest Freeway 77074',
#  ' 19752 Highway 249, Houston 77070',
#  ' 1055 Bay Area Boulevard, Clear Lake 77058',
#  ' 1852 FM 359 Road 77406',
#  ' 11842 Wilcrest Drive 77031',
#  ' 516 Westheimer Road, Houston 77006',
#  ' 2800 Kirby Drive, Suite B 132, Houston 77098',
#  ' 1212 NASA Pkwy, Houston 77058',
#  ' 25701 I-45 N, Suite 12, Houston 77380',
#  ' 5704 Richmond Avenue, Houston 77057',
#  ' 6690 Southwest Freeway 77074',
#  ' 19752 Highway 249, Houston 77070',
#  ' 1055 Bay Area Boulevard, Clear Lake 77058',
#  ' 1852 FM 359 Road 77406',
#  ' 11842 Wilcrest Drive 77031',
#  ' 516 Westheimer Road, Houston 77006',
#  ' 2800 Kirby Drive, Suite B 132, Houston 77098',
#  ' 1212 NASA Pkwy, Houston 77058',
#  ' 25701 I-45 N, Suite 12, Houston 77380',
#  ' 5704 Richmond Avenue, Houston 77057',
#  ' 6690 Southwest Freeway 77074',
#  ' 19752 Highway 249, Houston 77070',
#  ' 1055 Bay Area Boulevard, Clear Lake 77058',
#  ' 1852 FM 359 Road 77406',
#  ' 11842 Wilcrest Drive 77031',
#  ' 516 Westheimer Road, Houston 77006',
#  ' 2800 Kirby Drive, Suite B 132, Houston 77098',
#  ' 1212 NASA Pkwy, Houston 77058',
#  ' 25701 I-45 N, Suite 12, Houston 77380',
#  ' 5704 Richmond Avenue, Houston 77057',
#  ' 6690 Southwest Freeway 77074',
#  ' 19752 Highway 249, Houston 77070',
#  ' 1055 Bay Area Boulevard, Clear Lake 77058',
#  ' 1852 FM 359 Road 77406',
#  ' 11842 Wilcrest Drive 77031',
#  ' 516 Westheimer Road, Houston 77006',
#  ' 2800 Kirby Drive, Suite B 132, Houston 77098',
#  ' 1212 NASA Pkwy, Houston 77058',
#  ' 25701 I-45 N, Suite 12, Houston 77380',
#  ' 5704 Richmond Avenue, Houston 77057',
#  ' 6690 Southwest Freeway 77074',
#  ' 19752 Highway 249, Houston 77070',
#  ' 1055 Bay Area Boulevard, Clear Lake 77058',
#  ' 1852 FM 359 Road 77406',
#  ' 11842 Wilcrest Drive 77031',
#  ' 516 Westheimer Road, Houston 77006',
#  ' 2800 Kirby Drive, Suite B 132, Houston 77098',
#  ' 1212 NASA Pkwy, Houston 77058',
#  ' 25701 I-45 N, Suite 12, Houston 77380',
#  ' 5704 Richmond Avenue, Houston 77057',
#  ' 6690 Southwest Freeway 77074',
#  ' 19752 Highway 249, Houston 77070',
#  ' 1055 Bay Area Boulevard, Clear Lake 77058',
#  ' 1852 FM 359 Road 77406',
#  ' 11842 Wilcrest Drive 77031',
#  ' 516 Westheimer Road, Houston 77006',
#  ' 2800 Kirby Drive, Suite B 132, Houston 77098',
#  ' 1212 NASA Pkwy, Houston 77058',
#  ' 25701 I-45 N, Suite 12, Houston 77380',
#  ' 5704 Richmond Avenue, Houston 77057',
#  ' 6690 Southwest Freeway 77074',
#  ' 19752 Highway 249, Houston 77070',
#  ' 1055 Bay Area Boulevard, Clear Lake 77058',
#  ' 1852 FM 359 Road 77406',
#  ' 11842 Wilcrest Drive 77031']

# %%
votes
# Out:
# ['189 votes',
#  '161 votes',
#  '128 votes',
#  '109 votes',
#  '110 votes',
#  '84 votes',
#  '73 votes',
#  ',',
#  '54 votes',
#  '39 votes',
#  '189 votes',
#  '161 votes',
#  '128 votes',
#  '109 votes',
#  '110 votes',
#  '84 votes',
#  '73 votes',
#  ',',
#  '54 votes',
#  '39 votes',
#  '189 votes',
#  '161 votes',
#  '128 votes',
#  '109 votes',
#  '110 votes',
#  '84 votes',
#  '73 votes',
#  ',',
#  '54 votes',
#  '39 votes',
#  '189 votes',
#  '161 votes',
#  '128 votes',
#  '109 votes',
#  '110 votes',
#  '84 votes',
#  '73 votes',
#  ',',
#  '54 votes',
#  '39 votes',
#  '189 votes',
#  '161 votes',
#  '128 votes',
#  '109 votes',
#  '110 votes',
#  '84 votes',
#  '73 votes',
#  ',',
#  '54 votes',
#  '39 votes',
#  '189 votes',
#  '161 votes',
#  '128 votes',
#  '109 votes',
#  '110 votes',
#  '84 votes',
#  '73 votes',
#  ',',
#  '54 votes',
#  '39 votes',
#  '189 votes',
#  '161 votes',
#  '128 votes',
#  '109 votes',
#  '110 votes',
#  '84 votes',
#  '73 votes',
#  ',',
#  '54 votes',
#  '39 votes',
#  '189 votes',
#  '161 votes',
#  '128 votes',
#  '109 votes',
#  '110 votes',
#  '84 votes',
#  '73 votes',
#  ',',
#  '54 votes',
#  '39 votes',
#  '189 votes',
#  '161 votes',
#  '128 votes',
#  '109 votes',
#  '110 votes',
#  '84 votes',
#  '73 votes',
#  ',',
#  '54 votes',
#  '39 votes',
#  '189 votes',
#  '161 votes',
#  '128 votes',
#  '109 votes',
#  '110 votes',
#  '84 votes',
#  '73 votes',
#  ',',
#  '54 votes',
#  '39 votes',
#  '189 votes',
#  '161 votes',
#  '128 votes',
#  '109 votes',
#  '110 votes',
#  '84 votes',
#  '73 votes',
#  ',',
#  '54 votes',
#  '39 votes',
#  '189 votes',
#  '161 votes',
#  '128 votes',
#  '109 votes',
#  '110 votes',
#  '84 votes',
#  '73 votes',
#  ',',
#  '54 votes',
#  '39 votes',
#  '189 votes',
#  '161 votes',
#  '128 votes',
#  '109 votes',
#  '110 votes',
#  '84 votes',
#  '73 votes',
#  ',',
#  '54 votes',
#  '39 votes',
#  '189 votes',
#  '161 votes',
#  '128 votes',
#  '109 votes',
#  '110 votes',
#  '84 votes',
#  '73 votes',
#  ',',
#  '54 votes',
#  '39 votes',
#  '189 votes',
#  '161 votes',
#  '128 votes',
#  '109 votes',
#  '110 votes',
#  '84 votes',
#  '73 votes',
#  ',',
#  '54 votes',
#  '39 votes',
#  '189 votes',
#  '161 votes',
#  '128 votes',
#  '109 votes',
#  '110 votes',
#  '84 votes',
#  '73 votes',
#  ',',
#  '54 votes',
#  '39 votes',
#  '189 votes',
#  '161 votes',
#  '128 votes',
#  '109 votes',
#  '110 votes',
#  '84 votes',
#  '73 votes',
#  ',',
#  '54 votes',
#  '39 votes',
#  '189 votes',
#  '161 votes',
#  '128 votes',
#  '109 votes',
#  '110 votes',
#  '84 votes',
#  '73 votes',
#  ',',
#  '54 votes',
#  '39 votes',
#  '189 votes',
#  '161 votes',
#  '128 votes',
#  '109 votes',
#  '110 votes',
#  '84 votes',
#  '73 votes',
#  ',',
#  '54 votes',
#  '39 votes',
#  '189 votes',
#  '161 votes',
#  '128 votes',
#  '109 votes',
#  '110 votes',
#  '84 votes',
#  '73 votes',
#  ',',
#  '54 votes',
#  '39 votes',
#  '189 votes',
#  '161 votes',
#  '128 votes',
#  '109 votes',
#  '110 votes',
#  '84 votes',
#  '73 votes',
#  ',',
#  '54 votes',
#  '39 votes',
#  '189 votes',
#  '161 votes',
#  '128 votes',
#  '109 votes',
#  '110 votes',
#  '84 votes',
#  '73 votes',
#  ',',
#  '54 votes',
#  '39 votes',
#  '189 votes',
#  '161 votes',
#  '128 votes',
#  '109 votes',
#  '110 votes',
#  '84 votes',
#  '73 votes',
#  ',',
#  '54 votes',
#  '39 votes',
#  '189 votes',
#  '161 votes',
#  '128 votes',
#  '109 votes',
#  '110 votes',
#  '84 votes',
#  '73 votes',
#  ',',
#  '54 votes',
#  '39 votes',
#  '189 votes',
#  '161 votes',
#  '128 votes',
#  '109 votes',
#  '110 votes',
#  '84 votes',
#  '73 votes',
#  ',',
#  '54 votes',
#  '39 votes',
#  '189 votes',
#  '161 votes',
#  '128 votes',
#  '109 votes',
#  '110 votes',
#  '84 votes',
#  '73 votes',
#  ',',
#  '54 votes',
#  '39 votes',
#  '189 votes',
#  '161 votes',
#  '128 votes',
#  '109 votes',
#  '110 votes',
#  '84 votes',
#  '73 votes',
#  ',',
#  '54 votes',
#  '39 votes',
#  '189 votes',
#  '161 votes',
#  '128 votes',
#  '109 votes',
#  '110 votes',
#  '84 votes',
#  '73 votes',
#  ',',
#  '54 votes',
#  '39 votes',
#  '189 votes',
#  '161 votes',
#  '128 votes',
#  '109 votes',
#  '110 votes',
#  '84 votes',
#  '73 votes',
#  ',',
#  '54 votes',
#  '39 votes']

# %%
ratings
# Out:
# ['\n                                        4.2\n                                    ',
#  '\n                                        4.0\n                                    ',
#  '\n                                        4.3\n                                    ',
#  '\n                                        4.1\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        3.9\n                                    ',
#  '\n                                        4.0\n                                    ',
#  '\n                                        4.0\n                                    ',
#  '\n                                        4.1\n                                    ',
#  '\n                                        4.1\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.0\n                                    ',
#  '\n                                        4.3\n                                    ',
#  '\n                                        4.1\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        3.9\n                                    ',
#  '\n                                        4.0\n                                    ',
#  '\n                                        4.0\n                                    ',
#  '\n                                        4.1\n                                    ',
#  '\n                                        4.1\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.0\n                                    ',
#  '\n                                        4.3\n                                    ',
#  '\n                                        4.1\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        3.9\n                                    ',
#  '\n                                        4.0\n                                    ',
#  '\n                                        4.0\n                                    ',
#  '\n                                        4.1\n                                    ',
#  '\n                                        4.1\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.0\n                                    ',
#  '\n                                        4.3\n                                    ',
#  '\n                                        4.1\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        3.9\n                                    ',
#  '\n                                        4.0\n                                    ',
#  '\n                                        4.0\n                                    ',
#  '\n                                        4.1\n                                    ',
#  '\n                                        4.1\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.0\n                                    ',
#  '\n                                        4.3\n                                    ',
#  '\n                                        4.1\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        3.9\n                                    ',
#  '\n                                        4.0\n                                    ',
#  '\n                                        4.0\n                                    ',
#  '\n                                        4.1\n                                    ',
#  '\n                                        4.1\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.0\n                                    ',
#  '\n                                        4.3\n                                    ',
#  '\n                                        4.1\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        3.9\n                                    ',
#  '\n                                        4.0\n                                    ',
#  '\n                                        4.0\n                                    ',
#  '\n                                        4.1\n                                    ',
#  '\n                                        4.1\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.0\n                                    ',
#  '\n                                        4.3\n                                    ',
#  '\n                                        4.1\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        3.9\n                                    ',
#  '\n                                        4.0\n                                    ',
#  '\n                                        4.0\n                                    ',
#  '\n                                        4.1\n                                    ',
#  '\n                                        4.1\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.0\n                                    ',
#  '\n                                        4.3\n                                    ',
#  '\n                                        4.1\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        3.9\n                                    ',
#  '\n                                        4.0\n                                    ',
#  '\n                                        4.0\n                                    ',
#  '\n                                        4.1\n                                    ',
#  '\n                                        4.1\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.0\n                                    ',
#  '\n                                        4.3\n                                    ',
#  '\n                                        4.1\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        3.9\n                                    ',
#  '\n                                        4.0\n                                    ',
#  '\n                                        4.0\n                                    ',
#  '\n                                        4.1\n                                    ',
#  '\n                                        4.1\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.0\n                                    ',
#  '\n                                        4.3\n                                    ',
#  '\n                                        4.1\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        3.9\n                                    ',
#  '\n                                        4.0\n                                    ',
#  '\n                                        4.0\n                                    ',
#  '\n                                        4.1\n                                    ',
#  '\n                                        4.1\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.0\n                                    ',
#  '\n                                        4.3\n                                    ',
#  '\n                                        4.1\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        3.9\n                                    ',
#  '\n                                        4.0\n                                    ',
#  '\n                                        4.0\n                                    ',
#  '\n                                        4.1\n                                    ',
#  '\n                                        4.1\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.0\n                                    ',
#  '\n                                        4.3\n                                    ',
#  '\n                                        4.1\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        3.9\n                                    ',
#  '\n                                        4.0\n                                    ',
#  '\n                                        4.0\n                                    ',
#  '\n                                        4.1\n                                    ',
#  '\n                                        4.1\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.0\n                                    ',
#  '\n                                        4.3\n                                    ',
#  '\n                                        4.1\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        3.9\n                                    ',
#  '\n                                        4.0\n                                    ',
#  '\n                                        4.0\n                                    ',
#  '\n                                        4.1\n                                    ',
#  '\n                                        4.1\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.0\n                                    ',
#  '\n                                        4.3\n                                    ',
#  '\n                                        4.1\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        3.9\n                                    ',
#  '\n                                        4.0\n                                    ',
#  '\n                                        4.0\n                                    ',
#  '\n                                        4.1\n                                    ',
#  '\n                                        4.1\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.0\n                                    ',
#  '\n                                        4.3\n                                    ',
#  '\n                                        4.1\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        3.9\n                                    ',
#  '\n                                        4.0\n                                    ',
#  '\n                                        4.0\n                                    ',
#  '\n                                        4.1\n                                    ',
#  '\n                                        4.1\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.0\n                                    ',
#  '\n                                        4.3\n                                    ',
#  '\n                                        4.1\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        3.9\n                                    ',
#  '\n                                        4.0\n                                    ',
#  '\n                                        4.0\n                                    ',
#  '\n                                        4.1\n                                    ',
#  '\n                                        4.1\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.0\n                                    ',
#  '\n                                        4.3\n                                    ',
#  '\n                                        4.1\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        3.9\n                                    ',
#  '\n                                        4.0\n                                    ',
#  '\n                                        4.0\n                                    ',
#  '\n                                        4.1\n                                    ',
#  '\n                                        4.1\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.0\n                                    ',
#  '\n                                        4.3\n                                    ',
#  '\n                                        4.1\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        3.9\n                                    ',
#  '\n                                        4.0\n                                    ',
#  '\n                                        4.0\n                                    ',
#  '\n                                        4.1\n                                    ',
#  '\n                                        4.1\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.0\n                                    ',
#  '\n                                        4.3\n                                    ',
#  '\n                                        4.1\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        3.9\n                                    ',
#  '\n                                        4.0\n                                    ',
#  '\n                                        4.0\n                                    ',
#  '\n                                        4.1\n                                    ',
#  '\n                                        4.1\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.0\n                                    ',
#  '\n                                        4.3\n                                    ',
#  '\n                                        4.1\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        3.9\n                                    ',
#  '\n                                        4.0\n                                    ',
#  '\n                                        4.0\n                                    ',
#  '\n                                        4.1\n                                    ',
#  '\n                                        4.1\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.0\n                                    ',
#  '\n                                        4.3\n                                    ',
#  '\n                                        4.1\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        3.9\n                                    ',
#  '\n                                        4.0\n                                    ',
#  '\n                                        4.0\n                                    ',
#  '\n                                        4.1\n                                    ',
#  '\n                                        4.1\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.0\n                                    ',
#  '\n                                        4.3\n                                    ',
#  '\n                                        4.1\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        3.9\n                                    ',
#  '\n                                        4.0\n                                    ',
#  '\n                                        4.0\n                                    ',
#  '\n                                        4.1\n                                    ',
#  '\n                                        4.1\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.0\n                                    ',
#  '\n                                        4.3\n                                    ',
#  '\n                                        4.1\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        3.9\n                                    ',
#  '\n                                        4.0\n                                    ',
#  '\n                                        4.0\n                                    ',
#  '\n                                        4.1\n                                    ',
#  '\n                                        4.1\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.0\n                                    ',
#  '\n                                        4.3\n                                    ',
#  '\n                                        4.1\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        3.9\n                                    ',
#  '\n                                        4.0\n                                    ',
#  '\n                                        4.0\n                                    ',
#  '\n                                        4.1\n                                    ',
#  '\n                                        4.1\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.0\n                                    ',
#  '\n                                        4.3\n                                    ',
#  '\n                                        4.1\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        3.9\n                                    ',
#  '\n                                        4.0\n                                    ',
#  '\n                                        4.0\n                                    ',
#  '\n                                        4.1\n                                    ',
#  '\n                                        4.1\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.0\n                                    ',
#  '\n                                        4.3\n                                    ',
#  '\n                                        4.1\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        3.9\n                                    ',
#  '\n                                        4.0\n                                    ',
#  '\n                                        4.0\n                                    ',
#  '\n                                        4.1\n                                    ',
#  '\n                                        4.1\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.0\n                                    ',
#  '\n                                        4.3\n                                    ',
#  '\n                                        4.1\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        3.9\n                                    ',
#  '\n                                        4.0\n                                    ',
#  '\n                                        4.0\n                                    ',
#  '\n                                        4.1\n                                    ',
#  '\n                                        4.1\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.0\n                                    ',
#  '\n                                        4.3\n                                    ',
#  '\n                                        4.1\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        3.9\n                                    ',
#  '\n                                        4.0\n                                    ',
#  '\n                                        4.0\n                                    ',
#  '\n                                        4.1\n                                    ',
#  '\n                                        4.1\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        4.0\n                                    ',
#  '\n                                        4.3\n                                    ',
#  '\n                                        4.1\n                                    ',
#  '\n                                        4.2\n                                    ',
#  '\n                                        3.9\n                                    ',
#  '\n                                        4.0\n                                    ',
#  '\n                                        4.0\n                                    ',
#  '\n                                        4.1\n                                    ',
#  '\n                                        4.1\n                                    ']

# %%
df_restaurant_HOU_IN=pd.DataFrame({'Name': restaurant_name,
                                 'Address':restaurant_address,
                                 'Votes': votes,
                                 'Rating': ratings,'cost':costs})
df_restaurant_HOU_IN
# Out:
#                                                   Name  \
# 0         Indika\n
# 1     Pondicheri\n
# 2    Cuisine of India\n                            ...
# 3    Sitar Cuisine of India\n                      ...
# 4    India's Restaurant\n                          ...
# ..                                                 ...
# 285  London Sizzler\n                              ...
# 286  Dhakshin Indian Cuisine\n                     ...
# 287  Mogul Indian Restaurant\n                     ...
# 288  Bombay Grill\n                                ...
# 289  Aga's Restaurant & Catering\n                 ...
#
#                                            Address      Votes  \
# 0               516 Westheimer Road, Houston 77006  189 votes
# 1     2800 Kirby Drive, Suite B 132, Houston 77098  161 votes
# 2                    1212 NASA Pkwy, Houston 77058  128 votes
# 3            25701 I-45 N, Suite 12, Houston 77380  109 votes
# 4              5704 Richmond Avenue, Houston 77057  110 votes
# ..                                             ...        ...
# 285                   6690 Southwest Freeway 77074   84 votes
# 286               19752 Highway 249, Houston 77070   73 votes
# 287      1055 Bay Area Boulevard, Clear Lake 77058          ,
# 288                         1852 FM 359 Road 77406   54 votes
# 289                     11842 Wilcrest Drive 77031   39 votes
#
#                                                 Rating              cost
# 0    \n                                        4.2\...  Cost for two:$60
# 1    \n                                        4.0\...  Cost for two:$50
# 2    \n                                        4.3\...  Cost for two:$75
# 3    \n                                        4.1\...  Cost for two:$75
# 4    \n                                        4.2\...  Cost for two:$30
# ..                                                 ...               ...
# 285  \n                                        3.9\...  Cost for two:$45
# 286  \n                                        4.0\...  Cost for two:$75
# 287  \n                                        4.0\...  Cost for two:$30
# 288  \n                                        4.1\...  Cost for two:$75
# 289  \n                                        4.1\...  Cost for two:$75
#
# [290 rows x 5 columns]

# %%
#### Save raw data to csv
df_restaurant_HOU_IN.drop_duplicates()
# Out:
#                                                 Name  \
# 0       Indika\n
# 1   Pondicheri\n
# 2  Cuisine of India\n                            ...
# 3  Sitar Cuisine of India\n                      ...
# 4  India's Restaurant\n                          ...
# 5  London Sizzler\n                              ...
# 6  Dhakshin Indian Cuisine\n                     ...
# 7  Mogul Indian Restaurant\n                     ...
# 8  Bombay Grill\n                                ...
# 9  Aga's Restaurant & Catering\n                 ...
#
#                                          Address      Votes  \
# 0             516 Westheimer Road, Houston 77006  189 votes
# 1   2800 Kirby Drive, Suite B 132, Houston 77098  161 votes
# 2                  1212 NASA Pkwy, Houston 77058  128 votes
# 3          25701 I-45 N, Suite 12, Houston 77380  109 votes
# 4            5704 Richmond Avenue, Houston 77057  110 votes
# 5                   6690 Southwest Freeway 77074   84 votes
# 6               19752 Highway 249, Houston 77070   73 votes
# 7      1055 Bay Area Boulevard, Clear Lake 77058          ,
# 8                         1852 FM 359 Road 77406   54 votes
# 9                     11842 Wilcrest Drive 77031   39 votes
#
#                                               Rating              cost
# 0  \n                                        4.2\...  Cost for two:$60
# 1  \n                                        4.0\...  Cost for two:$50
# 2  \n                                        4.3\...  Cost for two:$75
# 3  \n                                        4.1\...  Cost for two:$75
# 4  \n                                        4.2\...  Cost for two:$30
# 5  \n                                        3.9\...  Cost for two:$45
# 6  \n                                        4.0\...  Cost for two:$75
# 7  \n                                        4.0\...  Cost for two:$30
# 8  \n                                        4.1\...  Cost for two:$75
# 9  \n                                        4.1\...  Cost for two:$75

# %%
#### Save raw data to csv
df_restaurant_HOU_IN.to_csv('df_restaurant_HOU_IN_raw_EO.csv',index=False)
