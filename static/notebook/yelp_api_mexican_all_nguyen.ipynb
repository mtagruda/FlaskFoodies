# %%
# Mexican restaurants in Houston
import requests
import json
import pandas as pd
import matplotlib.pyplot as plt
from yelpapi import YelpAPI
from config import yelp_API

# %%
url='https://api.yelp.com/v3/businesses/search'
headers = {'Authorization':'Bearer '+ yelp_API}

# %%
# Mexican restaurants in Houston

df_yelp_houston_mexican=pd.DataFrame()

offset= [0, 50, 100, 150, 200, 250, 300, 350, 400, 450, 500, 550, 600, 650, 700, 750, 800, 850, 900, 950, 1000]

for item in offset:
    params_set1 = {'location': 'Houston, TX','limit': 50,'offset': item,'categories': 'mexican','term': 'restaurant'}
    response = requests.get(url, headers=headers, params=params_set1)
    response_json=response.json()
    res_lat=[]
    res_long=[]
    res_name=[]
    res_rating=[]
    res_vote=[]
    for respo in response_json:
        try:
            nam=response_json['businesses']
        except:
            print('NA')
        for na in nam:
            try:
                name= na['name']
                rating= na['rating']
                vote=na['review_count']
                lat=na['coordinates']['latitude']
                long=na['coordinates']['longitude']
                res_name.append(name)
                res_rating.append(rating)
                res_vote.append(vote)
                res_lat.append(lat)
                res_long.append(long)
            except:
                print('NA')
    df_yelp=pd.DataFrame({'Name': res_name,'Latitude':res_lat,'Longitude': res_long,'Votes': res_vote,'Rating': res_rating})
    df_yelp_houston_mexican=df_yelp_houston_mexican.append(df_yelp)

df_yelp_houston_mexican['Type']='mexican'
df_yelp_houston_mexican['City']='houston'
# Out:
# NA

# %%
# Drop duplicates:
df_yelp_houston_mexican_all=df_yelp_houston_mexican.drop_duplicates(keep='first')
df_yelp_houston_mexican_all
# Out:
#                                   Name   Latitude  Longitude   Votes  Rating  \
# 0   The Original Ninfa's on Navigation  29.756670 -95.342700  1333.0     4.0
# 1                     Irma's Southwest  29.757590 -95.358305   324.0     4.0
# 2                          La Fisheria  29.763473 -95.362154   528.0     4.0
# 3                       La Calle Tacos  29.763466 -95.360690   564.0     4.0
# 4               Blanco Tacos + Tequila  29.739600 -95.465471   319.0     4.0
# 5                            M&M Grill  29.701250 -95.385580   713.0     4.5
# 6                                Xochi  29.754551 -95.358200   702.0     4.0
# 7                           Calle Onze  29.790430 -95.399740   347.0     4.0
# 8          El Tiempo Cantina- Richmond  29.734229 -95.425733   732.0     4.0
# 9                        Cantina Barba  29.790850 -95.373390   129.0     4.5
# 10      El Tiempo Cantina - Navigation  29.756310 -95.341510   334.0     4.0
# ...

# %%
#### Save raw data to csv
df_yelp_houston_mexican_all.to_csv('C:\workspace\Resources\df_yelp_houston_mexican_all_NN.csv',index=False)

# %%
# BBQ restaurants in NY

df_yelp_ny_mexican=pd.DataFrame()

offset= [0, 50, 100, 150, 200, 250, 300, 350, 400, 450, 500, 550, 600, 650, 700, 750, 800, 850, 900, 950, 1000,1050, 1100]

for item in offset:
    params_set1 = {'location': 'New York, NY','limit': 50,'offset': item,'categories': 'mexican','term': 'restaurant'}
    response = requests.get(url, headers=headers, params=params_set1)
    response_json=response.json()
    res_lat=[]
    res_long=[]
    res_name=[]
    res_rating=[]
    res_vote=[]
    for respo in response_json:
        try:
            nam=response_json['businesses']
        except:
            print('NA')
        for na in nam:
            try:
                name= na['name']
                rating= na['rating']
                vote=na['review_count']
                lat=na['coordinates']['latitude']
                long=na['coordinates']['longitude']
                res_name.append(name)
                res_rating.append(rating)
                res_vote.append(vote)
                res_lat.append(lat)
                res_long.append(long)
            except:
                print('NA')
    df_yelp=pd.DataFrame({'Name': res_name,'Latitude':res_lat,'Longitude': res_long,'Votes': res_vote,'Rating': res_rating})
    df_yelp_ny_mexican=df_yelp_ny_mexican.append(df_yelp)

df_yelp_ny_mexican['Type']='mexican'
df_yelp_ny_mexican['City']='ny'
# Out:
# NA
# NA
# NA

# %%
# Drop duplicates:
df_yelp_ny_mexican_all=df_yelp_ny_mexican.drop_duplicates(keep='first')
df_yelp_ny_mexican_all
# Out:
#                                Name   Latitude  Longitude  Votes  Rating  \
# 0                            Jajaja  40.714153 -73.990425    859     4.5
# 1                            Jajaja  40.729790 -74.004550     73     4.5
# 2                       Toloache 50  40.762325 -73.985574   1904     4.0
# 3                      Casa Enrique  40.743404 -73.954350   1146     4.0
# 4                           Rosie's  40.724920 -73.990790    683     4.0
# 5                       Cafe Habana  40.722998 -73.994171   3134     4.0
# 6                           Oxomoco  40.729910 -73.955480    258     4.0
# 7                    Los Tacos No.1  40.742555 -74.006084   2861     4.5
# 8                       La Contenta  40.718730 -73.986910    720     4.5
# 9                          The Maze  40.747846 -73.987250    418     4.0
# 10                       Taco Dumbo  40.700601 -73.988467    182     4.0
# 11                        Breakroom  40.716691 -73.999944   1568     4.5
# ...

# %%
#### Save raw data to csv
df_yelp_ny_mexican_all.to_csv('../static/data/df_yelp_ny_mexican_all_NN.csv',index=False)
