# %%
# American restaurants in Houston
import requests
import json
import pandas as pd
import matplotlib.pyplot as plt
from yelpapi import YelpAPI
from config import yelp_API

# %%
url='https://api.yelp.com/v3/businesses/search'
headers = {'Authorization':'Bearer '+ yelp_API}

# %%
# mediterranean restaurants in Houston

df_yelp_houston_mediterranean=pd.DataFrame()

offset= [0, 50, 100, 150, 200, 250, 300, 350, 400, 450, 500, 550, 600, 650, 700, 750, 800, 850, 900, 950]

for item in offset:
    params_set1 = {'location': 'Houston, TX','limit': 50,'offset': item,'categories': 'mediterranean','term': 'restaurant'}
    response = requests.get(url, headers=headers, params=params_set1)
    response_json=response.json()
    res_lat=[]
    res_long=[]
    res_name=[]
    res_rating=[]
    res_vote=[]
    for respo in response_json:
        try:
            nam=response_json['businesses']
        except:
            print('NA')
        for na in nam:
            try:
                name= na['name']
                rating= na['rating']
                vote=na['review_count']
                lat=na['coordinates']['latitude']
                long=na['coordinates']['longitude']
                res_name.append(name)
                res_rating.append(rating)
                res_vote.append(vote)
                res_lat.append(lat)
                res_long.append(long)
            except:
                print('NA')
    df_yelp=pd.DataFrame({'Name': res_name,'Latitude':res_lat,'Longitude': res_long,'Votes': res_vote,'Rating': res_rating})
    df_yelp_houston_mediterranean=df_yelp_houston_mediterranean.append(df_yelp)

df_yelp_houston_mediterranean['Type']='mediterranean'
df_yelp_houston_mediterranean['City']='houston'

# %%
# Drop duplicates:
df_yelp_houston_mediterranean_all=df_yelp_houston_mediterranean.drop_duplicates(keep='first')
df_yelp_houston_mediterranean_all
# Out:
#                                          Name   Latitude  Longitude   Votes  \
# 0                                      Savoir  29.795960 -95.398890    34.0
# 1               Aladdin Mediterranean Cuisine  29.745032 -95.391123  1034.0
# 2                                   M&M Grill  29.701250 -95.385580   713.0
# 3           Niko Niko's Greek & American Cafe  29.746510 -95.392180  1888.0
# 4                          Doris Metropolitan  29.740215 -95.410475   201.0
# 5                                    Lucienne  29.755125 -95.366058    65.0
# 6                                        Roti  29.709264 -95.401498     3.0
# 7                       Fig & Olive - Houston  29.739691 -95.465290   271.0
# 8                                Warehouse 72  29.785959 -95.465455    88.0
# 9                         The Gyro Grill Guys  29.743904 -95.364636   216.0
# 10                             Istanbul Grill  29.715660 -95.414630   515.0
# ...

# %%
#### Save raw data to csv
df_yelp_houston_mediterranean_all.to_csv('C:\workspace\Resources\df_yelp_houston_mediterranean_all_NN.csv',index=False)

# %%
# mediterranean restaurants in New York

df_yelp_ny_mediterranean=pd.DataFrame()

offset= [0, 50, 100, 150, 200, 250, 300, 350, 400, 450, 500, 550, 600, 650, 700, 750, 800, 850, 900, 950, 1000]

for item in offset:
    params_set1 = {'location': 'New York, NY','limit': 50,'offset': item,'categories': 'mediterranean','term': 'restaurant'}
    response = requests.get(url, headers=headers, params=params_set1)
    response_json=response.json()
    res_lat=[]
    res_long=[]
    res_name=[]
    res_rating=[]
    res_vote=[]
    for respo in response_json:
        try:
            nam=response_json['businesses']
        except:
            print('NA')
        for na in nam:
            try:
                name= na['name']
                rating= na['rating']
                vote=na['review_count']
                lat=na['coordinates']['latitude']
                long=na['coordinates']['longitude']
                res_name.append(name)
                res_rating.append(rating)
                res_vote.append(vote)
                res_lat.append(lat)
                res_long.append(long)
            except:
                print('NA')
    df_yelp=pd.DataFrame({'Name': res_name,'Latitude':res_lat,'Longitude': res_long,'Votes': res_vote,'Rating': res_rating})
    df_yelp_ny_mediterranean=df_yelp_ny_mediterranean.append(df_yelp)

df_yelp_ny_mediterranean['Type']='mediterranean'
df_yelp_ny_mediterranean['City']='ny'
# Out:
# NA

# %%
# Drop duplicates:
df_yelp_ny_mediterranean_all=df_yelp_ny_mediterranean.drop_duplicates(keep='first')
df_yelp_ny_mediterranean_all
# Out:
#                                               Name   Latitude  Longitude  \
# 0                                           Balzem  40.721408 -73.995415
# 1                                             Alta  40.734516 -73.998337
# 2                    Tableside Italian Cook Shoppe  40.726629 -73.986338
# 3                                          Bijan's  40.688030 -73.986710
# 4                                        Celestine  40.704676 -73.987975
# 5                                           Savida  40.716450 -74.007830
# 6                                         Miss Ada  40.689436 -73.972381
# 7                                             Gato  40.725531 -73.995195
# 8                                         Local 92  40.726957 -73.988535
# 9                            Cathédrale Restaurant  40.731600 -73.989510
# 10                                           Shuka  40.727070 -74.002830
# 11                                            Yara  40.756460 -73.966200
# ...

# %%
#### Save raw data to csv
df_yelp_ny_mediterranean_all.to_csv('../static/data/df_yelp_ny_mediterranean_all_NN.csv',index=False)
