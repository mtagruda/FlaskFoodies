# %%
# American restaurants in Houston
import requests
import json
import pandas as pd
import matplotlib.pyplot as plt
from yelpapi import YelpAPI
from config import yelp_API

# %%
url='https://api.yelp.com/v3/businesses/search'
headers = {'Authorization':'Bearer '+ yelp_API}

# %%
# Italian restaurants in Houston

df_yelp_houston_italian=pd.DataFrame()

offset= [0, 50, 100, 150, 200, 250, 300, 350, 400, 450, 500, 550, 600, 650, 700, 750, 800, 850, 900, 950]

for item in offset:
    params_set1 = {'location': 'Houston, TX','limit': 50,'offset': item,'categories': 'italian','term': 'restaurant'}
    response = requests.get(url, headers=headers, params=params_set1)
    response_json=response.json()
    res_lat=[]
    res_long=[]
    res_name=[]
    res_rating=[]
    res_vote=[]
    for respo in response_json:
        try:
            nam=response_json['businesses']
        except:
            print('NA')
        for na in nam:
            try:
                name= na['name']
                rating= na['rating']
                vote=na['review_count']
                lat=na['coordinates']['latitude']
                long=na['coordinates']['longitude']
                res_name.append(name)
                res_rating.append(rating)
                res_vote.append(vote)
                res_lat.append(lat)
                res_long.append(long)
            except:
                print('NA')
    df_yelp=pd.DataFrame({'Name': res_name,'Latitude':res_lat,'Longitude': res_long,'Votes': res_vote,'Rating': res_rating})
    df_yelp_houston_italian=df_yelp_houston_italian.append(df_yelp)

df_yelp_houston_italian['Type']='italian'
df_yelp_houston_italian['City']='houston'

# %%
# Drop duplicates:
df_yelp_houston_italian_all=df_yelp_houston_italian.drop_duplicates(keep='first')
df_yelp_houston_italian_all
# Out:
#                              Name   Latitude  Longitude   Votes  Rating  \
# 0                    North Italia  29.748587 -95.462025  1520.0     4.0
# 1                Postino Montrose  29.746510 -95.390330    66.0     4.5
# 2                 Grotto Downtown  29.753918 -95.357197   324.0     4.0
# 3                       Coltivare  29.781700 -95.393710   831.0     4.0
# 4                           Crisp  29.806284 -95.422089   856.0     4.0
# 5           Bollo Woodfired Pizza  29.738979 -95.413458   580.0     4.5
# 6                Osso & Kristalla  29.757451 -95.357903   243.0     4.0
# 7                         Potente  29.757238 -95.357447   206.0     4.5
# 8       Riva's Italian Restaurant  29.746050 -95.392480   517.0     4.0
# 9                            Roma  29.714900 -95.414750    74.0     4.0
# 10                       Perbacco  29.760168 -95.365059   167.0     4.0
# 11          Giacomo's Cibo e Vino  29.742032 -95.423718   512.0     4.0
# 12                       Bistecca  29.744848 -95.383987   190.0     4.5
# 13  D'Amico's Italian Market Cafe  29.715980 -95.415350   368.0     4.0
# 14                       Da Marco  29.743130 -95.397814   324.0     4.0
# 15                     Dolce Vita  29.744775 -95.387420   711.0     4.0
# 16            Mia Bella Trattoria  29.753468 -95.364117   281.0     4.0
# 17                        Rocco's  29.793330 -95.359280    58.0     4.5
# 18                   Patrenella's  29.769120 -95.402100   348.0     4.0
# 19                   Warehouse 72  29.785959 -95.465455    88.0     4.0
# 20              BOH Pasta & Pizza  29.761766 -95.362181    37.0     4.5
# 21   Sorrento Ristorante Italiano  29.744413 -95.386714   306.0     4.0
# 22                Postino Heights  29.783060 -95.398530   402.0     4.0
# 23                     La Griglia  29.753560 -95.408890   352.0     4.0
# 24                Vinoteca Poscol  29.744760 -95.389350   121.0     4.0
# 25                          Piola  29.742872 -95.379885   587.0     4.0
# 26           Rosalie Italian Soul  29.757956 -95.371180    19.0     4.0
# 27                 Mandola's Deli  29.737640 -95.339560   271.0     4.5
# 28                 Antica Osteria  29.725282 -95.413276   315.0     4.0
# 29        Maggiano's Little Italy  29.745070 -95.460509   635.0     3.5
# ..                            ...        ...        ...     ...     ...
# 46           Luigi's Italian Food  29.748648 -95.378565    29.0     3.5
# 47                     Pizza Love  29.742012 -95.390618   100.0     3.0
# 48     Fuzzy's Pizza & Sport Cafe  29.704260 -95.473180    24.0     4.0
# 49      George's Italian Pizzaria  29.684781 -95.294033    29.0     3.5
# 0          Edo's Cafe On the Park  29.747768 -95.451782     9.0     3.0
# 1                 Food Music Life  29.734470 -95.423940    10.0     3.5
# 2              La Dolce Vita Cafe  29.756590 -95.368450    21.0     3.0
# 3                       Pizza Hut  29.850409 -95.265014    61.0     1.5
# 4                          Sbarro  29.738978 -95.462510    15.0     2.5
# 5                       Pizza Hut  29.751835 -95.355479    41.0     1.5
# 6                       Pizza Hut  29.706544 -95.405319    38.0     2.0
# 7                   Ponte Vecchio  29.758073 -95.370181     1.0     2.0
# 8                       Pizza Hut  29.777354 -95.396929    50.0     1.5
# 9                       Pizza Hut  29.841982 -95.472715    20.0     2.5
# 10                      Pizza Hut  29.732215 -95.441919    39.0     2.0
# 11                          Cicis  29.696303 -95.297224    12.0     2.5
# 12                       Corleone  29.769210 -95.402240     1.0     3.0
# 13                      Pizza Hut  29.827526 -95.431368    25.0     2.0
# 14                      Pizza Hut  29.731661 -95.308754    20.0     2.0
# 15                      Pizza Hut  29.743770 -95.394540    35.0     1.5
# 16                      Pizza Hut  29.672779 -95.275912    19.0     1.5
# 17       Kathrina's Cafe Roma III  29.705711 -95.403541     2.0     2.0
# 18                      Pizza Hut  29.691848 -95.412185    25.0     1.5
# 19                      Pizza Hut  29.719173 -95.337754    30.0     1.5
# 20                      Pizza Hut  29.828912 -95.379708    13.0     1.5
# 21                      Pizza Hut  29.724396 -95.476807     2.0     1.0
# 22                      Pizza Hut  29.703673 -95.296208     4.0     2.5
# 23                      Pizza Hut  29.850409 -95.265014     6.0     2.5
# 24                      Pizza Hut  42.023572 -95.368087    23.0     1.5
# 25                      Pizza Hut  27.545498 -99.482161     2.0     2.5
#
#        Type     City
# 0   italian  houston
# 1   italian  houston
# 2   italian  houston
# 3   italian  houston
# 4   italian  houston
# 5   italian  houston
# 6   italian  houston
# 7   italian  houston
# 8   italian  houston
# 9   italian  houston
# 10  italian  houston
# 11  italian  houston
# 12  italian  houston
# 13  italian  houston
# 14  italian  houston
# 15  italian  houston
# 16  italian  houston
# 17  italian  houston
# 18  italian  houston
# 19  italian  houston
# 20  italian  houston
# 21  italian  houston
# 22  italian  houston
# 23  italian  houston
# 24  italian  houston
# 25  italian  houston
# 26  italian  houston
# 27  italian  houston
# 28  italian  houston
# 29  italian  houston
# ..      ...      ...
# 46  italian  houston
# 47  italian  houston
# 48  italian  houston
# 49  italian  houston
# 0   italian  houston
# 1   italian  houston
# 2   italian  houston
# 3   italian  houston
# 4   italian  houston
# 5   italian  houston
# 6   italian  houston
# 7   italian  houston
# 8   italian  houston
# 9   italian  houston
# 10  italian  houston
# 11  italian  houston
# 12  italian  houston
# 13  italian  houston
# 14  italian  houston
# 15  italian  houston
# 16  italian  houston
# 17  italian  houston
# 18  italian  houston
# 19  italian  houston
# 20  italian  houston
# 21  italian  houston
# 22  italian  houston
# 23  italian  houston
# 24  italian  houston
# 25  italian  houston
#
# [126 rows x 7 columns]

# %%
#### Save raw data to csv
df_yelp_houston_italian_all.to_csv('C:\workspace\Resources\df_yelp_houston_italian_all_NN.csv',index=False)

# %%
# Italian restaurants in New York

df_yelp_ny_italian=pd.DataFrame()

offset= [0, 50, 100, 150, 200, 250, 300, 350, 400, 450, 500, 550, 600, 650, 700, 750, 800, 850, 900, 950, 1000]

for item in offset:
    params_set1 = {'location': 'New York, NY','limit': 50,'offset': item,'categories': 'italian','term': 'restaurant'}
    response = requests.get(url, headers=headers, params=params_set1)
    response_json=response.json()
    res_lat=[]
    res_long=[]
    res_name=[]
    res_rating=[]
    res_vote=[]
    for respo in response_json:
        try:
            nam=response_json['businesses']
        except:
            print('NA')
        for na in nam:
            try:
                name= na['name']
                rating= na['rating']
                vote=na['review_count']
                lat=na['coordinates']['latitude']
                long=na['coordinates']['longitude']
                res_name.append(name)
                res_rating.append(rating)
                res_vote.append(vote)
                res_lat.append(lat)
                res_long.append(long)
            except:
                print('NA')
    df_yelp=pd.DataFrame({'Name': res_name,'Latitude':res_lat,'Longitude': res_long,'Votes': res_vote,'Rating': res_rating})
    df_yelp_ny_italian=df_yelp_ny_italian.append(df_yelp)

df_yelp_ny_italian['Type']='italian'
df_yelp_ny_italian['City']='ny'
# Out:
# NA

# %%
# Drop duplicates:
df_yelp_ny_italian_all=df_yelp_ny_italian.drop_duplicates(keep='first')
df_yelp_ny_italian_all
# Out:
#                                            Name   Latitude  Longitude  Votes  \
# 0                                   Aunt Jake's  40.719031 -73.997716   1393
# 1                    Paesano of Mulberry Street  40.718554 -73.997447    834
# 2                                      L'Artusi  40.733714 -74.005068   1780
# 3                                     Da Andrea  40.736218 -73.995970    733
# 4                                 Gelso & Grand  40.719409 -73.997378    855
# 5                                      Rubirosa  40.722750 -73.996220   2104
# 6   Carmine's Italian Restaurant - Times Square  40.757496 -73.986684   3667
# 7                        Piccola Cucina Osteria  40.725060 -74.003220    498
# 8                             Antica Ristorante  40.703936 -74.012173    491
# 9                             Pepe Rosso Social  40.720070 -73.996180    812
# 10                                       Supper  40.722900 -73.985270   1268
# 11                                   Olio e Piú  40.733826 -73.999852   2029
# 12                Tableside Italian Cook Shoppe  40.726629 -73.986338    246
# 13                                    Naked Dog  40.731272 -73.959349    192
# 14                        Lillo Cucina Italiana  40.690230 -73.996340    119
# 15                                Carroll Place  40.728700 -73.999710   1030
# 16                               Noodle Pudding  40.699790 -73.992030    556
# 17                                       Aurora  40.715621 -73.964757    583
# 18                                        Galli  40.721610 -74.001270    901
# 19                                  Basta Pasta  40.738810 -73.994070   1406
# 20                                  IL Brigante  40.707492 -74.002571    379
# 21                                      Evelina  40.689722 -73.971003    151
# 22                                        Lilia  40.717570 -73.952360    754
# 23                                  Pepe Giallo  40.746894 -74.004990    624
# 24                               Sauce & Barrel  40.707999 -74.014265    377
# 25                          Malatesta Trattoria  40.732850 -74.008470   1227
# 26                                    Roberta's  40.705044 -73.933571   2764
# 27                                         Lupa  40.727600 -74.000045   1501
# 28                            The Saint Austere  40.711460 -73.947618    381
# 29                                  Forno Rosso  40.694460 -73.983160    662
# ..                                          ...        ...        ...    ...
# 20                                     Tiramisu  40.775154 -73.956967    176
# 21                    Sfilatino Italian Gourmet  40.767506 -73.985107    173
# 22                     Smiling Pizza Restaurant  40.667031 -73.981287    225
# 23      Abbondanza Trattoria & Brick Oven Pizza  40.715990 -74.045510    236
# 24                                      Panello  40.746949 -74.038004    181
# 25                 Pino's La Forchetta Pizzeria  40.671257 -73.977570    197
# 26                                Palermo Pizza  40.700360 -73.898260     16
# 27              Olive Garden Italian Restaurant  40.734006 -73.868733    386
# 28                          Donato's Restaurant  40.748580 -73.912980    141
# 29                 Panino Rustico of Mill Basin  40.619560 -73.919070     59
# 30                                  Rosticceria  40.741998 -73.989942     55
# 31           Centro Pizza Bar & Italian Kitchen  40.744890 -73.953010    100
# 32                        Luigi's Gourmet Grill  40.765550 -73.983420    187
# 33                                 Piccolo Cafe  40.755782 -73.990462    231
# 34                          Libretto's Pizzeria  40.747270 -73.977210    171
# 35                                  Otto Strada  40.746604 -74.031161    280
# 36                          Marchi's Restaurant  40.743140 -73.977590     41
# 37                           Little Italy Pizza  40.791875 -73.973554    264
# 38                   Il Mattone Lower East Side  40.723317 -73.989709      9
# 39                                    Luciano's  40.694168 -73.985017    109
# 40            Gina la Fornarina - Lexington Ave  40.770982 -73.961898     37
# 41                                 Ravioli Fair  40.706835 -74.010278      1
# 42                                Pizza Mercato  40.730150 -73.994160    162
# 43                                      Girello  40.719590 -74.007030     37
# 44                                   Pane Caldo  40.661072 -73.997063     15
# 45                                Tuscany Grill  40.622950 -74.031570     93
# 46                                Pizza D'Amore  40.614730 -73.912620    145
# 47                        Sal & Carmine's Pizza  40.798311 -73.969441    339
# 48                         Joe & Pat's Pizzeria  40.612810 -74.121980    369
# 49                           D. Coluccio & Sons  40.629740 -74.000290     56
#
#     Rating     Type City
# 0      4.0  italian   ny
# 1      4.0  italian   ny
# 2      4.5  italian   ny
# 3      4.0  italian   ny
# 4      4.0  italian   ny
# 5      4.5  italian   ny
# 6      4.0  italian   ny
# 7      4.5  italian   ny
# 8      4.5  italian   ny
# 9      4.0  italian   ny
# 10     4.0  italian   ny
# 11     4.0  italian   ny
# 12     4.5  italian   ny
# 13     4.5  italian   ny
# 14     5.0  italian   ny
# 15     4.0  italian   ny
# 16     4.0  italian   ny
# 17     4.0  italian   ny
# 18     4.0  italian   ny
# 19     4.0  italian   ny
# 20     4.0  italian   ny
# 21     4.5  italian   ny
# 22     4.0  italian   ny
# 23     4.0  italian   ny
# 24     4.0  italian   ny
# 25     4.0  italian   ny
# 26     4.0  italian   ny
# 27     4.0  italian   ny
# 28     4.5  italian   ny
# 29     4.0  italian   ny
# ..     ...      ...  ...
# 20     3.5  italian   ny
# 21     4.0  italian   ny
# 22     3.5  italian   ny
# 23     3.5  italian   ny
# 24     4.0  italian   ny
# 25     3.5  italian   ny
# 26     4.5  italian   ny
# 27     2.5  italian   ny
# 28     3.0  italian   ny
# 29     4.5  italian   ny
# 30     4.0  italian   ny
# 31     3.5  italian   ny
# 32     3.5  italian   ny
# 33     4.0  italian   ny
# 34     3.5  italian   ny
# 35     4.0  italian   ny
# 36     3.0  italian   ny
# 37     4.0  italian   ny
# 38     4.0  italian   ny
# 39     2.5  italian   ny
# 40     3.0  italian   ny
# 41     5.0  italian   ny
# 42     3.5  italian   ny
# 43     3.5  italian   ny
# 44     4.0  italian   ny
# 45     3.5  italian   ny
# 46     3.0  italian   ny
# 47     3.5  italian   ny
# 48     3.5  italian   ny
# 49     4.5  italian   ny
#
# [1000 rows x 7 columns]

# %%
#### Save raw data to csv
df_yelp_ny_italian_all.to_csv('../static/data/df_yelp_ny_italian_all_NN.csv',index=False)
