# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
## Open raw files
ny_mexican = pd.read_csv('../static/data/df_yelp_ny_mexican_all_NN.csv')
houston_mexican = pd.read_csv('../static/data/df_yelp_houston_mexican_all_NN.csv')
ny_mediterranean = pd.read_csv('../static/data/df_yelp_ny_mediterranean_all_NN.csv')
houston_mediterranean = pd.read_csv('../static/data/df_yelp_houston_mediterranean_all_NN.csv')
ny_italian = pd.read_csv('../static/data/df_yelp_ny_italian_all_NN.csv')
houston_italian = pd.read_csv('../static/data/df_yelp_houston_italian_all_NN.csv')
ny_indian = pd.read_csv('../static/data/df_yelp_ny_indian_all_NN.csv')
houston_indian = pd.read_csv('../static/data/df_yelp_houston_indian_all_NN.csv')
ny_bbq = pd.read_csv('../static/data/df_yelp_ny_bbq_all_NN.csv')
houston_bbq = pd.read_csv('../static/data/df_yelp_houston_bbq_all_NN.csv')
ny_american = pd.read_csv('../static/data/df_yelp_ny_american_all_NN.csv')
houston_american = pd.read_csv('../static/data/df_yelp_houston_american_all_NN.csv')

# %%
df_all= pd.DataFrame()
df_all= (((((((((((df_all.append(ny_mexican)).append(houston_mexican)).append(ny_mediterranean)).append(houston_mediterranean)).append(ny_italian)).append(houston_italian)).append(ny_indian)).append(houston_indian)).append(ny_bbq)).append(houston_bbq)).append(ny_american)).append(houston_american)
df_all
# Out:
#                                   Name   Latitude  Longitude   Votes  Rating  \
# 0                               Jajaja  40.714153 -73.990425   859.0     4.5
# 1                               Jajaja  40.729790 -74.004550    73.0     4.5
# 2                          Toloache 50  40.762325 -73.985574  1904.0     4.0
# 3                         Casa Enrique  40.743404 -73.954350  1146.0     4.0
# 4                              Rosie's  40.724920 -73.990790   683.0     4.0
# 5                          Cafe Habana  40.722998 -73.994171  3134.0     4.0
# 6                              Oxomoco  40.729910 -73.955480   258.0     4.0
# 7                       Los Tacos No.1  40.742555 -74.006084  2861.0     4.5
# 8                          La Contenta  40.718730 -73.986910   720.0     4.5
# 9                             The Maze  40.747846 -73.987250   418.0     4.0
# 10                          Taco Dumbo  40.700601 -73.988467   182.0     4.0
# ...

# %%
df_all_c=df_all.dropna(how='any')
df_all_c
# Out:
#                                   Name   Latitude  Longitude   Votes  Rating  \
# 0                               Jajaja  40.714153 -73.990425   859.0     4.5
# 1                               Jajaja  40.729790 -74.004550    73.0     4.5
# 2                          Toloache 50  40.762325 -73.985574  1904.0     4.0
# 3                         Casa Enrique  40.743404 -73.954350  1146.0     4.0
# 4                              Rosie's  40.724920 -73.990790   683.0     4.0
# 5                          Cafe Habana  40.722998 -73.994171  3134.0     4.0
# 6                              Oxomoco  40.729910 -73.955480   258.0     4.0
# 7                       Los Tacos No.1  40.742555 -74.006084  2861.0     4.5
# 8                          La Contenta  40.718730 -73.986910   720.0     4.5
# 9                             The Maze  40.747846 -73.987250   418.0     4.0
# 10                          Taco Dumbo  40.700601 -73.988467   182.0     4.0
# ...

# %%
#### Save combined data to csv
df_all_c.to_csv('../static/data/df_all_NN.csv',index=False)
